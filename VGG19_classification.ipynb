# %% [markdown]
# <h3>Import packages</h3>

# %%
from datetime import date
from timeit import default_timer as timer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import imagenet_utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Configure TensorFlow to use GPU for training
tf.config.list_physical_devices('GPU') 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
#Set GPU memory limit so my GPU doesn't crash
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <h3>Create class to record time taken to train the model</h3>

# %%
#class to record time taken to train per epoch
class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# <h3>Create train and test folder</h3>

# %%
#creates a folder each time the set of code is run to sort dataset into train and test
day = date.today()
formatDate = day.strftime("%b-%d-%Y")

#create folder with current date to group predictions ran in a day together, if it does not exists
if os.path.isdir('Prediction (' + formatDate + ')') is False:
    folder = os.mkdir('Prediction (' + formatDate + ')')
folder = 'Prediction (' + formatDate + ')'

#looping through to find if destination folder exists
i = 1
while True:
    if os.path.isdir(folder + '/Battery Images - ' + str(i)) is False:
        break
    i += 1

#destination path for unsorted folder
destination = folder + '/Battery Images - ' + str(i)

#source path for unsorted folder
# source = 'Battery Images/'
# source = 'Battery Images [Old]/'
# source = 'Battery Images [StreamLined]/'
source = 'Battery Images [Download]/'

#duplicate the unsorted folder from source to destination
shutil.copytree(source, destination)

os.mkdir(destination + '/train')
os.mkdir(destination + '/test')

# %% [markdown]
# <h3>Sort dataset into train and test folder</h3>

# %%
#function to split images into training (80%) and testing (20%) and return both
def split(data):
    # num = int(len(data) * 0.8)
    num = int(len(data) * 0.9) #90/10 split
#     num = int(len(data) * 0.7) #70/30 split
    random.shuffle(data)
    return data[:num], data[num:]

dir = os.chdir(destination)
for category in os.listdir(dir):
    #skip the iteration if folder is "train" or "test"
    skip = ['train', 'test']
    if category in skip:
        continue
    
    shutil.move(f'{category}', 'train')
    #create a subfolder with the same name in test
    os.mkdir(f'test/{category}')

    #get the images in each folder (battery type) for spltting of data into training and testing
    img = os.listdir(f'train/{category}')
    training, testing = split(img)
    
    for file in testing:
        shutil.move(f'train/{category}/{file}', f'test/{category}')

# %% [markdown]
# <h3>a) Simple sequential model</h3>

# %%
model = keras.Sequential()
model.add(keras.Input(shape=(224, 224, 3)))  # 250x250 RGB images
model.add(layers.Conv2D(32, 5, strides=2, activation="relu"))
model.add(layers.Conv2D(32, 3, activation="relu"))
model.add(layers.MaxPooling2D(3))
model.add(layers.Conv2D(32, 3, activation="relu"))
model.add(layers.Conv2D(32, 3, activation="relu"))
model.add(layers.MaxPooling2D(3))
model.add(layers.Conv2D(32, 3, activation="relu"))
model.add(layers.Conv2D(32, 3, activation="relu"))
model.add(layers.MaxPooling2D(2))
model.add(layers.GlobalMaxPooling2D())
# model.add(layers.Dense(5, activation="softmax"))
# model.add(layers.Dense(10, activation="softmax")) #For 10 Cats
model.add(layers.Dense(8, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 110, 110, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 108, 108, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 36, 36, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 32)        9248
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)          9248
#
#  conv2d_5 (Conv2D)           (None, 6, 6, 32)          9248
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 32)         0
#  2D)
#
#  global_max_pooling2d (Globa  (None, 32)               0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 8)                 264
#
# =================================================================
# Total params: 48,936
# Trainable params: 48,936
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h3>b) Transfer Learning - MobileNet</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.mobilenet.MobileNet(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %% [markdown]
# <h3>c) Transfer Learning - MobileNetV2</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.MobileNetV2(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %% [markdown]
# <h3>c) Transfer Learning - VGG16</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.vgg16.VGG16(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %% [markdown]
# <h3>d) Transfer Learning - VGG19</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.vgg19.VGG19(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
mobile.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in mobile.layers[:-2]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = mobile(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
# x = tf.keras.layers.Dropout(0.65)(x) #Higher dropout to reduce overfitting (last best setting)
# output = tf.keras.layers.Dense(5, activation="softmax")(x)   
# output = tf.keras.layers.Dense(10, activation="softmax")(x)   #Changed to reflect new categories
output = tf.keras.layers.Dense(8, activation="softmax")(x)   #Changed to reflect new categories

model = keras.Model(inputs, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 8)                 4104
#
# =================================================================
# Total params: 20,028,488
# Trainable params: 2,363,912
# Non-trainable params: 17,664,576
# _________________________________________________________________

# %% [markdown]
# <h3>Process data</h3>

# %%
train_path = 'train'
test_path = 'test'

#for data augmentation on training data
datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet.preprocess_input,
    # validation_split=0.2,
    validation_split=0.1, #changes made for 90/10 split
    rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.2, # Randomly zoom image 
    width_shift_range = 0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range = 0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip = True,  # randomly flip images
#     vertical_flip = False,    # randomly flip images
    vertical_flip = True, #include vertical flip for better generalisation
    )  

#takes images from directory path and generates batches of augmented data
train = datagen.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='training',
        shuffle = False)

#for validation data
# validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
#                                         validation_split=0.2)
validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
                                        validation_split=0.1) #changes made for 90/10 split


validation = validation_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='validation',
        shuffle = False)

#for test data
test = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input)\
.flow_from_directory(directory=test_path, target_size=(224,224), batch_size=32, shuffle=False)
# Out:
# Found 691 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 89 images belonging to 8 classes.

# %% [markdown]
# <h3>Train model</h3>

# %%
model.compile(optimizer=Adam(learning_rate=0.006), loss='categorical_crossentropy', metrics=['accuracy']) #Last best setting
# model.compile(optimizer=Adam(learning_rate=0.0045), loss='categorical_crossentropy', metrics=['accuracy']) #Lower LR
# model.compile(optimizer=Adam(learning_rate=0.0075), loss='categorical_crossentropy', metrics=['accuracy']) 
checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True) #save best model

#more epochs for better results
result = model.fit(x=train, validation_data=validation, epochs=300, verbose=2, callbacks=[model_checkpoint_callback,cb])
# result = model.fit(x=train, validation_data=validation, epochs=200, verbose=2, callbacks=[cb])
# Out:
# Epoch 1/300
# c:\Users\ngden\anaconda3\lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 22/22 - 48s - loss: 8.3536 - accuracy: 0.0751 - val_loss: 2.0776 - val_accuracy: 0.1370 - 48s/epoch - 2s/step
# Epoch 2/300
# 22/22 - 24s - loss: 2.0838 - accuracy: 0.1358 - val_loss: 2.0780 - val_accuracy: 0.1644 - 24s/epoch - 1s/step
# Epoch 3/300
# 22/22 - 15s - loss: 2.0801 - accuracy: 0.1460 - val_loss: 2.0707 - val_accuracy: 0.1918 - 15s/epoch - 692ms/step
# Epoch 4/300
# 22/22 - 15s - loss: 2.0707 - accuracy: 0.1561 - val_loss: 2.0478 - val_accuracy: 0.1644 - 15s/epoch - 682ms/step
# Epoch 5/300
# 22/22 - 16s - loss: 2.0604 - accuracy: 0.1850 - val_loss: 1.9805 - val_accuracy: 0.1644 - 16s/epoch - 706ms/step
# Epoch 6/300
# 22/22 - 16s - loss: 2.0377 - accuracy: 0.1705 - val_loss: 1.9840 - val_accuracy: 0.2055 - 16s/epoch - 716ms/step
# Epoch 7/300
# 22/22 - 15s - loss: 2.0462 - accuracy: 0.1821 - val_loss: 2.0223 - val_accuracy: 0.2055 - 15s/epoch - 686ms/step
# Epoch 8/300
# 22/22 - 15s - loss: 2.0421 - accuracy: 0.1835 - val_loss: 1.9456 - val_accuracy: 0.2055 - 15s/epoch - 680ms/step
# Epoch 9/300
# 22/22 - 16s - loss: 1.9609 - accuracy: 0.1922 - val_loss: 1.8757 - val_accuracy: 0.2192 - 16s/epoch - 708ms/step
# Epoch 10/300
# 22/22 - 15s - loss: 2.0192 - accuracy: 0.1647 - val_loss: 1.8804 - val_accuracy: 0.2466 - 15s/epoch - 702ms/step
# Epoch 11/300
# 22/22 - 15s - loss: 1.9674 - accuracy: 0.1329 - val_loss: 1.9236 - val_accuracy: 0.2192 - 15s/epoch - 693ms/step
# Epoch 12/300
# 22/22 - 15s - loss: 1.9775 - accuracy: 0.1633 - val_loss: 1.9843 - val_accuracy: 0.1644 - 15s/epoch - 687ms/step
# Epoch 13/300
# 22/22 - 15s - loss: 1.9701 - accuracy: 0.1734 - val_loss: 1.8653 - val_accuracy: 0.1918 - 15s/epoch - 669ms/step
# Epoch 14/300
# 22/22 - 16s - loss: 1.9345 - accuracy: 0.2139 - val_loss: 1.8239 - val_accuracy: 0.2877 - 16s/epoch - 717ms/step
# Epoch 15/300
# 22/22 - 15s - loss: 1.9657 - accuracy: 0.2095 - val_loss: 1.9717 - val_accuracy: 0.3014 - 15s/epoch - 685ms/step
# Epoch 16/300
# 22/22 - 15s - loss: 2.0382 - accuracy: 0.1763 - val_loss: 1.9238 - val_accuracy: 0.3151 - 15s/epoch - 688ms/step
# Epoch 17/300
# 22/22 - 16s - loss: 1.9588 - accuracy: 0.2240 - val_loss: 1.7765 - val_accuracy: 0.4110 - 16s/epoch - 713ms/step
# Epoch 18/300
# 22/22 - 16s - loss: 1.9303 - accuracy: 0.2327 - val_loss: 1.8127 - val_accuracy: 0.4110 - 16s/epoch - 705ms/step
# Epoch 19/300
# 22/22 - 16s - loss: 1.8968 - accuracy: 0.2110 - val_loss: 1.7587 - val_accuracy: 0.4247 - 16s/epoch - 716ms/step
# Epoch 20/300
# 22/22 - 15s - loss: 1.9219 - accuracy: 0.2428 - val_loss: 1.7587 - val_accuracy: 0.4110 - 15s/epoch - 685ms/step
# Epoch 21/300
# 22/22 - 15s - loss: 1.8751 - accuracy: 0.2471 - val_loss: 1.7690 - val_accuracy: 0.4384 - 15s/epoch - 689ms/step
# Epoch 22/300
# 22/22 - 15s - loss: 1.8727 - accuracy: 0.2803 - val_loss: 1.6985 - val_accuracy: 0.3973 - 15s/epoch - 683ms/step
# Epoch 23/300
# 22/22 - 16s - loss: 1.8901 - accuracy: 0.2688 - val_loss: 1.7187 - val_accuracy: 0.4521 - 16s/epoch - 713ms/step
# Epoch 24/300
# 22/22 - 15s - loss: 1.8841 - accuracy: 0.2500 - val_loss: 1.7390 - val_accuracy: 0.4247 - 15s/epoch - 679ms/step
# Epoch 25/300
# 22/22 - 15s - loss: 1.8797 - accuracy: 0.2702 - val_loss: 1.6443 - val_accuracy: 0.4932 - 15s/epoch - 694ms/step
# Epoch 26/300
# 22/22 - 15s - loss: 1.8370 - accuracy: 0.2746 - val_loss: 1.6633 - val_accuracy: 0.4384 - 15s/epoch - 683ms/step
# Epoch 27/300
# 22/22 - 15s - loss: 1.8036 - accuracy: 0.2876 - val_loss: 1.6261 - val_accuracy: 0.5068 - 15s/epoch - 697ms/step
# Epoch 28/300
# 22/22 - 15s - loss: 1.8417 - accuracy: 0.2659 - val_loss: 1.6489 - val_accuracy: 0.4795 - 15s/epoch - 679ms/step
# Epoch 29/300
# 22/22 - 15s - loss: 1.7917 - accuracy: 0.3165 - val_loss: 1.5780 - val_accuracy: 0.4932 - 15s/epoch - 675ms/step
# Epoch 30/300
# 22/22 - 15s - loss: 1.8160 - accuracy: 0.3092 - val_loss: 1.5873 - val_accuracy: 0.5205 - 15s/epoch - 695ms/step
# Epoch 31/300
# 22/22 - 15s - loss: 1.7794 - accuracy: 0.2659 - val_loss: 1.6343 - val_accuracy: 0.4795 - 15s/epoch - 679ms/step
# Epoch 32/300
# 22/22 - 15s - loss: 1.8088 - accuracy: 0.2919 - val_loss: 1.6841 - val_accuracy: 0.4658 - 15s/epoch - 682ms/step
# Epoch 33/300
# 22/22 - 15s - loss: 1.7769 - accuracy: 0.3396 - val_loss: 1.5077 - val_accuracy: 0.5616 - 15s/epoch - 693ms/step
# Epoch 34/300
# 22/22 - 15s - loss: 1.8120 - accuracy: 0.2731 - val_loss: 1.6606 - val_accuracy: 0.5068 - 15s/epoch - 685ms/step
# Epoch 35/300
# 22/22 - 15s - loss: 1.7677 - accuracy: 0.3121 - val_loss: 1.5489 - val_accuracy: 0.4932 - 15s/epoch - 688ms/step
# Epoch 36/300
# 22/22 - 15s - loss: 1.7927 - accuracy: 0.3020 - val_loss: 1.5777 - val_accuracy: 0.5479 - 15s/epoch - 680ms/step
# Epoch 37/300
# 22/22 - 16s - loss: 1.7313 - accuracy: 0.3179 - val_loss: 1.7084 - val_accuracy: 0.4521 - 16s/epoch - 708ms/step
# Epoch 38/300
# 22/22 - 15s - loss: 1.8270 - accuracy: 0.2905 - val_loss: 1.6386 - val_accuracy: 0.4658 - 15s/epoch - 694ms/step
# Epoch 39/300
# 22/22 - 15s - loss: 1.7850 - accuracy: 0.2847 - val_loss: 1.5121 - val_accuracy: 0.5205 - 15s/epoch - 682ms/step
# Epoch 40/300
# 22/22 - 15s - loss: 1.7506 - accuracy: 0.3237 - val_loss: 1.5230 - val_accuracy: 0.5342 - 15s/epoch - 684ms/step
# Epoch 41/300
# 22/22 - 15s - loss: 1.7530 - accuracy: 0.3179 - val_loss: 1.5646 - val_accuracy: 0.4932 - 15s/epoch - 666ms/step
# Epoch 42/300
# 22/22 - 15s - loss: 1.7092 - accuracy: 0.3526 - val_loss: 1.4846 - val_accuracy: 0.5479 - 15s/epoch - 684ms/step
# Epoch 43/300
# 22/22 - 15s - loss: 1.7357 - accuracy: 0.3150 - val_loss: 1.5387 - val_accuracy: 0.4932 - 15s/epoch - 660ms/step
# Epoch 44/300
# 22/22 - 15s - loss: 1.7032 - accuracy: 0.3439 - val_loss: 1.4816 - val_accuracy: 0.5205 - 15s/epoch - 673ms/step
# Epoch 45/300
# 22/22 - 15s - loss: 1.7181 - accuracy: 0.3454 - val_loss: 1.5055 - val_accuracy: 0.4521 - 15s/epoch - 665ms/step
# Epoch 46/300
# 22/22 - 15s - loss: 1.6513 - accuracy: 0.3656 - val_loss: 1.4514 - val_accuracy: 0.5068 - 15s/epoch - 666ms/step
# Epoch 47/300
# 22/22 - 15s - loss: 1.6727 - accuracy: 0.3526 - val_loss: 1.4367 - val_accuracy: 0.5068 - 15s/epoch - 673ms/step
# Epoch 48/300
# 22/22 - 15s - loss: 1.5832 - accuracy: 0.4263 - val_loss: 1.4445 - val_accuracy: 0.5342 - 15s/epoch - 686ms/step
# Epoch 49/300
# 22/22 - 15s - loss: 1.6819 - accuracy: 0.3656 - val_loss: 1.4586 - val_accuracy: 0.5205 - 15s/epoch - 679ms/step
# Epoch 50/300
# 22/22 - 15s - loss: 1.6023 - accuracy: 0.3801 - val_loss: 1.4378 - val_accuracy: 0.5342 - 15s/epoch - 663ms/step
# Epoch 51/300
# 22/22 - 15s - loss: 1.6154 - accuracy: 0.3988 - val_loss: 1.5453 - val_accuracy: 0.4658 - 15s/epoch - 662ms/step
# Epoch 52/300
# 22/22 - 15s - loss: 1.6204 - accuracy: 0.3844 - val_loss: 1.4005 - val_accuracy: 0.5890 - 15s/epoch - 690ms/step
# Epoch 53/300
# 22/22 - 15s - loss: 1.6010 - accuracy: 0.3873 - val_loss: 1.5238 - val_accuracy: 0.5342 - 15s/epoch - 690ms/step
# Epoch 54/300
# 22/22 - 15s - loss: 1.5851 - accuracy: 0.4046 - val_loss: 1.4683 - val_accuracy: 0.5205 - 15s/epoch - 660ms/step
# Epoch 55/300
# 22/22 - 14s - loss: 1.5525 - accuracy: 0.4032 - val_loss: 1.4345 - val_accuracy: 0.5342 - 14s/epoch - 659ms/step
# Epoch 56/300
# 22/22 - 15s - loss: 1.5775 - accuracy: 0.3887 - val_loss: 1.4562 - val_accuracy: 0.5342 - 15s/epoch - 664ms/step
# Epoch 57/300
# 22/22 - 15s - loss: 1.5825 - accuracy: 0.4061 - val_loss: 1.3360 - val_accuracy: 0.5890 - 15s/epoch - 662ms/step
# Epoch 58/300
# 22/22 - 15s - loss: 1.6366 - accuracy: 0.3627 - val_loss: 1.4060 - val_accuracy: 0.5753 - 15s/epoch - 664ms/step
# Epoch 59/300
# 22/22 - 15s - loss: 1.5890 - accuracy: 0.4090 - val_loss: 1.3898 - val_accuracy: 0.5616 - 15s/epoch - 664ms/step
# Epoch 60/300
# 22/22 - 15s - loss: 1.5600 - accuracy: 0.3960 - val_loss: 1.3627 - val_accuracy: 0.5616 - 15s/epoch - 668ms/step
# Epoch 61/300
# 22/22 - 15s - loss: 1.5365 - accuracy: 0.4118 - val_loss: 1.3977 - val_accuracy: 0.5616 - 15s/epoch - 666ms/step
# Epoch 62/300
# 22/22 - 15s - loss: 1.5147 - accuracy: 0.4234 - val_loss: 1.3341 - val_accuracy: 0.6027 - 15s/epoch - 680ms/step
# Epoch 63/300
# 22/22 - 15s - loss: 1.5296 - accuracy: 0.4205 - val_loss: 1.3110 - val_accuracy: 0.6164 - 15s/epoch - 676ms/step
# Epoch 64/300
# 22/22 - 14s - loss: 1.5069 - accuracy: 0.4234 - val_loss: 1.2811 - val_accuracy: 0.5890 - 14s/epoch - 658ms/step
# Epoch 65/300
# 22/22 - 15s - loss: 1.5044 - accuracy: 0.4205 - val_loss: 1.3146 - val_accuracy: 0.6027 - 15s/epoch - 661ms/step
# Epoch 66/300
# 22/22 - 15s - loss: 1.5652 - accuracy: 0.4046 - val_loss: 1.3689 - val_accuracy: 0.5616 - 15s/epoch - 660ms/step
# Epoch 67/300
# 22/22 - 15s - loss: 1.5812 - accuracy: 0.4176 - val_loss: 1.2128 - val_accuracy: 0.6438 - 15s/epoch - 675ms/step
# Epoch 68/300
# 22/22 - 15s - loss: 1.4742 - accuracy: 0.4451 - val_loss: 1.2839 - val_accuracy: 0.6164 - 15s/epoch - 662ms/step
# Epoch 69/300
# 22/22 - 15s - loss: 1.4861 - accuracy: 0.4393 - val_loss: 1.3568 - val_accuracy: 0.5890 - 15s/epoch - 660ms/step
# Epoch 70/300
# 22/22 - 15s - loss: 1.5160 - accuracy: 0.4147 - val_loss: 1.2243 - val_accuracy: 0.6712 - 15s/epoch - 670ms/step
# Epoch 71/300
# 22/22 - 15s - loss: 1.4952 - accuracy: 0.4321 - val_loss: 1.2613 - val_accuracy: 0.6438 - 15s/epoch - 662ms/step
# Epoch 72/300
# 22/22 - 15s - loss: 1.5202 - accuracy: 0.4249 - val_loss: 1.2159 - val_accuracy: 0.6164 - 15s/epoch - 660ms/step
# Epoch 73/300
# 22/22 - 15s - loss: 1.4477 - accuracy: 0.4422 - val_loss: 1.2540 - val_accuracy: 0.5753 - 15s/epoch - 659ms/step
# Epoch 74/300
# 22/22 - 15s - loss: 1.4598 - accuracy: 0.4552 - val_loss: 1.0972 - val_accuracy: 0.6986 - 15s/epoch - 677ms/step
# Epoch 75/300
# 22/22 - 15s - loss: 1.4908 - accuracy: 0.4176 - val_loss: 1.2908 - val_accuracy: 0.5479 - 15s/epoch - 666ms/step
# Epoch 76/300
# 22/22 - 15s - loss: 1.4889 - accuracy: 0.4191 - val_loss: 1.2094 - val_accuracy: 0.6438 - 15s/epoch - 674ms/step
# Epoch 77/300
# 22/22 - 15s - loss: 1.4605 - accuracy: 0.4277 - val_loss: 1.2181 - val_accuracy: 0.5890 - 15s/epoch - 670ms/step
# Epoch 78/300
# 22/22 - 15s - loss: 1.5094 - accuracy: 0.4176 - val_loss: 1.2025 - val_accuracy: 0.6027 - 15s/epoch - 685ms/step
# Epoch 79/300
# 22/22 - 15s - loss: 1.4616 - accuracy: 0.4234 - val_loss: 1.2124 - val_accuracy: 0.6027 - 15s/epoch - 679ms/step
# Epoch 80/300
# 22/22 - 14s - loss: 1.3982 - accuracy: 0.4436 - val_loss: 1.1967 - val_accuracy: 0.6164 - 14s/epoch - 658ms/step
# Epoch 81/300
# 22/22 - 14s - loss: 1.4560 - accuracy: 0.4451 - val_loss: 1.1723 - val_accuracy: 0.6164 - 14s/epoch - 655ms/step
# Epoch 82/300
# 22/22 - 15s - loss: 1.4700 - accuracy: 0.4364 - val_loss: 1.2014 - val_accuracy: 0.6301 - 15s/epoch - 662ms/step
# Epoch 83/300
# 22/22 - 15s - loss: 1.4223 - accuracy: 0.4552 - val_loss: 1.1145 - val_accuracy: 0.6301 - 15s/epoch - 668ms/step
# Epoch 84/300
# 22/22 - 15s - loss: 1.4478 - accuracy: 0.4292 - val_loss: 1.1212 - val_accuracy: 0.6164 - 15s/epoch - 682ms/step
# Epoch 85/300
# 22/22 - 15s - loss: 1.4556 - accuracy: 0.4350 - val_loss: 1.0608 - val_accuracy: 0.7397 - 15s/epoch - 686ms/step
# Epoch 86/300
# 22/22 - 15s - loss: 1.4558 - accuracy: 0.4494 - val_loss: 1.1009 - val_accuracy: 0.6986 - 15s/epoch - 670ms/step
# Epoch 87/300
# 22/22 - 15s - loss: 1.3674 - accuracy: 0.4827 - val_loss: 1.0933 - val_accuracy: 0.6575 - 15s/epoch - 669ms/step
# Epoch 88/300
# 22/22 - 15s - loss: 1.4168 - accuracy: 0.4465 - val_loss: 1.0675 - val_accuracy: 0.6849 - 15s/epoch - 663ms/step
# Epoch 89/300
# 22/22 - 15s - loss: 1.3917 - accuracy: 0.4754 - val_loss: 1.0651 - val_accuracy: 0.6438 - 15s/epoch - 689ms/step
# Epoch 90/300
# 22/22 - 15s - loss: 1.4218 - accuracy: 0.4408 - val_loss: 1.0671 - val_accuracy: 0.6575 - 15s/epoch - 660ms/step
# Epoch 91/300
# 22/22 - 15s - loss: 1.3672 - accuracy: 0.4668 - val_loss: 1.1567 - val_accuracy: 0.6164 - 15s/epoch - 664ms/step
# Epoch 92/300
# 22/22 - 15s - loss: 1.3887 - accuracy: 0.4509 - val_loss: 1.0992 - val_accuracy: 0.6712 - 15s/epoch - 685ms/step
# Epoch 93/300
# 22/22 - 15s - loss: 1.3233 - accuracy: 0.4899 - val_loss: 1.0506 - val_accuracy: 0.6438 - 15s/epoch - 665ms/step
# Epoch 94/300
# 22/22 - 14s - loss: 1.3474 - accuracy: 0.4798 - val_loss: 1.1681 - val_accuracy: 0.6438 - 14s/epoch - 657ms/step
# Epoch 95/300
# 22/22 - 14s - loss: 1.3792 - accuracy: 0.4668 - val_loss: 1.0347 - val_accuracy: 0.6712 - 14s/epoch - 657ms/step
# Epoch 96/300
# 22/22 - 14s - loss: 1.3165 - accuracy: 0.4812 - val_loss: 1.0663 - val_accuracy: 0.5890 - 14s/epoch - 655ms/step
# Epoch 97/300
# 22/22 - 14s - loss: 1.3736 - accuracy: 0.4798 - val_loss: 1.0774 - val_accuracy: 0.6301 - 14s/epoch - 656ms/step
# Epoch 98/300
# 22/22 - 14s - loss: 1.4012 - accuracy: 0.4595 - val_loss: 1.0506 - val_accuracy: 0.6301 - 14s/epoch - 658ms/step
# Epoch 99/300
# 22/22 - 14s - loss: 1.3253 - accuracy: 0.4682 - val_loss: 1.0137 - val_accuracy: 0.6575 - 14s/epoch - 658ms/step
# Epoch 100/300
# 22/22 - 14s - loss: 1.2550 - accuracy: 0.5043 - val_loss: 0.9619 - val_accuracy: 0.6986 - 14s/epoch - 654ms/step
# Epoch 101/300
# 22/22 - 14s - loss: 1.3208 - accuracy: 0.4812 - val_loss: 1.0867 - val_accuracy: 0.6438 - 14s/epoch - 658ms/step
# Epoch 102/300
# 22/22 - 14s - loss: 1.3305 - accuracy: 0.4740 - val_loss: 1.0155 - val_accuracy: 0.6438 - 14s/epoch - 654ms/step
# Epoch 103/300
# 22/22 - 14s - loss: 1.2773 - accuracy: 0.4870 - val_loss: 1.0565 - val_accuracy: 0.6164 - 14s/epoch - 658ms/step
# Epoch 104/300
# 22/22 - 14s - loss: 1.3645 - accuracy: 0.4725 - val_loss: 1.0899 - val_accuracy: 0.6438 - 14s/epoch - 656ms/step
# Epoch 105/300
# 22/22 - 14s - loss: 1.3498 - accuracy: 0.4653 - val_loss: 1.0991 - val_accuracy: 0.6027 - 14s/epoch - 657ms/step
# Epoch 106/300
# 22/22 - 14s - loss: 1.3579 - accuracy: 0.4697 - val_loss: 1.0172 - val_accuracy: 0.5890 - 14s/epoch - 655ms/step
# Epoch 107/300
# 22/22 - 15s - loss: 1.3463 - accuracy: 0.4740 - val_loss: 1.0079 - val_accuracy: 0.6712 - 15s/epoch - 661ms/step
# Epoch 108/300
# 22/22 - 14s - loss: 1.2920 - accuracy: 0.4827 - val_loss: 1.0039 - val_accuracy: 0.6712 - 14s/epoch - 653ms/step
# Epoch 109/300
# 22/22 - 14s - loss: 1.3050 - accuracy: 0.4783 - val_loss: 1.0352 - val_accuracy: 0.6301 - 14s/epoch - 657ms/step
# Epoch 110/300
# 22/22 - 14s - loss: 1.3222 - accuracy: 0.4725 - val_loss: 0.9673 - val_accuracy: 0.7260 - 14s/epoch - 656ms/step
# Epoch 111/300
# 22/22 - 14s - loss: 1.2496 - accuracy: 0.4870 - val_loss: 0.9828 - val_accuracy: 0.6849 - 14s/epoch - 656ms/step
# Epoch 112/300
# 22/22 - 14s - loss: 1.3374 - accuracy: 0.4581 - val_loss: 1.0138 - val_accuracy: 0.6438 - 14s/epoch - 654ms/step
# Epoch 113/300
# 22/22 - 14s - loss: 1.3100 - accuracy: 0.4610 - val_loss: 0.9700 - val_accuracy: 0.6712 - 14s/epoch - 658ms/step
# Epoch 114/300
# 22/22 - 14s - loss: 1.3174 - accuracy: 0.4653 - val_loss: 0.9740 - val_accuracy: 0.6712 - 14s/epoch - 657ms/step
# Epoch 115/300
# 22/22 - 15s - loss: 1.2478 - accuracy: 0.5217 - val_loss: 0.9381 - val_accuracy: 0.6986 - 15s/epoch - 695ms/step
# Epoch 116/300
# 22/22 - 16s - loss: 1.2992 - accuracy: 0.4783 - val_loss: 0.9497 - val_accuracy: 0.6301 - 16s/epoch - 711ms/step
# Epoch 117/300
# 22/22 - 15s - loss: 1.2786 - accuracy: 0.5058 - val_loss: 1.0328 - val_accuracy: 0.6438 - 15s/epoch - 661ms/step
# Epoch 118/300
# 22/22 - 14s - loss: 1.2929 - accuracy: 0.4827 - val_loss: 0.9440 - val_accuracy: 0.6849 - 14s/epoch - 656ms/step
# Epoch 119/300
# 22/22 - 15s - loss: 1.2354 - accuracy: 0.4913 - val_loss: 0.9427 - val_accuracy: 0.6986 - 15s/epoch - 660ms/step
# Epoch 120/300
# 22/22 - 15s - loss: 1.2984 - accuracy: 0.4740 - val_loss: 0.9782 - val_accuracy: 0.6164 - 15s/epoch - 670ms/step
# Epoch 121/300
# 22/22 - 15s - loss: 1.2368 - accuracy: 0.4942 - val_loss: 0.9992 - val_accuracy: 0.6575 - 15s/epoch - 659ms/step
# Epoch 122/300
# 22/22 - 14s - loss: 1.2734 - accuracy: 0.4827 - val_loss: 0.9735 - val_accuracy: 0.6849 - 14s/epoch - 659ms/step
# Epoch 123/300
# 22/22 - 14s - loss: 1.2843 - accuracy: 0.4740 - val_loss: 0.9839 - val_accuracy: 0.6164 - 14s/epoch - 657ms/step
# Epoch 124/300
# 22/22 - 14s - loss: 1.2060 - accuracy: 0.5014 - val_loss: 0.9459 - val_accuracy: 0.6164 - 14s/epoch - 658ms/step
# Epoch 125/300
# 22/22 - 14s - loss: 1.2455 - accuracy: 0.5058 - val_loss: 0.9908 - val_accuracy: 0.6027 - 14s/epoch - 655ms/step
# Epoch 126/300
# 22/22 - 14s - loss: 1.2352 - accuracy: 0.4957 - val_loss: 0.9876 - val_accuracy: 0.6575 - 14s/epoch - 658ms/step
# Epoch 127/300
# 22/22 - 14s - loss: 1.2507 - accuracy: 0.4957 - val_loss: 1.0004 - val_accuracy: 0.6301 - 14s/epoch - 658ms/step
# Epoch 128/300
# 22/22 - 15s - loss: 1.2703 - accuracy: 0.4812 - val_loss: 1.0085 - val_accuracy: 0.6164 - 15s/epoch - 667ms/step
# Epoch 129/300
# 22/22 - 14s - loss: 1.2275 - accuracy: 0.5043 - val_loss: 0.9855 - val_accuracy: 0.6438 - 14s/epoch - 657ms/step
# Epoch 130/300
# 22/22 - 15s - loss: 1.2303 - accuracy: 0.5202 - val_loss: 0.9189 - val_accuracy: 0.6164 - 15s/epoch - 659ms/step
# Epoch 131/300
# 22/22 - 15s - loss: 1.2120 - accuracy: 0.4971 - val_loss: 0.9622 - val_accuracy: 0.6164 - 15s/epoch - 677ms/step
# Epoch 132/300
# 22/22 - 15s - loss: 1.2096 - accuracy: 0.5130 - val_loss: 0.9528 - val_accuracy: 0.6849 - 15s/epoch - 690ms/step
# Epoch 133/300
# 22/22 - 15s - loss: 1.2203 - accuracy: 0.4928 - val_loss: 0.9557 - val_accuracy: 0.6575 - 15s/epoch - 691ms/step
# Epoch 134/300
# 22/22 - 15s - loss: 1.2260 - accuracy: 0.4812 - val_loss: 1.0508 - val_accuracy: 0.5753 - 15s/epoch - 684ms/step
# Epoch 135/300
# 22/22 - 15s - loss: 1.3125 - accuracy: 0.4682 - val_loss: 0.9760 - val_accuracy: 0.6849 - 15s/epoch - 693ms/step
# Epoch 136/300
# 22/22 - 15s - loss: 1.2257 - accuracy: 0.5029 - val_loss: 1.0322 - val_accuracy: 0.6849 - 15s/epoch - 670ms/step
# Epoch 137/300
# 22/22 - 15s - loss: 1.2680 - accuracy: 0.4754 - val_loss: 0.9995 - val_accuracy: 0.6301 - 15s/epoch - 678ms/step
# Epoch 138/300
# 22/22 - 15s - loss: 1.2319 - accuracy: 0.5014 - val_loss: 0.9863 - val_accuracy: 0.6712 - 15s/epoch - 671ms/step
# Epoch 139/300
# 22/22 - 15s - loss: 1.2505 - accuracy: 0.4754 - val_loss: 1.0166 - val_accuracy: 0.6438 - 15s/epoch - 669ms/step
# Epoch 140/300
# 22/22 - 15s - loss: 1.2769 - accuracy: 0.4957 - val_loss: 0.9908 - val_accuracy: 0.6575 - 15s/epoch - 667ms/step
# Epoch 141/300
# 22/22 - 15s - loss: 1.1905 - accuracy: 0.5043 - val_loss: 1.0561 - val_accuracy: 0.6301 - 15s/epoch - 666ms/step
# Epoch 142/300
# 22/22 - 15s - loss: 1.2235 - accuracy: 0.5058 - val_loss: 0.9949 - val_accuracy: 0.6712 - 15s/epoch - 672ms/step
# Epoch 143/300
# 22/22 - 15s - loss: 1.2474 - accuracy: 0.4913 - val_loss: 1.0024 - val_accuracy: 0.6575 - 15s/epoch - 678ms/step
# Epoch 144/300
# 22/22 - 15s - loss: 1.1818 - accuracy: 0.5072 - val_loss: 0.9620 - val_accuracy: 0.6575 - 15s/epoch - 665ms/step
# Epoch 145/300
# 22/22 - 15s - loss: 1.1812 - accuracy: 0.5332 - val_loss: 0.9592 - val_accuracy: 0.6438 - 15s/epoch - 670ms/step
# Epoch 146/300
# 22/22 - 15s - loss: 1.2018 - accuracy: 0.4913 - val_loss: 0.9982 - val_accuracy: 0.6575 - 15s/epoch - 672ms/step
# Epoch 147/300
# 22/22 - 15s - loss: 1.2342 - accuracy: 0.5000 - val_loss: 1.0241 - val_accuracy: 0.6712 - 15s/epoch - 670ms/step
# Epoch 148/300
# 22/22 - 15s - loss: 1.2295 - accuracy: 0.5101 - val_loss: 1.0020 - val_accuracy: 0.6849 - 15s/epoch - 669ms/step
# Epoch 149/300
# 22/22 - 15s - loss: 1.1543 - accuracy: 0.5058 - val_loss: 0.9522 - val_accuracy: 0.6849 - 15s/epoch - 674ms/step
# Epoch 150/300
# 22/22 - 15s - loss: 1.1921 - accuracy: 0.5145 - val_loss: 0.9816 - val_accuracy: 0.6849 - 15s/epoch - 671ms/step
# Epoch 151/300
# 22/22 - 15s - loss: 1.2132 - accuracy: 0.4942 - val_loss: 0.9732 - val_accuracy: 0.6986 - 15s/epoch - 672ms/step
# Epoch 152/300
# 22/22 - 15s - loss: 1.1384 - accuracy: 0.5419 - val_loss: 0.9544 - val_accuracy: 0.6712 - 15s/epoch - 671ms/step
# Epoch 153/300
# 22/22 - 15s - loss: 1.2831 - accuracy: 0.4740 - val_loss: 0.9412 - val_accuracy: 0.6986 - 15s/epoch - 684ms/step
# Epoch 154/300
# 22/22 - 15s - loss: 1.2350 - accuracy: 0.4899 - val_loss: 0.9423 - val_accuracy: 0.6849 - 15s/epoch - 675ms/step
# Epoch 155/300
# 22/22 - 15s - loss: 1.2717 - accuracy: 0.4711 - val_loss: 0.9538 - val_accuracy: 0.7123 - 15s/epoch - 673ms/step
# Epoch 156/300
# 22/22 - 15s - loss: 1.2055 - accuracy: 0.5072 - val_loss: 0.9300 - val_accuracy: 0.7260 - 15s/epoch - 673ms/step
# Epoch 157/300
# 22/22 - 16s - loss: 1.1730 - accuracy: 0.5000 - val_loss: 0.9340 - val_accuracy: 0.7671 - 16s/epoch - 710ms/step
# Epoch 158/300
# 22/22 - 16s - loss: 1.1824 - accuracy: 0.4783 - val_loss: 0.9383 - val_accuracy: 0.6986 - 16s/epoch - 713ms/step
# Epoch 159/300
# 22/22 - 15s - loss: 1.0926 - accuracy: 0.5405 - val_loss: 0.9706 - val_accuracy: 0.6849 - 15s/epoch - 703ms/step
# Epoch 160/300
# 22/22 - 15s - loss: 1.2401 - accuracy: 0.5014 - val_loss: 0.9650 - val_accuracy: 0.7123 - 15s/epoch - 703ms/step
# Epoch 161/300
# 22/22 - 16s - loss: 1.1851 - accuracy: 0.5087 - val_loss: 0.9994 - val_accuracy: 0.6712 - 16s/epoch - 718ms/step
# Epoch 162/300
# 22/22 - 16s - loss: 1.2428 - accuracy: 0.4812 - val_loss: 0.9953 - val_accuracy: 0.6849 - 16s/epoch - 709ms/step
# Epoch 163/300
# 22/22 - 15s - loss: 1.2214 - accuracy: 0.5029 - val_loss: 0.9436 - val_accuracy: 0.7123 - 15s/epoch - 686ms/step
# Epoch 164/300
# 22/22 - 15s - loss: 1.1786 - accuracy: 0.5217 - val_loss: 0.9275 - val_accuracy: 0.7260 - 15s/epoch - 679ms/step
# Epoch 165/300
# 22/22 - 15s - loss: 1.2373 - accuracy: 0.4682 - val_loss: 0.9688 - val_accuracy: 0.6849 - 15s/epoch - 690ms/step
# Epoch 166/300
# 22/22 - 16s - loss: 1.1445 - accuracy: 0.5101 - val_loss: 0.9448 - val_accuracy: 0.6712 - 16s/epoch - 715ms/step
# Epoch 167/300
# 22/22 - 16s - loss: 1.2240 - accuracy: 0.4754 - val_loss: 0.9989 - val_accuracy: 0.6712 - 16s/epoch - 719ms/step
# Epoch 168/300
# 22/22 - 16s - loss: 1.1939 - accuracy: 0.5058 - val_loss: 0.9380 - val_accuracy: 0.7123 - 16s/epoch - 708ms/step
# Epoch 169/300
# 22/22 - 15s - loss: 1.2297 - accuracy: 0.4971 - val_loss: 0.9945 - val_accuracy: 0.6849 - 15s/epoch - 695ms/step
# Epoch 170/300
# 22/22 - 15s - loss: 1.1851 - accuracy: 0.5000 - val_loss: 0.9674 - val_accuracy: 0.7260 - 15s/epoch - 690ms/step
# Epoch 171/300
# 22/22 - 15s - loss: 1.1655 - accuracy: 0.5116 - val_loss: 0.9212 - val_accuracy: 0.7123 - 15s/epoch - 690ms/step
# Epoch 172/300
# 22/22 - 15s - loss: 1.1389 - accuracy: 0.5246 - val_loss: 0.9435 - val_accuracy: 0.6986 - 15s/epoch - 694ms/step
# Epoch 173/300
# 22/22 - 15s - loss: 1.1827 - accuracy: 0.4870 - val_loss: 0.8922 - val_accuracy: 0.7397 - 15s/epoch - 674ms/step
# Epoch 174/300
# 22/22 - 15s - loss: 1.1153 - accuracy: 0.5159 - val_loss: 0.9133 - val_accuracy: 0.6986 - 15s/epoch - 680ms/step
# Epoch 175/300
# 22/22 - 15s - loss: 1.1719 - accuracy: 0.5303 - val_loss: 0.9094 - val_accuracy: 0.7123 - 15s/epoch - 679ms/step
# Epoch 176/300
# 22/22 - 15s - loss: 1.2009 - accuracy: 0.5000 - val_loss: 0.9642 - val_accuracy: 0.6712 - 15s/epoch - 676ms/step
# Epoch 177/300
# 22/22 - 15s - loss: 1.1380 - accuracy: 0.5173 - val_loss: 0.9736 - val_accuracy: 0.6849 - 15s/epoch - 677ms/step
# Epoch 178/300
# 22/22 - 15s - loss: 1.1792 - accuracy: 0.4913 - val_loss: 0.9420 - val_accuracy: 0.7123 - 15s/epoch - 675ms/step
# Epoch 179/300
# 22/22 - 15s - loss: 1.2082 - accuracy: 0.4942 - val_loss: 0.9650 - val_accuracy: 0.6986 - 15s/epoch - 674ms/step
# Epoch 180/300
# 22/22 - 15s - loss: 1.1312 - accuracy: 0.5332 - val_loss: 0.9064 - val_accuracy: 0.7534 - 15s/epoch - 675ms/step
# Epoch 181/300
# 22/22 - 15s - loss: 1.1689 - accuracy: 0.5101 - val_loss: 0.9496 - val_accuracy: 0.6849 - 15s/epoch - 676ms/step
# Epoch 182/300
# 22/22 - 15s - loss: 1.1859 - accuracy: 0.4913 - val_loss: 0.9621 - val_accuracy: 0.6986 - 15s/epoch - 673ms/step
# Epoch 183/300
# 22/22 - 15s - loss: 1.1778 - accuracy: 0.5188 - val_loss: 0.9841 - val_accuracy: 0.7260 - 15s/epoch - 675ms/step
# Epoch 184/300
# 22/22 - 15s - loss: 1.2012 - accuracy: 0.4725 - val_loss: 0.9749 - val_accuracy: 0.7123 - 15s/epoch - 677ms/step
# Epoch 185/300
# 22/22 - 15s - loss: 1.1499 - accuracy: 0.4971 - val_loss: 0.9758 - val_accuracy: 0.7260 - 15s/epoch - 672ms/step
# Epoch 186/300
# 22/22 - 15s - loss: 1.1431 - accuracy: 0.5188 - val_loss: 0.9577 - val_accuracy: 0.6986 - 15s/epoch - 675ms/step
# Epoch 187/300
# 22/22 - 15s - loss: 1.1752 - accuracy: 0.5116 - val_loss: 1.0355 - val_accuracy: 0.6986 - 15s/epoch - 676ms/step
# Epoch 188/300
# 22/22 - 15s - loss: 1.1651 - accuracy: 0.5072 - val_loss: 0.9792 - val_accuracy: 0.7123 - 15s/epoch - 668ms/step
# Epoch 189/300
# 22/22 - 15s - loss: 1.2160 - accuracy: 0.5043 - val_loss: 0.9511 - val_accuracy: 0.7260 - 15s/epoch - 671ms/step
# Epoch 190/300
# 22/22 - 15s - loss: 1.1570 - accuracy: 0.5173 - val_loss: 0.9616 - val_accuracy: 0.7397 - 15s/epoch - 677ms/step
# Epoch 191/300
# 22/22 - 15s - loss: 1.1484 - accuracy: 0.5014 - val_loss: 0.9468 - val_accuracy: 0.7123 - 15s/epoch - 676ms/step
# Epoch 192/300
# 22/22 - 15s - loss: 1.1751 - accuracy: 0.5000 - val_loss: 0.9465 - val_accuracy: 0.6712 - 15s/epoch - 673ms/step
# Epoch 193/300
# 22/22 - 15s - loss: 1.1584 - accuracy: 0.5159 - val_loss: 0.9383 - val_accuracy: 0.6849 - 15s/epoch - 673ms/step
# Epoch 194/300
# 22/22 - 15s - loss: 1.1493 - accuracy: 0.5202 - val_loss: 1.0367 - val_accuracy: 0.6986 - 15s/epoch - 675ms/step
# Epoch 195/300
# 22/22 - 15s - loss: 1.1592 - accuracy: 0.5087 - val_loss: 1.0145 - val_accuracy: 0.6849 - 15s/epoch - 673ms/step
# Epoch 196/300
# 22/22 - 15s - loss: 1.1158 - accuracy: 0.5405 - val_loss: 0.9948 - val_accuracy: 0.6986 - 15s/epoch - 676ms/step
# Epoch 197/300
# 22/22 - 15s - loss: 1.1570 - accuracy: 0.5101 - val_loss: 0.9323 - val_accuracy: 0.6849 - 15s/epoch - 673ms/step
# Epoch 198/300
# 22/22 - 15s - loss: 1.2216 - accuracy: 0.4769 - val_loss: 0.9995 - val_accuracy: 0.6301 - 15s/epoch - 676ms/step
# Epoch 199/300
# 22/22 - 15s - loss: 1.0604 - accuracy: 0.5564 - val_loss: 0.9429 - val_accuracy: 0.6849 - 15s/epoch - 674ms/step
# Epoch 200/300
# 22/22 - 15s - loss: 1.1474 - accuracy: 0.5058 - val_loss: 0.9169 - val_accuracy: 0.7123 - 15s/epoch - 673ms/step
# Epoch 201/300
# 22/22 - 15s - loss: 1.1202 - accuracy: 0.5116 - val_loss: 0.9195 - val_accuracy: 0.7260 - 15s/epoch - 672ms/step
# Epoch 202/300
# 22/22 - 15s - loss: 1.1990 - accuracy: 0.4899 - val_loss: 0.9183 - val_accuracy: 0.6986 - 15s/epoch - 672ms/step
# Epoch 203/300
# 22/22 - 15s - loss: 1.1254 - accuracy: 0.5347 - val_loss: 0.9101 - val_accuracy: 0.6712 - 15s/epoch - 671ms/step
# Epoch 204/300
# 22/22 - 15s - loss: 1.0914 - accuracy: 0.5621 - val_loss: 0.8746 - val_accuracy: 0.7260 - 15s/epoch - 671ms/step
# Epoch 205/300
# 22/22 - 15s - loss: 1.1664 - accuracy: 0.5202 - val_loss: 0.9290 - val_accuracy: 0.7123 - 15s/epoch - 673ms/step
# Epoch 206/300
# 22/22 - 15s - loss: 1.1986 - accuracy: 0.4957 - val_loss: 0.9711 - val_accuracy: 0.6575 - 15s/epoch - 676ms/step
# Epoch 207/300
# 22/22 - 15s - loss: 1.2018 - accuracy: 0.4812 - val_loss: 0.8990 - val_accuracy: 0.7260 - 15s/epoch - 674ms/step
# Epoch 208/300
# 22/22 - 15s - loss: 1.1068 - accuracy: 0.5275 - val_loss: 0.9407 - val_accuracy: 0.7260 - 15s/epoch - 674ms/step
# Epoch 209/300
# 22/22 - 15s - loss: 1.1884 - accuracy: 0.5043 - val_loss: 1.0239 - val_accuracy: 0.6849 - 15s/epoch - 671ms/step
# Epoch 210/300
# 22/22 - 15s - loss: 1.1526 - accuracy: 0.5231 - val_loss: 1.0197 - val_accuracy: 0.6438 - 15s/epoch - 675ms/step
# Epoch 211/300
# 22/22 - 15s - loss: 1.1684 - accuracy: 0.5246 - val_loss: 0.9745 - val_accuracy: 0.6712 - 15s/epoch - 673ms/step
# Epoch 212/300
# 22/22 - 15s - loss: 1.2377 - accuracy: 0.4769 - val_loss: 0.9656 - val_accuracy: 0.7260 - 15s/epoch - 673ms/step
# Epoch 213/300
# 22/22 - 15s - loss: 1.1560 - accuracy: 0.5072 - val_loss: 0.9291 - val_accuracy: 0.6986 - 15s/epoch - 672ms/step
# Epoch 214/300
# 22/22 - 15s - loss: 1.0713 - accuracy: 0.5636 - val_loss: 0.9420 - val_accuracy: 0.7260 - 15s/epoch - 673ms/step
# Epoch 215/300
# 22/22 - 15s - loss: 1.1917 - accuracy: 0.5014 - val_loss: 0.9360 - val_accuracy: 0.7260 - 15s/epoch - 697ms/step
# Epoch 216/300
# 22/22 - 15s - loss: 1.1079 - accuracy: 0.5332 - val_loss: 0.8907 - val_accuracy: 0.6986 - 15s/epoch - 695ms/step
# Epoch 217/300
# 22/22 - 15s - loss: 1.1353 - accuracy: 0.5231 - val_loss: 0.9239 - val_accuracy: 0.7260 - 15s/epoch - 702ms/step
# Epoch 218/300
# 22/22 - 15s - loss: 1.1583 - accuracy: 0.5202 - val_loss: 0.9595 - val_accuracy: 0.7397 - 15s/epoch - 688ms/step
# Epoch 219/300
# 22/22 - 15s - loss: 1.1397 - accuracy: 0.5145 - val_loss: 0.9088 - val_accuracy: 0.7534 - 15s/epoch - 693ms/step
# Epoch 220/300
# 22/22 - 15s - loss: 1.1375 - accuracy: 0.5159 - val_loss: 0.9626 - val_accuracy: 0.7534 - 15s/epoch - 689ms/step
# Epoch 221/300
# 22/22 - 15s - loss: 1.0968 - accuracy: 0.5477 - val_loss: 0.9291 - val_accuracy: 0.7808 - 15s/epoch - 699ms/step
# Epoch 222/300
# 22/22 - 15s - loss: 1.1307 - accuracy: 0.5260 - val_loss: 0.9267 - val_accuracy: 0.7534 - 15s/epoch - 693ms/step
# Epoch 223/300
# 22/22 - 15s - loss: 1.1475 - accuracy: 0.5246 - val_loss: 0.9430 - val_accuracy: 0.7397 - 15s/epoch - 688ms/step
# Epoch 224/300
# 22/22 - 15s - loss: 1.0661 - accuracy: 0.5448 - val_loss: 0.9568 - val_accuracy: 0.7123 - 15s/epoch - 688ms/step
# Epoch 225/300
# 22/22 - 15s - loss: 1.1092 - accuracy: 0.5477 - val_loss: 0.9483 - val_accuracy: 0.7397 - 15s/epoch - 702ms/step
# Epoch 226/300
# 22/22 - 15s - loss: 1.1812 - accuracy: 0.4827 - val_loss: 0.9155 - val_accuracy: 0.7808 - 15s/epoch - 695ms/step
# Epoch 227/300
# 22/22 - 15s - loss: 1.1019 - accuracy: 0.5303 - val_loss: 0.9209 - val_accuracy: 0.7534 - 15s/epoch - 684ms/step
# Epoch 228/300
# 22/22 - 15s - loss: 1.1676 - accuracy: 0.5130 - val_loss: 0.9555 - val_accuracy: 0.7534 - 15s/epoch - 683ms/step
# Epoch 229/300
# 22/22 - 15s - loss: 1.1199 - accuracy: 0.5303 - val_loss: 0.9350 - val_accuracy: 0.7671 - 15s/epoch - 680ms/step
# Epoch 230/300
# 22/22 - 16s - loss: 1.1297 - accuracy: 0.5231 - val_loss: 0.9073 - val_accuracy: 0.7671 - 16s/epoch - 706ms/step
# Epoch 231/300
# 22/22 - 15s - loss: 1.1174 - accuracy: 0.5318 - val_loss: 0.9539 - val_accuracy: 0.7397 - 15s/epoch - 691ms/step
# Epoch 232/300
# 22/22 - 15s - loss: 1.1549 - accuracy: 0.5361 - val_loss: 1.0333 - val_accuracy: 0.6849 - 15s/epoch - 683ms/step
# Epoch 233/300
# 22/22 - 15s - loss: 1.1500 - accuracy: 0.5188 - val_loss: 0.9634 - val_accuracy: 0.7534 - 15s/epoch - 681ms/step
# Epoch 234/300
# 22/22 - 15s - loss: 1.1584 - accuracy: 0.5202 - val_loss: 1.0402 - val_accuracy: 0.7123 - 15s/epoch - 674ms/step
# Epoch 235/300
# 22/22 - 15s - loss: 1.1123 - accuracy: 0.5390 - val_loss: 0.9935 - val_accuracy: 0.7123 - 15s/epoch - 685ms/step
# Epoch 236/300
# 22/22 - 15s - loss: 1.1319 - accuracy: 0.5347 - val_loss: 0.9531 - val_accuracy: 0.6712 - 15s/epoch - 687ms/step
# Epoch 237/300
# 22/22 - 15s - loss: 1.1230 - accuracy: 0.5260 - val_loss: 1.0093 - val_accuracy: 0.6849 - 15s/epoch - 688ms/step
# Epoch 238/300
# 22/22 - 15s - loss: 1.0809 - accuracy: 0.5419 - val_loss: 0.8947 - val_accuracy: 0.7260 - 15s/epoch - 682ms/step
# Epoch 239/300
# 22/22 - 15s - loss: 1.0954 - accuracy: 0.5477 - val_loss: 0.9826 - val_accuracy: 0.6575 - 15s/epoch - 686ms/step
# Epoch 240/300
# 22/22 - 15s - loss: 1.1474 - accuracy: 0.5159 - val_loss: 0.9155 - val_accuracy: 0.7397 - 15s/epoch - 677ms/step
# Epoch 241/300
# 22/22 - 15s - loss: 1.1268 - accuracy: 0.5289 - val_loss: 0.9204 - val_accuracy: 0.6849 - 15s/epoch - 677ms/step
# Epoch 242/300
# 22/22 - 15s - loss: 1.1212 - accuracy: 0.5275 - val_loss: 0.9823 - val_accuracy: 0.6712 - 15s/epoch - 694ms/step
# Epoch 243/300
# 22/22 - 15s - loss: 1.1699 - accuracy: 0.5043 - val_loss: 0.9643 - val_accuracy: 0.6575 - 15s/epoch - 683ms/step
# Epoch 244/300
# 22/22 - 15s - loss: 1.0975 - accuracy: 0.5390 - val_loss: 1.0041 - val_accuracy: 0.6575 - 15s/epoch - 673ms/step
# Epoch 245/300
# 22/22 - 15s - loss: 1.1382 - accuracy: 0.5202 - val_loss: 1.0237 - val_accuracy: 0.6301 - 15s/epoch - 672ms/step
# Epoch 246/300
# 22/22 - 15s - loss: 1.1196 - accuracy: 0.5303 - val_loss: 0.9899 - val_accuracy: 0.6575 - 15s/epoch - 669ms/step
# Epoch 247/300
# 22/22 - 15s - loss: 1.1109 - accuracy: 0.5434 - val_loss: 0.9740 - val_accuracy: 0.7123 - 15s/epoch - 664ms/step
# Epoch 248/300
# 22/22 - 15s - loss: 1.1300 - accuracy: 0.5116 - val_loss: 0.9583 - val_accuracy: 0.7123 - 15s/epoch - 670ms/step
# Epoch 249/300
# 22/22 - 15s - loss: 1.1380 - accuracy: 0.5173 - val_loss: 0.9781 - val_accuracy: 0.6712 - 15s/epoch - 672ms/step
# Epoch 250/300
# 22/22 - 15s - loss: 1.1638 - accuracy: 0.5303 - val_loss: 0.9502 - val_accuracy: 0.6986 - 15s/epoch - 666ms/step
# Epoch 251/300
# 22/22 - 15s - loss: 1.1028 - accuracy: 0.5405 - val_loss: 0.9099 - val_accuracy: 0.6849 - 15s/epoch - 666ms/step
# Epoch 252/300
# 22/22 - 15s - loss: 1.1265 - accuracy: 0.5520 - val_loss: 0.9699 - val_accuracy: 0.6849 - 15s/epoch - 670ms/step
# Epoch 253/300
# 22/22 - 15s - loss: 1.1150 - accuracy: 0.5405 - val_loss: 1.0082 - val_accuracy: 0.6575 - 15s/epoch - 665ms/step
# Epoch 254/300
# 22/22 - 15s - loss: 1.1224 - accuracy: 0.5275 - val_loss: 1.0027 - val_accuracy: 0.6849 - 15s/epoch - 671ms/step
# Epoch 255/300
# 22/22 - 15s - loss: 1.0989 - accuracy: 0.5520 - val_loss: 0.9687 - val_accuracy: 0.7123 - 15s/epoch - 672ms/step
# Epoch 256/300
# 22/22 - 15s - loss: 1.0967 - accuracy: 0.5477 - val_loss: 1.0416 - val_accuracy: 0.6301 - 15s/epoch - 669ms/step
# Epoch 257/300
# 22/22 - 15s - loss: 1.1543 - accuracy: 0.4855 - val_loss: 0.9676 - val_accuracy: 0.6849 - 15s/epoch - 671ms/step
# Epoch 258/300
# 22/22 - 15s - loss: 1.0878 - accuracy: 0.5520 - val_loss: 0.9611 - val_accuracy: 0.6849 - 15s/epoch - 671ms/step
# Epoch 259/300
# 22/22 - 15s - loss: 1.1061 - accuracy: 0.5116 - val_loss: 0.9121 - val_accuracy: 0.7123 - 15s/epoch - 664ms/step
# Epoch 260/300
# 22/22 - 15s - loss: 1.0612 - accuracy: 0.5665 - val_loss: 0.9684 - val_accuracy: 0.7534 - 15s/epoch - 674ms/step
# Epoch 261/300
# 22/22 - 15s - loss: 1.1579 - accuracy: 0.5101 - val_loss: 0.9724 - val_accuracy: 0.6849 - 15s/epoch - 675ms/step
# Epoch 262/300
# 22/22 - 15s - loss: 1.0835 - accuracy: 0.5621 - val_loss: 0.9736 - val_accuracy: 0.6849 - 15s/epoch - 676ms/step
# Epoch 263/300
# 22/22 - 15s - loss: 1.0886 - accuracy: 0.5347 - val_loss: 0.8901 - val_accuracy: 0.7534 - 15s/epoch - 670ms/step
# Epoch 264/300
# 22/22 - 15s - loss: 1.1676 - accuracy: 0.4986 - val_loss: 0.9043 - val_accuracy: 0.6849 - 15s/epoch - 665ms/step
# Epoch 265/300
# 22/22 - 15s - loss: 1.1170 - accuracy: 0.5376 - val_loss: 0.9524 - val_accuracy: 0.6849 - 15s/epoch - 664ms/step
# Epoch 266/300
# 22/22 - 15s - loss: 1.1253 - accuracy: 0.5217 - val_loss: 0.9487 - val_accuracy: 0.6849 - 15s/epoch - 671ms/step
# Epoch 267/300
# 22/22 - 15s - loss: 1.1046 - accuracy: 0.5405 - val_loss: 1.0122 - val_accuracy: 0.6986 - 15s/epoch - 679ms/step
# Epoch 268/300
# 22/22 - 15s - loss: 1.0670 - accuracy: 0.5520 - val_loss: 0.8959 - val_accuracy: 0.7534 - 15s/epoch - 667ms/step
# Epoch 269/300
# 22/22 - 15s - loss: 1.1023 - accuracy: 0.5520 - val_loss: 0.9744 - val_accuracy: 0.7260 - 15s/epoch - 671ms/step
# Epoch 270/300
# 22/22 - 15s - loss: 1.1018 - accuracy: 0.5448 - val_loss: 0.9747 - val_accuracy: 0.6849 - 15s/epoch - 674ms/step
# Epoch 271/300
# 22/22 - 15s - loss: 1.1421 - accuracy: 0.5303 - val_loss: 0.9905 - val_accuracy: 0.6712 - 15s/epoch - 666ms/step
# Epoch 272/300
# 22/22 - 15s - loss: 1.1584 - accuracy: 0.5043 - val_loss: 0.9278 - val_accuracy: 0.6849 - 15s/epoch - 673ms/step
# Epoch 273/300
# 22/22 - 15s - loss: 1.0925 - accuracy: 0.5477 - val_loss: 1.0159 - val_accuracy: 0.6712 - 15s/epoch - 673ms/step
# Epoch 274/300
# 22/22 - 15s - loss: 1.1175 - accuracy: 0.5159 - val_loss: 0.9530 - val_accuracy: 0.7123 - 15s/epoch - 666ms/step
# Epoch 275/300
# 22/22 - 15s - loss: 1.0665 - accuracy: 0.5564 - val_loss: 0.9515 - val_accuracy: 0.6849 - 15s/epoch - 664ms/step
# Epoch 276/300
# 22/22 - 15s - loss: 1.1329 - accuracy: 0.5202 - val_loss: 0.9894 - val_accuracy: 0.6301 - 15s/epoch - 671ms/step
# Epoch 277/300
# 22/22 - 15s - loss: 1.0901 - accuracy: 0.5448 - val_loss: 0.9893 - val_accuracy: 0.7260 - 15s/epoch - 670ms/step
# Epoch 278/300
# 22/22 - 15s - loss: 1.1752 - accuracy: 0.5217 - val_loss: 0.9878 - val_accuracy: 0.6986 - 15s/epoch - 669ms/step
# Epoch 279/300
# 22/22 - 15s - loss: 1.0838 - accuracy: 0.5506 - val_loss: 1.0253 - val_accuracy: 0.6849 - 15s/epoch - 671ms/step
# Epoch 280/300
# 22/22 - 15s - loss: 1.0860 - accuracy: 0.5564 - val_loss: 0.9378 - val_accuracy: 0.7260 - 15s/epoch - 673ms/step
# Epoch 281/300
# 22/22 - 15s - loss: 1.1148 - accuracy: 0.5260 - val_loss: 1.0197 - val_accuracy: 0.6986 - 15s/epoch - 668ms/step
# Epoch 282/300
# 22/22 - 15s - loss: 1.1283 - accuracy: 0.5332 - val_loss: 1.0925 - val_accuracy: 0.6438 - 15s/epoch - 672ms/step
# Epoch 283/300
# 22/22 - 15s - loss: 1.1123 - accuracy: 0.5217 - val_loss: 1.0769 - val_accuracy: 0.6712 - 15s/epoch - 667ms/step
# Epoch 284/300
# 22/22 - 15s - loss: 1.1137 - accuracy: 0.5202 - val_loss: 1.0061 - val_accuracy: 0.7260 - 15s/epoch - 673ms/step
# Epoch 285/300
# 22/22 - 15s - loss: 1.1378 - accuracy: 0.5173 - val_loss: 1.0158 - val_accuracy: 0.7260 - 15s/epoch - 670ms/step
# Epoch 286/300
# 22/22 - 15s - loss: 1.0380 - accuracy: 0.5723 - val_loss: 1.0165 - val_accuracy: 0.7397 - 15s/epoch - 672ms/step
# Epoch 287/300
# 22/22 - 15s - loss: 1.1185 - accuracy: 0.5275 - val_loss: 1.0102 - val_accuracy: 0.7260 - 15s/epoch - 667ms/step
# Epoch 288/300
# 22/22 - 15s - loss: 1.0677 - accuracy: 0.5535 - val_loss: 1.0326 - val_accuracy: 0.7260 - 15s/epoch - 674ms/step
# Epoch 289/300
# 22/22 - 15s - loss: 1.1487 - accuracy: 0.5145 - val_loss: 0.9822 - val_accuracy: 0.7123 - 15s/epoch - 671ms/step
# Epoch 290/300
# 22/22 - 15s - loss: 1.0771 - accuracy: 0.5506 - val_loss: 1.0422 - val_accuracy: 0.7260 - 15s/epoch - 674ms/step
# Epoch 291/300
# 22/22 - 15s - loss: 1.1154 - accuracy: 0.5275 - val_loss: 0.9377 - val_accuracy: 0.7260 - 15s/epoch - 673ms/step
# Epoch 292/300
# 22/22 - 15s - loss: 1.1364 - accuracy: 0.5347 - val_loss: 0.9766 - val_accuracy: 0.6986 - 15s/epoch - 674ms/step
# Epoch 293/300
# 22/22 - 15s - loss: 1.1008 - accuracy: 0.5520 - val_loss: 0.9838 - val_accuracy: 0.7397 - 15s/epoch - 668ms/step
# Epoch 294/300
# 22/22 - 15s - loss: 1.1233 - accuracy: 0.5506 - val_loss: 0.9274 - val_accuracy: 0.6712 - 15s/epoch - 671ms/step
# Epoch 295/300
# 22/22 - 15s - loss: 1.0838 - accuracy: 0.5361 - val_loss: 0.9219 - val_accuracy: 0.7397 - 15s/epoch - 667ms/step
# Epoch 296/300
# 22/22 - 15s - loss: 1.1301 - accuracy: 0.5390 - val_loss: 0.9762 - val_accuracy: 0.6849 - 15s/epoch - 676ms/step
# Epoch 297/300
# 22/22 - 15s - loss: 1.0483 - accuracy: 0.5795 - val_loss: 0.9837 - val_accuracy: 0.7397 - 15s/epoch - 669ms/step
# Epoch 298/300
# 22/22 - 15s - loss: 1.0448 - accuracy: 0.5751 - val_loss: 0.9718 - val_accuracy: 0.6712 - 15s/epoch - 674ms/step
# Epoch 299/300
# 22/22 - 15s - loss: 1.1018 - accuracy: 0.5332 - val_loss: 1.0023 - val_accuracy: 0.6575 - 15s/epoch - 669ms/step
# Epoch 300/300
# 22/22 - 15s - loss: 1.0606 - accuracy: 0.5650 - val_loss: 1.0301 - val_accuracy: 0.7260 - 15s/epoch - 669ms/step

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# OPTIONAL: Decide if best weights should be loaded from previous model based on val_acc
# The model weights (that are considered the best) are loaded into the model.
result = model.load_weights(checkpoint_filepath)

# %% [markdown]
# <h3>Evaluate Test data</h3>

# %%
print(sum(cb.logs) / 150)

testLoss, testAcc = model.evaluate(test)
print('''
Test Loss: {}
Test Accuracy: {}
'''.format(testLoss, testAcc))
# Out:
# 30.021666225333295
# 3/3 [==============================] - 12s 5s/step - loss: 0.9468 - accuracy: 0.6854
#
# Test Loss: 0.9467871189117432
# Test Accuracy: 0.6853932738304138

# %% [markdown]
# <h4>*Optional - Fine tune model with two-step training*</h4>

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

mobile.trainable = True

for layer in mobile.layers[:-2]:
    layer.trainable = False
    
#re-train the model at a very low learning rate
model.compile(optimizer=Adam(learning_rate=0.00006), loss='categorical_crossentropy', metrics=['accuracy'])

result = model.fit(x=train, validation_data=validation, epochs=100, verbose=2, callbacks=[cb, es])
# Out:
# Epoch 1/100
# 22/22 - 17s - loss: 1.1058 - accuracy: 0.5289 - val_loss: 0.9300 - val_accuracy: 0.7808 - 17s/epoch - 788ms/step
# Epoch 2/100
# 22/22 - 17s - loss: 1.1250 - accuracy: 0.5101 - val_loss: 0.9299 - val_accuracy: 0.7808 - 17s/epoch - 750ms/step
# Epoch 3/100
# 22/22 - 17s - loss: 1.1382 - accuracy: 0.5202 - val_loss: 0.9305 - val_accuracy: 0.7808 - 17s/epoch - 751ms/step
# Epoch 4/100
# 22/22 - 17s - loss: 1.0288 - accuracy: 0.5621 - val_loss: 0.9306 - val_accuracy: 0.7808 - 17s/epoch - 753ms/step
# Epoch 5/100
# 22/22 - 17s - loss: 1.0788 - accuracy: 0.5477 - val_loss: 0.9310 - val_accuracy: 0.7808 - 17s/epoch - 752ms/step
# Epoch 6/100
# 22/22 - 17s - loss: 1.1268 - accuracy: 0.5318 - val_loss: 0.9308 - val_accuracy: 0.7808 - 17s/epoch - 751ms/step
# Epoch 7/100
# 22/22 - 17s - loss: 1.1069 - accuracy: 0.5260 - val_loss: 0.9311 - val_accuracy: 0.7808 - 17s/epoch - 755ms/step
# Epoch 8/100
# 22/22 - 17s - loss: 1.0858 - accuracy: 0.5462 - val_loss: 0.9308 - val_accuracy: 0.7808 - 17s/epoch - 753ms/step
# Epoch 9/100
# 22/22 - 17s - loss: 1.0925 - accuracy: 0.5405 - val_loss: 0.9308 - val_accuracy: 0.7808 - 17s/epoch - 753ms/step
# Epoch 10/100
# 22/22 - 17s - loss: 1.1200 - accuracy: 0.5116 - val_loss: 0.9310 - val_accuracy: 0.7808 - 17s/epoch - 755ms/step
# Epoch 11/100
# 22/22 - 17s - loss: 1.0974 - accuracy: 0.5275 - val_loss: 0.9307 - val_accuracy: 0.7808 - 17s/epoch - 776ms/step
# Epoch 12/100
# 22/22 - 17s - loss: 1.1229 - accuracy: 0.5289 - val_loss: 0.9319 - val_accuracy: 0.7808 - 17s/epoch - 771ms/step
# Epoch 12: early stopping

# %% [markdown]
# <h3>Accuracy and Loss graph</h3>

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# <h3>Classification report</h3>

# %%
predictions = model.predict(test, verbose=0)
# predictions = predictions.reshape(1,-1)[0]
lst = np.argmax(predictions, axis= 1)

print(classification_report(test.classes, lst, target_names = test.class_indices))
# Out:
#               precision    recall  f1-score   support
#
#     Duracell       0.67      1.00      0.80        14
#    Energizer       0.80      0.86      0.83        14
#     Eveready       0.67      0.20      0.31        10
#        Exell       0.70      0.78      0.74         9
#           GP       0.64      0.75      0.69        12
#         Ikea       1.00      0.67      0.80         9
#       Klarus       0.77      0.91      0.83        11
#    Panasonic       0.29      0.20      0.24        10
#
#     accuracy                           0.70        89
#    macro avg       0.69      0.67      0.65        89
# weighted avg       0.69      0.70      0.67        89

# %% [markdown]
# <h3>Confusion matrix</h3>

# %%
result = confusion_matrix(test.classes, lst)
print(result)

def plot_confusion_matrix(result, classes, cmap=plt.cm.Blues):
    plt.subplots(figsize=(7, 7))
    plt.imshow(result, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

    thresh = result.max() / 2.
    for i, j in itertools.product(range(result.shape[0]), range(result.shape[1])):
        plt.text(j, i, result[i, j],
            horizontalalignment="center",
            color = "white" if result[i, j] > thresh else "black")
        
    #current matplotlib version will cut off top and bottom of the matrix, 
    #hence the manual workaround - remove if matplotlib version does not cut off
    b, t = plt.ylim() # discover bottom and top values
    b += 0.5 # Add 0.5 to bottom
    t -= 0.5 # Subtract 0.5 from top
    plt.ylim(b, t) # update ylim(bottom, top) values
    plt.show()
    
plot_confusion_matrix(result, list(test.class_indices.keys()))
# Out:
# [[14  0  0  0  0  0  0  0]
#  [ 1 12  0  0  0  0  0  1]
#  [ 2  2  2  0  2  0  0  2]
#  [ 2  0  0  7  0  0  0  0]
#  [ 0  0  1  0  9  0  0  2]
#  [ 0  0  0  2  1  6  0  0]
#  [ 1  0  0  0  0  0 10  0]
#  [ 1  1  0  1  2  0  3  2]]

# %% [markdown]
# <h3>Labels of wrong predictions</h3>

# %%
def getErrors(test, predictions):
    #get file names of all images in test data
    names = test.filenames

    #get IDs of all classes
    allClassesID = test.classes

    #get dictionary of classes and respective ID
    classLabelDict = test.class_indices
    
    #list of the names of all classes
    classLabels = list(classLabelDict.keys())

    print("The list of classes: ", classLabels)

    #get the most predicted class
    predictedClasses = np.argmax(predictions, axis=1)

    predictedErrors = np.where(predictedClasses != allClassesID)[0]

    print("Number of errors = {}/{}".format(len(predictedErrors),test.samples))

    return classLabels, predictedErrors, names

def showErrors(classLabels, predictedErrors, predictions, names):
    # Show the errors
    for i in range(len(errors)):
        predictedClass = np.argmax(predictions[predictedErrors[i]])

        predictedLabel = classLabels[predictedClass]

        title = 'Original Picture : {}, Prediction : {}, Confidence/Percentage : {:.3f}'.format\
                (names[predictedErrors[i]].split('/')[0],predictedLabel, predictions[errors[i]][predictedClass])
        print(title)

# %%
#get the list of class labels, prediction errors and file names
labels, errors, names = getErrors(test, predictions)

#show wrongly predicted images, prediction and and the percentage (confidence)
showErrors(labels, errors, predictions, names)
# Out:
# The list of classes:  ['Duracell', 'Energizer', 'Eveready', 'Exell', 'GP', 'Ikea', 'Klarus', 'Panasonic']
# Number of errors = 27/89
# Original Picture : Energizer\40.jpeg, Prediction : Duracell, Confidence/Percentage : 0.813
# Original Picture : Energizer\Image_59.jpg, Prediction : Panasonic, Confidence/Percentage : 0.208
# Original Picture : Eveready\605e6216c1e26e78ed9f3726c554fb1c.jpg, Prediction : Energizer, Confidence/Percentage : 0.374
# Original Picture : Eveready\EvereadyAA.jpg, Prediction : GP, Confidence/Percentage : 0.948
# Original Picture : Eveready\Image_14.jpg, Prediction : Energizer, Confidence/Percentage : 0.677
# Original Picture : Eveready\Image_47.jpg, Prediction : Panasonic, Confidence/Percentage : 0.304
# Original Picture : Eveready\S93992a49ad204492919cd1d065ad18628.jpg_360x360q75.jpg_.jpg, Prediction : GP, Confidence/Percentage : 0.275
# Original Picture : Eveready\TA-B-AA1215-2-scaled.jpg, Prediction : Panasonic, Confidence/Percentage : 0.228
# Original Picture : Eveready\energizer-eveready-super-heavy-duty-zinc-carbon-aaa-battery-1212-54.jpg, Prediction : Duracell, Confidence/Percentage : 0.463
# Original Picture : Eveready\eveready_c_sizeformat_battery_1679558982_1a2418a8_progressive.jpg, Prediction : Duracell, Confidence/Percentage : 0.363
# Original Picture : Exell\14.jpeg, Prediction : Duracell, Confidence/Percentage : 0.297
# Original Picture : Exell\Image_58.jpg, Prediction : Duracell, Confidence/Percentage : 0.402
# Original Picture : GP\20pcs-lot-New-Original-GP-LR6-1-5V-15A-AA-Alkaline-Batteries-Gold-Battery.jpg, Prediction : Eveready, Confidence/Percentage : 0.364
# Original Picture : GP\GP-Alkaline-1-5V-AAA-Battery-2-Pack.jpg, Prediction : Panasonic, Confidence/Percentage : 0.346
# Original Picture : GP\aaa-gp-vera_dnkjpbuylnbeepmp.jpg, Prediction : Panasonic, Confidence/Percentage : 0.362
# Original Picture : Ikea\15 (2).jpeg, Prediction : Exell, Confidence/Percentage : 0.220
# Original Picture : Ikea\8 (2).jpeg, Prediction : GP, Confidence/Percentage : 0.254
# Original Picture : Ikea\ikea_ladda_aaa_triple_a_batter_1636556242_63231c44_progressive.jpg, Prediction : Exell, Confidence/Percentage : 0.383
# Original Picture : Klarus\Image_64.jpg, Prediction : Duracell, Confidence/Percentage : 0.713
# Original Picture : Panasonic\13.jpg, Prediction : Exell, Confidence/Percentage : 0.420
# Original Picture : Panasonic\16.jpg, Prediction : Klarus, Confidence/Percentage : 0.416
# Original Picture : Panasonic\29.jpeg, Prediction : Energizer, Confidence/Percentage : 0.316
# Original Picture : Panasonic\33.jpg, Prediction : GP, Confidence/Percentage : 0.506
# Original Picture : Panasonic\8.jpeg, Prediction : Duracell, Confidence/Percentage : 0.724
# Original Picture : Panasonic\Image_13.jpg, Prediction : GP, Confidence/Percentage : 0.313
# Original Picture : Panasonic\Image_2.jpg, Prediction : Klarus, Confidence/Percentage : 0.607
# Original Picture : Panasonic\test_battery_back.jpg, Prediction : Klarus, Confidence/Percentage : 0.789

# %% [markdown]
# <h3>Save the model</h3>

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model so that it can be passed to edge device
model.save("image_classification.h5")
