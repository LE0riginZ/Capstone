# %% [markdown]
# <h3>Import packages</h3>

# %%
from datetime import date
from timeit import default_timer as timer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import imagenet_utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Configure TensorFlow to use GPU for training
tf.config.list_physical_devices('GPU') 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
#Set GPU memory limit so my GPU doesn't crash
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <h3>Create class to record time taken to train the model</h3>

# %%
#class to record time taken to train per epoch
class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# <h3>Create train and test folder</h3>

# %%
#creates a folder each time the set of code is run to sort dataset into train and test
day = date.today()
formatDate = day.strftime("%b-%d-%Y")

#create folder with current date to group predictions ran in a day together, if it does not exists
if os.path.isdir('Prediction (' + formatDate + ')') is False:
    folder = os.mkdir('Prediction (' + formatDate + ')')
folder = 'Prediction (' + formatDate + ')'

#looping through to find if destination folder exists
i = 1
while True:
    if os.path.isdir(folder + '/Battery Images - ' + str(i)) is False:
        break
    i += 1

#destination path for unsorted folder
destination = folder + '/Battery Images - ' + str(i)

#source path for unsorted folder
# source = 'Battery Images/'
# source = 'Battery Images [Old]/'
# source = 'Battery Images [StreamLined]/'
source = 'Battery Images [Download]/'

#duplicate the unsorted folder from source to destination
shutil.copytree(source, destination)

os.mkdir(destination + '/train')
os.mkdir(destination + '/test')

# %% [markdown]
# <h3>Sort dataset into train and test folder</h3>

# %%
#function to split images into training (80%) and testing (20%) and return both
def split(data):
    # num = int(len(data) * 0.8)
    num = int(len(data) * 0.9) #90/10 split
#     num = int(len(data) * 0.7) #70/30 split
    random.shuffle(data)
    return data[:num], data[num:]

dir = os.chdir(destination)
for category in os.listdir(dir):
    #skip the iteration if folder is "train" or "test"
    skip = ['train', 'test']
    if category in skip:
        continue
    
    shutil.move(f'{category}', 'train')
    #create a subfolder with the same name in test
    os.mkdir(f'test/{category}')

    #get the images in each folder (battery type) for spltting of data into training and testing
    img = os.listdir(f'train/{category}')
    training, testing = split(img)
    
    for file in testing:
        shutil.move(f'train/{category}/{file}', f'test/{category}')

# %% [markdown]
# <h3>b) Transfer Learning - ResNet50V2</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.ResNet50V2(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
mobile.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 23,519,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
for layer in mobile.layers[:-2]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = mobile(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
# x = tf.keras.layers.Dropout(0.65)(x) #Higher dropout to reduce overfitting (last best setting)
# output = tf.keras.layers.Dense(5, activation="softmax")(x)   
# output = tf.keras.layers.Dense(10, activation="softmax")(x)   #Changed to reflect new categories
output = tf.keras.layers.Dense(8, activation="softmax")(x)   #Changed to reflect new categories

model = keras.Model(inputs, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 8)                 16392
#
# =================================================================
# Total params: 23,581,192
# Trainable params: 20,488
# Non-trainable params: 23,560,704
# _________________________________________________________________

# %% [markdown]
# <h3>Process data</h3>

# %%
train_path = 'train'
test_path = 'test'

#for data augmentation on training data
datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet.preprocess_input,
    # validation_split=0.2,
    validation_split=0.1, #changes made for 90/10 split
    rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.2, # Randomly zoom image 
    width_shift_range = 0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range = 0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip = True,  # randomly flip images
#     vertical_flip = False,    # randomly flip images
    vertical_flip = True, #include vertical flip for better generalisation
    )  

#takes images from directory path and generates batches of augmented data
train = datagen.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='training',
        shuffle = False)

#for validation data
# validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
#                                         validation_split=0.2)
validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
                                        validation_split=0.1) #changes made for 90/10 split


validation = validation_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='validation',
        shuffle = False)

#for test data
test = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input)\
.flow_from_directory(directory=test_path, target_size=(224,224), batch_size=32, shuffle=False)
# Out:
# Found 691 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 89 images belonging to 8 classes.

# %% [markdown]
# <h3>Train model</h3>

# %%
model.compile(optimizer=Adam(learning_rate=0.006), loss='categorical_crossentropy', metrics=['accuracy']) #Last best setting
# model.compile(optimizer=Adam(learning_rate=0.0045), loss='categorical_crossentropy', metrics=['accuracy']) #Lower LR
# model.compile(optimizer=Adam(learning_rate=0.0075), loss='categorical_crossentropy', metrics=['accuracy']) 
checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True) #save best model

#more epochs for better results
result = model.fit(x=train, validation_data=validation, epochs=300, verbose=2, callbacks=[model_checkpoint_callback,cb])
# result = model.fit(x=train, validation_data=validation, epochs=200, verbose=2, callbacks=[cb])
# Out:
# Epoch 1/300
# c:\Users\ngden\anaconda3\lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 22/22 - 34s - loss: 6.5033 - accuracy: 0.0232 - val_loss: 2.5688 - val_accuracy: 0.2740 - 34s/epoch - 2s/step
# Epoch 2/300
# 22/22 - 16s - loss: 3.3402 - accuracy: 0.2562 - val_loss: 1.7148 - val_accuracy: 0.4658 - 16s/epoch - 733ms/step
# Epoch 3/300
# 22/22 - 16s - loss: 2.2390 - accuracy: 0.4327 - val_loss: 1.5259 - val_accuracy: 0.5068 - 16s/epoch - 744ms/step
# Epoch 4/300
# 22/22 - 16s - loss: 1.6020 - accuracy: 0.5456 - val_loss: 0.8752 - val_accuracy: 0.6712 - 16s/epoch - 740ms/step
# Epoch 5/300
# 22/22 - 16s - loss: 1.1895 - accuracy: 0.6353 - val_loss: 1.0733 - val_accuracy: 0.5753 - 16s/epoch - 736ms/step
# Epoch 6/300
# 22/22 - 16s - loss: 1.0488 - accuracy: 0.6845 - val_loss: 1.7396 - val_accuracy: 0.5205 - 16s/epoch - 726ms/step
# Epoch 7/300
# 22/22 - 16s - loss: 1.7108 - accuracy: 0.5528 - val_loss: 0.9569 - val_accuracy: 0.6849 - 16s/epoch - 740ms/step
# Epoch 8/300
# 22/22 - 15s - loss: 1.3847 - accuracy: 0.6643 - val_loss: 1.3665 - val_accuracy: 0.6301 - 15s/epoch - 695ms/step
# Epoch 9/300
# 22/22 - 16s - loss: 1.8593 - accuracy: 0.5745 - val_loss: 0.8483 - val_accuracy: 0.7260 - 16s/epoch - 735ms/step
# Epoch 10/300
# 22/22 - 16s - loss: 1.1614 - accuracy: 0.6237 - val_loss: 0.7360 - val_accuracy: 0.7397 - 16s/epoch - 734ms/step
# Epoch 11/300
# 22/22 - 16s - loss: 0.9117 - accuracy: 0.7323 - val_loss: 1.3752 - val_accuracy: 0.5479 - 16s/epoch - 725ms/step
# Epoch 12/300
# 22/22 - 16s - loss: 0.9369 - accuracy: 0.7467 - val_loss: 0.7282 - val_accuracy: 0.7671 - 16s/epoch - 739ms/step
# Epoch 13/300
# 22/22 - 16s - loss: 0.8443 - accuracy: 0.7381 - val_loss: 0.7252 - val_accuracy: 0.7260 - 16s/epoch - 706ms/step
# Epoch 14/300
# 22/22 - 16s - loss: 0.8557 - accuracy: 0.7250 - val_loss: 0.9080 - val_accuracy: 0.6986 - 16s/epoch - 727ms/step
# Epoch 15/300
# 22/22 - 16s - loss: 0.7885 - accuracy: 0.7540 - val_loss: 0.7708 - val_accuracy: 0.7534 - 16s/epoch - 722ms/step
# Epoch 16/300
# 22/22 - 15s - loss: 0.7711 - accuracy: 0.7583 - val_loss: 1.1293 - val_accuracy: 0.6164 - 15s/epoch - 684ms/step
# Epoch 17/300
# 22/22 - 17s - loss: 0.8405 - accuracy: 0.7670 - val_loss: 1.4821 - val_accuracy: 0.6027 - 17s/epoch - 780ms/step
# Epoch 18/300
# 22/22 - 17s - loss: 0.7892 - accuracy: 0.7627 - val_loss: 0.8340 - val_accuracy: 0.7534 - 17s/epoch - 791ms/step
# Epoch 19/300
# 22/22 - 16s - loss: 0.6232 - accuracy: 0.7931 - val_loss: 0.8161 - val_accuracy: 0.7260 - 16s/epoch - 711ms/step
# Epoch 20/300
# 22/22 - 15s - loss: 0.6928 - accuracy: 0.7800 - val_loss: 0.9651 - val_accuracy: 0.7123 - 15s/epoch - 678ms/step
# Epoch 21/300
# 22/22 - 15s - loss: 0.7362 - accuracy: 0.7728 - val_loss: 0.8878 - val_accuracy: 0.7260 - 15s/epoch - 677ms/step
# Epoch 22/300
# 22/22 - 15s - loss: 0.6102 - accuracy: 0.7974 - val_loss: 0.7188 - val_accuracy: 0.7671 - 15s/epoch - 678ms/step
# Epoch 23/300
# 22/22 - 15s - loss: 0.6203 - accuracy: 0.7858 - val_loss: 0.8062 - val_accuracy: 0.7397 - 15s/epoch - 677ms/step
# Epoch 24/300
# 22/22 - 15s - loss: 0.8356 - accuracy: 0.7525 - val_loss: 0.6826 - val_accuracy: 0.8082 - 15s/epoch - 700ms/step
# Epoch 25/300
# 22/22 - 15s - loss: 1.0388 - accuracy: 0.7120 - val_loss: 0.6477 - val_accuracy: 0.7808 - 15s/epoch - 703ms/step
# Epoch 26/300
# 22/22 - 15s - loss: 0.8629 - accuracy: 0.7583 - val_loss: 1.1176 - val_accuracy: 0.6301 - 15s/epoch - 698ms/step
# Epoch 27/300
# 22/22 - 15s - loss: 0.7083 - accuracy: 0.7800 - val_loss: 0.7312 - val_accuracy: 0.7534 - 15s/epoch - 673ms/step
# Epoch 28/300
# 22/22 - 15s - loss: 0.9648 - accuracy: 0.7250 - val_loss: 0.7854 - val_accuracy: 0.7397 - 15s/epoch - 670ms/step
# Epoch 29/300
# 22/22 - 15s - loss: 0.8079 - accuracy: 0.7467 - val_loss: 0.7777 - val_accuracy: 0.7808 - 15s/epoch - 671ms/step
# Epoch 30/300
# 22/22 - 15s - loss: 0.6545 - accuracy: 0.7902 - val_loss: 0.6628 - val_accuracy: 0.8219 - 15s/epoch - 697ms/step
# Epoch 31/300
# 22/22 - 16s - loss: 0.4835 - accuracy: 0.8466 - val_loss: 0.5813 - val_accuracy: 0.8630 - 16s/epoch - 712ms/step
# Epoch 32/300
# 22/22 - 15s - loss: 0.6280 - accuracy: 0.7931 - val_loss: 0.7224 - val_accuracy: 0.8082 - 15s/epoch - 692ms/step
# Epoch 33/300
# 22/22 - 15s - loss: 0.7494 - accuracy: 0.7887 - val_loss: 1.0855 - val_accuracy: 0.6986 - 15s/epoch - 689ms/step
# Epoch 34/300
# 22/22 - 15s - loss: 0.6036 - accuracy: 0.8234 - val_loss: 1.1464 - val_accuracy: 0.6986 - 15s/epoch - 676ms/step
# Epoch 35/300
# 22/22 - 15s - loss: 0.5401 - accuracy: 0.8263 - val_loss: 0.8639 - val_accuracy: 0.7671 - 15s/epoch - 680ms/step
# Epoch 36/300
# 22/22 - 15s - loss: 0.5106 - accuracy: 0.8495 - val_loss: 0.7663 - val_accuracy: 0.8219 - 15s/epoch - 675ms/step
# Epoch 37/300
# 22/22 - 15s - loss: 0.6168 - accuracy: 0.8046 - val_loss: 0.6419 - val_accuracy: 0.7671 - 15s/epoch - 669ms/step
# Epoch 38/300
# 22/22 - 15s - loss: 0.6341 - accuracy: 0.7858 - val_loss: 1.3610 - val_accuracy: 0.6849 - 15s/epoch - 669ms/step
# Epoch 39/300
# 22/22 - 15s - loss: 0.5752 - accuracy: 0.8379 - val_loss: 0.6787 - val_accuracy: 0.7534 - 15s/epoch - 671ms/step
# Epoch 40/300
# 22/22 - 15s - loss: 0.5485 - accuracy: 0.8177 - val_loss: 0.9989 - val_accuracy: 0.7671 - 15s/epoch - 669ms/step
# Epoch 41/300
# 22/22 - 15s - loss: 0.5743 - accuracy: 0.8075 - val_loss: 0.8393 - val_accuracy: 0.7671 - 15s/epoch - 671ms/step
# Epoch 42/300
# 22/22 - 15s - loss: 0.5771 - accuracy: 0.8365 - val_loss: 0.8985 - val_accuracy: 0.7671 - 15s/epoch - 667ms/step
# Epoch 43/300
# 22/22 - 15s - loss: 0.5161 - accuracy: 0.8452 - val_loss: 0.6793 - val_accuracy: 0.8082 - 15s/epoch - 673ms/step
# Epoch 44/300
# 22/22 - 15s - loss: 0.6826 - accuracy: 0.8119 - val_loss: 1.0048 - val_accuracy: 0.6986 - 15s/epoch - 671ms/step
# Epoch 45/300
# 22/22 - 15s - loss: 0.5096 - accuracy: 0.8394 - val_loss: 0.6994 - val_accuracy: 0.7945 - 15s/epoch - 669ms/step
# Epoch 46/300
# 22/22 - 15s - loss: 0.4277 - accuracy: 0.8683 - val_loss: 0.5978 - val_accuracy: 0.8493 - 15s/epoch - 668ms/step
# Epoch 47/300
# 22/22 - 15s - loss: 0.5118 - accuracy: 0.8466 - val_loss: 0.7732 - val_accuracy: 0.7808 - 15s/epoch - 666ms/step
# Epoch 48/300
# 22/22 - 15s - loss: 0.4514 - accuracy: 0.8437 - val_loss: 0.6635 - val_accuracy: 0.8219 - 15s/epoch - 673ms/step
# Epoch 49/300
# 22/22 - 15s - loss: 0.4624 - accuracy: 0.8538 - val_loss: 0.7200 - val_accuracy: 0.8082 - 15s/epoch - 668ms/step
# Epoch 50/300
# 22/22 - 15s - loss: 0.5618 - accuracy: 0.8234 - val_loss: 0.7576 - val_accuracy: 0.7808 - 15s/epoch - 670ms/step
# Epoch 51/300
# 22/22 - 15s - loss: 0.5024 - accuracy: 0.8495 - val_loss: 0.7055 - val_accuracy: 0.7808 - 15s/epoch - 668ms/step
# Epoch 52/300
# 22/22 - 15s - loss: 0.5598 - accuracy: 0.8292 - val_loss: 0.7788 - val_accuracy: 0.7945 - 15s/epoch - 671ms/step
# Epoch 53/300
# 22/22 - 15s - loss: 0.8135 - accuracy: 0.7902 - val_loss: 0.8792 - val_accuracy: 0.7534 - 15s/epoch - 673ms/step
# Epoch 54/300
# 22/22 - 15s - loss: 0.7711 - accuracy: 0.7959 - val_loss: 1.3860 - val_accuracy: 0.7260 - 15s/epoch - 668ms/step
# Epoch 55/300
# 22/22 - 15s - loss: 0.8789 - accuracy: 0.7757 - val_loss: 0.9216 - val_accuracy: 0.7534 - 15s/epoch - 667ms/step
# Epoch 56/300
# 22/22 - 15s - loss: 0.5671 - accuracy: 0.8307 - val_loss: 0.5286 - val_accuracy: 0.8219 - 15s/epoch - 665ms/step
# Epoch 57/300
# 22/22 - 15s - loss: 0.4296 - accuracy: 0.8567 - val_loss: 0.9058 - val_accuracy: 0.7534 - 15s/epoch - 666ms/step
# Epoch 58/300
# 22/22 - 15s - loss: 0.3849 - accuracy: 0.8683 - val_loss: 0.5891 - val_accuracy: 0.8219 - 15s/epoch - 667ms/step
# Epoch 59/300
# 22/22 - 15s - loss: 0.4035 - accuracy: 0.8755 - val_loss: 0.8035 - val_accuracy: 0.7534 - 15s/epoch - 668ms/step
# Epoch 60/300
# 22/22 - 15s - loss: 0.5057 - accuracy: 0.8683 - val_loss: 0.5503 - val_accuracy: 0.8493 - 15s/epoch - 665ms/step
# Epoch 61/300
# 22/22 - 15s - loss: 0.4966 - accuracy: 0.8408 - val_loss: 0.6145 - val_accuracy: 0.8356 - 15s/epoch - 669ms/step
# Epoch 62/300
# 22/22 - 15s - loss: 0.4238 - accuracy: 0.8640 - val_loss: 0.9169 - val_accuracy: 0.7945 - 15s/epoch - 672ms/step
# Epoch 63/300
# 22/22 - 15s - loss: 0.5305 - accuracy: 0.8423 - val_loss: 0.6582 - val_accuracy: 0.8219 - 15s/epoch - 676ms/step
# Epoch 64/300
# 22/22 - 15s - loss: 0.5686 - accuracy: 0.8394 - val_loss: 0.6769 - val_accuracy: 0.8356 - 15s/epoch - 677ms/step
# Epoch 65/300
# 22/22 - 15s - loss: 0.5776 - accuracy: 0.8480 - val_loss: 0.5984 - val_accuracy: 0.8356 - 15s/epoch - 669ms/step
# Epoch 66/300
# 22/22 - 15s - loss: 0.4987 - accuracy: 0.8524 - val_loss: 0.6658 - val_accuracy: 0.8219 - 15s/epoch - 673ms/step
# Epoch 67/300
# 22/22 - 15s - loss: 0.4682 - accuracy: 0.8509 - val_loss: 0.7102 - val_accuracy: 0.8356 - 15s/epoch - 671ms/step
# Epoch 68/300
# 22/22 - 15s - loss: 0.5269 - accuracy: 0.8336 - val_loss: 0.9432 - val_accuracy: 0.7534 - 15s/epoch - 672ms/step
# Epoch 69/300
# 22/22 - 15s - loss: 0.5810 - accuracy: 0.8437 - val_loss: 0.9589 - val_accuracy: 0.8082 - 15s/epoch - 676ms/step
# Epoch 70/300
# 22/22 - 15s - loss: 0.6178 - accuracy: 0.8452 - val_loss: 0.8109 - val_accuracy: 0.7534 - 15s/epoch - 673ms/step
# Epoch 71/300
# 22/22 - 15s - loss: 0.4879 - accuracy: 0.8553 - val_loss: 0.5728 - val_accuracy: 0.8493 - 15s/epoch - 667ms/step
# Epoch 72/300
# 22/22 - 15s - loss: 0.2956 - accuracy: 0.9030 - val_loss: 0.6788 - val_accuracy: 0.8082 - 15s/epoch - 668ms/step
# Epoch 73/300
# 22/22 - 15s - loss: 0.3353 - accuracy: 0.8828 - val_loss: 0.6986 - val_accuracy: 0.7808 - 15s/epoch - 671ms/step
# Epoch 74/300
# 22/22 - 15s - loss: 0.4071 - accuracy: 0.8828 - val_loss: 0.8081 - val_accuracy: 0.7808 - 15s/epoch - 684ms/step
# Epoch 75/300
# 22/22 - 15s - loss: 0.4196 - accuracy: 0.8755 - val_loss: 0.7412 - val_accuracy: 0.8219 - 15s/epoch - 701ms/step
# Epoch 76/300
# 22/22 - 15s - loss: 0.5353 - accuracy: 0.8509 - val_loss: 0.7393 - val_accuracy: 0.7671 - 15s/epoch - 697ms/step
# Epoch 77/300
# 22/22 - 15s - loss: 0.4533 - accuracy: 0.8654 - val_loss: 0.9748 - val_accuracy: 0.7397 - 15s/epoch - 704ms/step
# Epoch 78/300
# 22/22 - 16s - loss: 0.5414 - accuracy: 0.8437 - val_loss: 0.6265 - val_accuracy: 0.7945 - 16s/epoch - 708ms/step
# Epoch 79/300
# 22/22 - 17s - loss: 0.4538 - accuracy: 0.8538 - val_loss: 1.0422 - val_accuracy: 0.7397 - 17s/epoch - 757ms/step
# Epoch 80/300
# 22/22 - 16s - loss: 0.3411 - accuracy: 0.8944 - val_loss: 0.6863 - val_accuracy: 0.8356 - 16s/epoch - 705ms/step
# Epoch 81/300
# 22/22 - 15s - loss: 0.4152 - accuracy: 0.8683 - val_loss: 0.8062 - val_accuracy: 0.7808 - 15s/epoch - 692ms/step
# Epoch 82/300
# 22/22 - 17s - loss: 0.5097 - accuracy: 0.8524 - val_loss: 0.8861 - val_accuracy: 0.7671 - 17s/epoch - 762ms/step
# Epoch 83/300
# 22/22 - 17s - loss: 0.4224 - accuracy: 0.8654 - val_loss: 0.9085 - val_accuracy: 0.7671 - 17s/epoch - 766ms/step
# Epoch 84/300
# 22/22 - 16s - loss: 0.3383 - accuracy: 0.8987 - val_loss: 0.6773 - val_accuracy: 0.8356 - 16s/epoch - 709ms/step
# Epoch 85/300
# 22/22 - 16s - loss: 0.4383 - accuracy: 0.8495 - val_loss: 1.0444 - val_accuracy: 0.7397 - 16s/epoch - 722ms/step
# Epoch 86/300
# 22/22 - 16s - loss: 0.4358 - accuracy: 0.8741 - val_loss: 0.6618 - val_accuracy: 0.8082 - 16s/epoch - 730ms/step
# Epoch 87/300
# 22/22 - 15s - loss: 0.4567 - accuracy: 0.8669 - val_loss: 1.2281 - val_accuracy: 0.6986 - 15s/epoch - 701ms/step
# Epoch 88/300
# 22/22 - 15s - loss: 0.5653 - accuracy: 0.8394 - val_loss: 0.7548 - val_accuracy: 0.7534 - 15s/epoch - 686ms/step
# Epoch 89/300
# 22/22 - 15s - loss: 0.5310 - accuracy: 0.8437 - val_loss: 0.5735 - val_accuracy: 0.8630 - 15s/epoch - 686ms/step
# Epoch 90/300
# 22/22 - 15s - loss: 0.3620 - accuracy: 0.8857 - val_loss: 0.8431 - val_accuracy: 0.7534 - 15s/epoch - 681ms/step
# Epoch 91/300
# 22/22 - 15s - loss: 0.4101 - accuracy: 0.8813 - val_loss: 0.7337 - val_accuracy: 0.8493 - 15s/epoch - 685ms/step
# Epoch 92/300
# 22/22 - 15s - loss: 0.3933 - accuracy: 0.8929 - val_loss: 0.6193 - val_accuracy: 0.8219 - 15s/epoch - 685ms/step
# Epoch 93/300
# 22/22 - 15s - loss: 0.4095 - accuracy: 0.8770 - val_loss: 0.7560 - val_accuracy: 0.8082 - 15s/epoch - 685ms/step
# Epoch 94/300
# 22/22 - 15s - loss: 0.4671 - accuracy: 0.8741 - val_loss: 1.0574 - val_accuracy: 0.7671 - 15s/epoch - 686ms/step
# Epoch 95/300
# 22/22 - 15s - loss: 0.3163 - accuracy: 0.8973 - val_loss: 0.5967 - val_accuracy: 0.8493 - 15s/epoch - 687ms/step
# Epoch 96/300
# 22/22 - 15s - loss: 0.3937 - accuracy: 0.8886 - val_loss: 1.0657 - val_accuracy: 0.7534 - 15s/epoch - 687ms/step
# Epoch 97/300
# 22/22 - 15s - loss: 0.6570 - accuracy: 0.8278 - val_loss: 0.8195 - val_accuracy: 0.8082 - 15s/epoch - 682ms/step
# Epoch 98/300
# 22/22 - 15s - loss: 0.5460 - accuracy: 0.8567 - val_loss: 0.5942 - val_accuracy: 0.8493 - 15s/epoch - 678ms/step
# Epoch 99/300
# 22/22 - 15s - loss: 0.4876 - accuracy: 0.8669 - val_loss: 0.8274 - val_accuracy: 0.8219 - 15s/epoch - 682ms/step
# Epoch 100/300
# 22/22 - 15s - loss: 0.3989 - accuracy: 0.8944 - val_loss: 0.8115 - val_accuracy: 0.8219 - 15s/epoch - 693ms/step
# Epoch 101/300
# 22/22 - 16s - loss: 0.2984 - accuracy: 0.9016 - val_loss: 0.9134 - val_accuracy: 0.7534 - 16s/epoch - 708ms/step
# Epoch 102/300
# 22/22 - 16s - loss: 0.4203 - accuracy: 0.8842 - val_loss: 0.6551 - val_accuracy: 0.8356 - 16s/epoch - 709ms/step
# Epoch 103/300
# 22/22 - 15s - loss: 0.4250 - accuracy: 0.8698 - val_loss: 0.7632 - val_accuracy: 0.7945 - 15s/epoch - 690ms/step
# Epoch 104/300
# 22/22 - 15s - loss: 0.3560 - accuracy: 0.8813 - val_loss: 0.6457 - val_accuracy: 0.8219 - 15s/epoch - 698ms/step
# Epoch 105/300
# 22/22 - 16s - loss: 0.3103 - accuracy: 0.8799 - val_loss: 0.7905 - val_accuracy: 0.7945 - 16s/epoch - 707ms/step
# Epoch 106/300
# 22/22 - 15s - loss: 0.3123 - accuracy: 0.9059 - val_loss: 0.6984 - val_accuracy: 0.8493 - 15s/epoch - 703ms/step
# Epoch 107/300
# 22/22 - 15s - loss: 0.4138 - accuracy: 0.8973 - val_loss: 0.6657 - val_accuracy: 0.8630 - 15s/epoch - 688ms/step
# Epoch 108/300
# 22/22 - 15s - loss: 0.3253 - accuracy: 0.8900 - val_loss: 0.7223 - val_accuracy: 0.8219 - 15s/epoch - 687ms/step
# Epoch 109/300
# 22/22 - 16s - loss: 0.3808 - accuracy: 0.8871 - val_loss: 0.7228 - val_accuracy: 0.8356 - 16s/epoch - 705ms/step
# Epoch 110/300
# 22/22 - 16s - loss: 0.4186 - accuracy: 0.8698 - val_loss: 0.9105 - val_accuracy: 0.7808 - 16s/epoch - 709ms/step
# Epoch 111/300
# 22/22 - 15s - loss: 0.7272 - accuracy: 0.8191 - val_loss: 0.9627 - val_accuracy: 0.7671 - 15s/epoch - 691ms/step
# Epoch 112/300
# 22/22 - 15s - loss: 0.3239 - accuracy: 0.9059 - val_loss: 1.0572 - val_accuracy: 0.7534 - 15s/epoch - 693ms/step
# Epoch 113/300
# 22/22 - 16s - loss: 0.6033 - accuracy: 0.8423 - val_loss: 0.6520 - val_accuracy: 0.8219 - 16s/epoch - 720ms/step
# Epoch 114/300
# 22/22 - 17s - loss: 0.3594 - accuracy: 0.8857 - val_loss: 0.7377 - val_accuracy: 0.7945 - 17s/epoch - 755ms/step
# Epoch 115/300
# 22/22 - 16s - loss: 0.5408 - accuracy: 0.8538 - val_loss: 0.8192 - val_accuracy: 0.7945 - 16s/epoch - 706ms/step
# Epoch 116/300
# 22/22 - 15s - loss: 0.4505 - accuracy: 0.8784 - val_loss: 0.7094 - val_accuracy: 0.8082 - 15s/epoch - 686ms/step
# Epoch 117/300
# 22/22 - 15s - loss: 0.3633 - accuracy: 0.8929 - val_loss: 0.7397 - val_accuracy: 0.8356 - 15s/epoch - 697ms/step
# Epoch 118/300
# 22/22 - 15s - loss: 0.3973 - accuracy: 0.8784 - val_loss: 0.9383 - val_accuracy: 0.7534 - 15s/epoch - 694ms/step
# Epoch 119/300
# 22/22 - 15s - loss: 0.3985 - accuracy: 0.8770 - val_loss: 0.8846 - val_accuracy: 0.8082 - 15s/epoch - 698ms/step
# Epoch 120/300
# 22/22 - 15s - loss: 0.3871 - accuracy: 0.8799 - val_loss: 0.6564 - val_accuracy: 0.8219 - 15s/epoch - 679ms/step
# Epoch 121/300
# 22/22 - 15s - loss: 0.4906 - accuracy: 0.8640 - val_loss: 0.7317 - val_accuracy: 0.8356 - 15s/epoch - 681ms/step
# Epoch 122/300
# 22/22 - 15s - loss: 0.3548 - accuracy: 0.8900 - val_loss: 0.7040 - val_accuracy: 0.8493 - 15s/epoch - 686ms/step
# Epoch 123/300
# 22/22 - 15s - loss: 0.3881 - accuracy: 0.8871 - val_loss: 0.6862 - val_accuracy: 0.8630 - 15s/epoch - 699ms/step
# Epoch 124/300
# 22/22 - 17s - loss: 0.2757 - accuracy: 0.9074 - val_loss: 0.6152 - val_accuracy: 0.8767 - 17s/epoch - 775ms/step
# Epoch 125/300
# 22/22 - 16s - loss: 0.3755 - accuracy: 0.8799 - val_loss: 0.6879 - val_accuracy: 0.8219 - 16s/epoch - 720ms/step
# Epoch 126/300
# 22/22 - 16s - loss: 0.4653 - accuracy: 0.8755 - val_loss: 0.7493 - val_accuracy: 0.8082 - 16s/epoch - 746ms/step
# Epoch 127/300
# 22/22 - 16s - loss: 0.3736 - accuracy: 0.8886 - val_loss: 0.7270 - val_accuracy: 0.8493 - 16s/epoch - 711ms/step
# Epoch 128/300
# 22/22 - 15s - loss: 0.3234 - accuracy: 0.9001 - val_loss: 0.6396 - val_accuracy: 0.8630 - 15s/epoch - 700ms/step
# Epoch 129/300
# 22/22 - 15s - loss: 0.3438 - accuracy: 0.8871 - val_loss: 0.6703 - val_accuracy: 0.8630 - 15s/epoch - 688ms/step
# Epoch 130/300
# 22/22 - 16s - loss: 0.3589 - accuracy: 0.9161 - val_loss: 0.6309 - val_accuracy: 0.8904 - 16s/epoch - 732ms/step
# Epoch 131/300
# 22/22 - 17s - loss: 0.3111 - accuracy: 0.9103 - val_loss: 0.7787 - val_accuracy: 0.8082 - 17s/epoch - 768ms/step
# Epoch 132/300
# 22/22 - 17s - loss: 0.3884 - accuracy: 0.8886 - val_loss: 0.7152 - val_accuracy: 0.8630 - 17s/epoch - 752ms/step
# Epoch 133/300
# 22/22 - 15s - loss: 0.3372 - accuracy: 0.8944 - val_loss: 0.4958 - val_accuracy: 0.8493 - 15s/epoch - 692ms/step
# Epoch 134/300
# 22/22 - 15s - loss: 0.3816 - accuracy: 0.8799 - val_loss: 0.6887 - val_accuracy: 0.8493 - 15s/epoch - 699ms/step
# Epoch 135/300
# 22/22 - 15s - loss: 0.3916 - accuracy: 0.8755 - val_loss: 0.5276 - val_accuracy: 0.8356 - 15s/epoch - 697ms/step
# Epoch 136/300
# 22/22 - 16s - loss: 0.3485 - accuracy: 0.8813 - val_loss: 0.6218 - val_accuracy: 0.8493 - 16s/epoch - 707ms/step
# Epoch 137/300
# 22/22 - 15s - loss: 0.3725 - accuracy: 0.8784 - val_loss: 0.6562 - val_accuracy: 0.8630 - 15s/epoch - 689ms/step
# Epoch 138/300
# 22/22 - 16s - loss: 0.4609 - accuracy: 0.8712 - val_loss: 0.7689 - val_accuracy: 0.7945 - 16s/epoch - 710ms/step
# Epoch 139/300
# 22/22 - 16s - loss: 0.4503 - accuracy: 0.8726 - val_loss: 0.7120 - val_accuracy: 0.7945 - 16s/epoch - 719ms/step
# Epoch 140/300
# 22/22 - 15s - loss: 0.4845 - accuracy: 0.8683 - val_loss: 0.6976 - val_accuracy: 0.8356 - 15s/epoch - 693ms/step
# Epoch 141/300
# 22/22 - 15s - loss: 0.3916 - accuracy: 0.8857 - val_loss: 0.7650 - val_accuracy: 0.7808 - 15s/epoch - 680ms/step
# Epoch 142/300
# 22/22 - 15s - loss: 0.5046 - accuracy: 0.8698 - val_loss: 0.9981 - val_accuracy: 0.7123 - 15s/epoch - 672ms/step
# Epoch 143/300
# 22/22 - 15s - loss: 0.4462 - accuracy: 0.8640 - val_loss: 0.5783 - val_accuracy: 0.8493 - 15s/epoch - 677ms/step
# Epoch 144/300
# 22/22 - 16s - loss: 0.4394 - accuracy: 0.8741 - val_loss: 0.7107 - val_accuracy: 0.8082 - 16s/epoch - 707ms/step
# Epoch 145/300
# 22/22 - 16s - loss: 0.3720 - accuracy: 0.9001 - val_loss: 0.6784 - val_accuracy: 0.8493 - 16s/epoch - 711ms/step
# Epoch 146/300
# 22/22 - 15s - loss: 0.3833 - accuracy: 0.8842 - val_loss: 0.7203 - val_accuracy: 0.8082 - 15s/epoch - 685ms/step
# Epoch 147/300
# 22/22 - 15s - loss: 0.3712 - accuracy: 0.8698 - val_loss: 0.6255 - val_accuracy: 0.8630 - 15s/epoch - 673ms/step
# Epoch 148/300
# 22/22 - 16s - loss: 0.3684 - accuracy: 0.8857 - val_loss: 0.5301 - val_accuracy: 0.9178 - 16s/epoch - 715ms/step
# Epoch 149/300
# 22/22 - 17s - loss: 0.3011 - accuracy: 0.9088 - val_loss: 0.7857 - val_accuracy: 0.8356 - 17s/epoch - 751ms/step
# Epoch 150/300
# 22/22 - 15s - loss: 0.4819 - accuracy: 0.8683 - val_loss: 0.8246 - val_accuracy: 0.8082 - 15s/epoch - 678ms/step
# Epoch 151/300
# 22/22 - 15s - loss: 0.4893 - accuracy: 0.8654 - val_loss: 0.6727 - val_accuracy: 0.8630 - 15s/epoch - 670ms/step
# Epoch 152/300
# 22/22 - 15s - loss: 0.3632 - accuracy: 0.8987 - val_loss: 0.4992 - val_accuracy: 0.8356 - 15s/epoch - 665ms/step
# Epoch 153/300
# 22/22 - 15s - loss: 0.4142 - accuracy: 0.8698 - val_loss: 0.7719 - val_accuracy: 0.8082 - 15s/epoch - 663ms/step
# Epoch 154/300
# 22/22 - 15s - loss: 0.3768 - accuracy: 0.9030 - val_loss: 0.5752 - val_accuracy: 0.8356 - 15s/epoch - 664ms/step
# Epoch 155/300
# 22/22 - 15s - loss: 0.3397 - accuracy: 0.8944 - val_loss: 0.5654 - val_accuracy: 0.8356 - 15s/epoch - 668ms/step
# Epoch 156/300
# 22/22 - 15s - loss: 0.3853 - accuracy: 0.8842 - val_loss: 0.5803 - val_accuracy: 0.8493 - 15s/epoch - 669ms/step
# Epoch 157/300
# 22/22 - 15s - loss: 0.3530 - accuracy: 0.8987 - val_loss: 0.5102 - val_accuracy: 0.8356 - 15s/epoch - 663ms/step
# Epoch 158/300
# 22/22 - 15s - loss: 0.4807 - accuracy: 0.8596 - val_loss: 0.6836 - val_accuracy: 0.7945 - 15s/epoch - 665ms/step
# Epoch 159/300
# 22/22 - 15s - loss: 0.4058 - accuracy: 0.8944 - val_loss: 0.4943 - val_accuracy: 0.8767 - 15s/epoch - 670ms/step
# Epoch 160/300
# 22/22 - 15s - loss: 0.4030 - accuracy: 0.8871 - val_loss: 0.7915 - val_accuracy: 0.7945 - 15s/epoch - 667ms/step
# Epoch 161/300
# 22/22 - 15s - loss: 0.3102 - accuracy: 0.9045 - val_loss: 0.7875 - val_accuracy: 0.8219 - 15s/epoch - 684ms/step
# Epoch 162/300
# 22/22 - 15s - loss: 0.3367 - accuracy: 0.9088 - val_loss: 0.6151 - val_accuracy: 0.8219 - 15s/epoch - 668ms/step
# Epoch 163/300
# 22/22 - 15s - loss: 0.3342 - accuracy: 0.8944 - val_loss: 0.7292 - val_accuracy: 0.7945 - 15s/epoch - 675ms/step
# Epoch 164/300
# 22/22 - 15s - loss: 0.2730 - accuracy: 0.9103 - val_loss: 0.5713 - val_accuracy: 0.8219 - 15s/epoch - 669ms/step
# Epoch 165/300
# 22/22 - 15s - loss: 0.3261 - accuracy: 0.8958 - val_loss: 0.5525 - val_accuracy: 0.7945 - 15s/epoch - 665ms/step
# Epoch 166/300
# 22/22 - 15s - loss: 0.2985 - accuracy: 0.9045 - val_loss: 0.7941 - val_accuracy: 0.8219 - 15s/epoch - 662ms/step
# Epoch 167/300
# 22/22 - 15s - loss: 0.2976 - accuracy: 0.8900 - val_loss: 0.6402 - val_accuracy: 0.8356 - 15s/epoch - 670ms/step
# Epoch 168/300
# 22/22 - 15s - loss: 0.2766 - accuracy: 0.9103 - val_loss: 0.7632 - val_accuracy: 0.7671 - 15s/epoch - 685ms/step
# Epoch 169/300
# 22/22 - 15s - loss: 0.3170 - accuracy: 0.9059 - val_loss: 0.8301 - val_accuracy: 0.8082 - 15s/epoch - 667ms/step
# Epoch 170/300
# 22/22 - 15s - loss: 0.5616 - accuracy: 0.8813 - val_loss: 0.6119 - val_accuracy: 0.8082 - 15s/epoch - 675ms/step
# Epoch 171/300
# 22/22 - 16s - loss: 0.3979 - accuracy: 0.8958 - val_loss: 0.7007 - val_accuracy: 0.8219 - 16s/epoch - 706ms/step
# Epoch 172/300
# 22/22 - 15s - loss: 0.3491 - accuracy: 0.9074 - val_loss: 0.7507 - val_accuracy: 0.7808 - 15s/epoch - 665ms/step
# Epoch 173/300
# 22/22 - 15s - loss: 0.4197 - accuracy: 0.8842 - val_loss: 0.6986 - val_accuracy: 0.8356 - 15s/epoch - 675ms/step
# Epoch 174/300
# 22/22 - 15s - loss: 0.3375 - accuracy: 0.8828 - val_loss: 0.9490 - val_accuracy: 0.7671 - 15s/epoch - 671ms/step
# Epoch 175/300
# 22/22 - 15s - loss: 0.3487 - accuracy: 0.8973 - val_loss: 0.6257 - val_accuracy: 0.8082 - 15s/epoch - 667ms/step
# Epoch 176/300
# 22/22 - 15s - loss: 0.3634 - accuracy: 0.8973 - val_loss: 0.8725 - val_accuracy: 0.8219 - 15s/epoch - 665ms/step
# Epoch 177/300
# 22/22 - 15s - loss: 0.3738 - accuracy: 0.8900 - val_loss: 0.9620 - val_accuracy: 0.7945 - 15s/epoch - 670ms/step
# Epoch 178/300
# 22/22 - 15s - loss: 0.6214 - accuracy: 0.8278 - val_loss: 0.5730 - val_accuracy: 0.8356 - 15s/epoch - 669ms/step
# Epoch 179/300
# 22/22 - 15s - loss: 0.4066 - accuracy: 0.8828 - val_loss: 0.9631 - val_accuracy: 0.7671 - 15s/epoch - 665ms/step
# Epoch 180/300
# 22/22 - 15s - loss: 0.3704 - accuracy: 0.8973 - val_loss: 0.7532 - val_accuracy: 0.8219 - 15s/epoch - 692ms/step
# Epoch 181/300
# 22/22 - 15s - loss: 0.3594 - accuracy: 0.8929 - val_loss: 0.7350 - val_accuracy: 0.8219 - 15s/epoch - 684ms/step
# Epoch 182/300
# 22/22 - 15s - loss: 0.4117 - accuracy: 0.8871 - val_loss: 0.9636 - val_accuracy: 0.7808 - 15s/epoch - 691ms/step
# Epoch 183/300
# 22/22 - 15s - loss: 0.3078 - accuracy: 0.9117 - val_loss: 0.6612 - val_accuracy: 0.8219 - 15s/epoch - 674ms/step
# Epoch 184/300
# 22/22 - 15s - loss: 0.3817 - accuracy: 0.8842 - val_loss: 0.7550 - val_accuracy: 0.7808 - 15s/epoch - 676ms/step
# Epoch 185/300
# 22/22 - 15s - loss: 0.2684 - accuracy: 0.9117 - val_loss: 0.7883 - val_accuracy: 0.7808 - 15s/epoch - 676ms/step
# Epoch 186/300
# 22/22 - 15s - loss: 0.2755 - accuracy: 0.9161 - val_loss: 0.6958 - val_accuracy: 0.8082 - 15s/epoch - 682ms/step
# Epoch 187/300
# 22/22 - 15s - loss: 0.2961 - accuracy: 0.9146 - val_loss: 0.7937 - val_accuracy: 0.8082 - 15s/epoch - 692ms/step
# Epoch 188/300
# 22/22 - 15s - loss: 0.3198 - accuracy: 0.9059 - val_loss: 0.8185 - val_accuracy: 0.7945 - 15s/epoch - 682ms/step
# Epoch 189/300
# 22/22 - 15s - loss: 0.4430 - accuracy: 0.8842 - val_loss: 0.6965 - val_accuracy: 0.8356 - 15s/epoch - 666ms/step
# Epoch 190/300
# 22/22 - 15s - loss: 0.4389 - accuracy: 0.8929 - val_loss: 0.6293 - val_accuracy: 0.8219 - 15s/epoch - 665ms/step
# Epoch 191/300
# 22/22 - 15s - loss: 0.3555 - accuracy: 0.8973 - val_loss: 0.9190 - val_accuracy: 0.7808 - 15s/epoch - 664ms/step
# Epoch 192/300
# 22/22 - 15s - loss: 0.2434 - accuracy: 0.9320 - val_loss: 0.8749 - val_accuracy: 0.7671 - 15s/epoch - 665ms/step
# Epoch 193/300
# 22/22 - 15s - loss: 0.4354 - accuracy: 0.8712 - val_loss: 0.7827 - val_accuracy: 0.7808 - 15s/epoch - 662ms/step
# Epoch 194/300
# 22/22 - 15s - loss: 0.3422 - accuracy: 0.8987 - val_loss: 0.7211 - val_accuracy: 0.8356 - 15s/epoch - 664ms/step
# Epoch 195/300
# 22/22 - 15s - loss: 0.3248 - accuracy: 0.9045 - val_loss: 0.6641 - val_accuracy: 0.8082 - 15s/epoch - 662ms/step
# Epoch 196/300
# 22/22 - 15s - loss: 0.2881 - accuracy: 0.9074 - val_loss: 0.8168 - val_accuracy: 0.8219 - 15s/epoch - 667ms/step
# Epoch 197/300
# 22/22 - 15s - loss: 0.3159 - accuracy: 0.9088 - val_loss: 0.6506 - val_accuracy: 0.8356 - 15s/epoch - 664ms/step
# Epoch 198/300
# 22/22 - 15s - loss: 0.3442 - accuracy: 0.9059 - val_loss: 1.1914 - val_accuracy: 0.7808 - 15s/epoch - 663ms/step
# Epoch 199/300
# 22/22 - 15s - loss: 0.4453 - accuracy: 0.8857 - val_loss: 0.7063 - val_accuracy: 0.8219 - 15s/epoch - 664ms/step
# Epoch 200/300
# 22/22 - 15s - loss: 0.3357 - accuracy: 0.9016 - val_loss: 0.6841 - val_accuracy: 0.8493 - 15s/epoch - 672ms/step
# Epoch 201/300
# 22/22 - 15s - loss: 0.3916 - accuracy: 0.8958 - val_loss: 0.8724 - val_accuracy: 0.7945 - 15s/epoch - 678ms/step
# Epoch 202/300
# 22/22 - 15s - loss: 0.3574 - accuracy: 0.8929 - val_loss: 0.8370 - val_accuracy: 0.7671 - 15s/epoch - 673ms/step
# Epoch 203/300
# 22/22 - 15s - loss: 0.3847 - accuracy: 0.8784 - val_loss: 0.8203 - val_accuracy: 0.7945 - 15s/epoch - 664ms/step
# Epoch 204/300
# 22/22 - 16s - loss: 0.3903 - accuracy: 0.8886 - val_loss: 0.8971 - val_accuracy: 0.8082 - 16s/epoch - 725ms/step
# Epoch 205/300
# 22/22 - 15s - loss: 0.3127 - accuracy: 0.8886 - val_loss: 0.7562 - val_accuracy: 0.8493 - 15s/epoch - 692ms/step
# Epoch 206/300
# 22/22 - 15s - loss: 0.4089 - accuracy: 0.8828 - val_loss: 0.7185 - val_accuracy: 0.8356 - 15s/epoch - 673ms/step
# Epoch 207/300
# 22/22 - 15s - loss: 0.3563 - accuracy: 0.8958 - val_loss: 0.7304 - val_accuracy: 0.8356 - 15s/epoch - 683ms/step
# Epoch 208/300
# 22/22 - 17s - loss: 0.4480 - accuracy: 0.8799 - val_loss: 0.6564 - val_accuracy: 0.8356 - 17s/epoch - 760ms/step
# Epoch 209/300
# 22/22 - 16s - loss: 0.3833 - accuracy: 0.8929 - val_loss: 0.6928 - val_accuracy: 0.8630 - 16s/epoch - 724ms/step
# Epoch 210/300
# 22/22 - 15s - loss: 0.3964 - accuracy: 0.9030 - val_loss: 1.1312 - val_accuracy: 0.7534 - 15s/epoch - 670ms/step
# Epoch 211/300
# 22/22 - 16s - loss: 0.3782 - accuracy: 0.8900 - val_loss: 0.5103 - val_accuracy: 0.8630 - 16s/epoch - 724ms/step
# Epoch 212/300
# 22/22 - 16s - loss: 0.3340 - accuracy: 0.9045 - val_loss: 0.9340 - val_accuracy: 0.8082 - 16s/epoch - 735ms/step
# Epoch 213/300
# 22/22 - 15s - loss: 0.3733 - accuracy: 0.8828 - val_loss: 0.5991 - val_accuracy: 0.8767 - 15s/epoch - 669ms/step
# Epoch 214/300
# 22/22 - 15s - loss: 0.3330 - accuracy: 0.8973 - val_loss: 0.6606 - val_accuracy: 0.8356 - 15s/epoch - 681ms/step
# Epoch 215/300
# 22/22 - 15s - loss: 0.4224 - accuracy: 0.8842 - val_loss: 0.6372 - val_accuracy: 0.8630 - 15s/epoch - 692ms/step
# Epoch 216/300
# 22/22 - 15s - loss: 0.3647 - accuracy: 0.9059 - val_loss: 0.5384 - val_accuracy: 0.8630 - 15s/epoch - 691ms/step
# Epoch 217/300
# 22/22 - 15s - loss: 0.3713 - accuracy: 0.8813 - val_loss: 0.8167 - val_accuracy: 0.8219 - 15s/epoch - 682ms/step
# Epoch 218/300
# 22/22 - 15s - loss: 0.3723 - accuracy: 0.8842 - val_loss: 0.7396 - val_accuracy: 0.8082 - 15s/epoch - 678ms/step
# Epoch 219/300
# 22/22 - 15s - loss: 0.3809 - accuracy: 0.9001 - val_loss: 0.5390 - val_accuracy: 0.8493 - 15s/epoch - 670ms/step
# Epoch 220/300
# 22/22 - 15s - loss: 0.3620 - accuracy: 0.9001 - val_loss: 0.5720 - val_accuracy: 0.8219 - 15s/epoch - 686ms/step
# Epoch 221/300
# 22/22 - 16s - loss: 0.4054 - accuracy: 0.8784 - val_loss: 0.5698 - val_accuracy: 0.8356 - 16s/epoch - 709ms/step
# Epoch 222/300
# 22/22 - 15s - loss: 0.3696 - accuracy: 0.8886 - val_loss: 0.5471 - val_accuracy: 0.8219 - 15s/epoch - 702ms/step
# Epoch 223/300
# 22/22 - 15s - loss: 0.2809 - accuracy: 0.9117 - val_loss: 0.6626 - val_accuracy: 0.8219 - 15s/epoch - 698ms/step
# Epoch 224/300
# 22/22 - 15s - loss: 0.2617 - accuracy: 0.8987 - val_loss: 0.7274 - val_accuracy: 0.7808 - 15s/epoch - 678ms/step
# Epoch 225/300
# 22/22 - 15s - loss: 0.3028 - accuracy: 0.9161 - val_loss: 0.6878 - val_accuracy: 0.8219 - 15s/epoch - 684ms/step
# Epoch 226/300
# 22/22 - 16s - loss: 0.3727 - accuracy: 0.8755 - val_loss: 0.7009 - val_accuracy: 0.7808 - 16s/epoch - 712ms/step
# Epoch 227/300
# 22/22 - 15s - loss: 0.3575 - accuracy: 0.8886 - val_loss: 0.4831 - val_accuracy: 0.8767 - 15s/epoch - 680ms/step
# Epoch 228/300
# 22/22 - 15s - loss: 0.3669 - accuracy: 0.9016 - val_loss: 0.7377 - val_accuracy: 0.8219 - 15s/epoch - 665ms/step
# Epoch 229/300
# 22/22 - 15s - loss: 0.3380 - accuracy: 0.8958 - val_loss: 0.5007 - val_accuracy: 0.8767 - 15s/epoch - 666ms/step
# Epoch 230/300
# 22/22 - 15s - loss: 0.3608 - accuracy: 0.9117 - val_loss: 0.5507 - val_accuracy: 0.8356 - 15s/epoch - 661ms/step
# Epoch 231/300
# 22/22 - 15s - loss: 0.3017 - accuracy: 0.9117 - val_loss: 0.4984 - val_accuracy: 0.8630 - 15s/epoch - 674ms/step
# Epoch 232/300
# 22/22 - 15s - loss: 0.3751 - accuracy: 0.8842 - val_loss: 0.7173 - val_accuracy: 0.7945 - 15s/epoch - 700ms/step
# Epoch 233/300
# 22/22 - 16s - loss: 0.2821 - accuracy: 0.9204 - val_loss: 0.4735 - val_accuracy: 0.9041 - 16s/epoch - 736ms/step
# Epoch 234/300
# 22/22 - 15s - loss: 0.3782 - accuracy: 0.8813 - val_loss: 0.4621 - val_accuracy: 0.8219 - 15s/epoch - 689ms/step
# Epoch 235/300
# 22/22 - 16s - loss: 0.3721 - accuracy: 0.9016 - val_loss: 0.5646 - val_accuracy: 0.8356 - 16s/epoch - 729ms/step
# Epoch 236/300
# 22/22 - 15s - loss: 0.2300 - accuracy: 0.9175 - val_loss: 0.5368 - val_accuracy: 0.8630 - 15s/epoch - 673ms/step
# Epoch 237/300
# 22/22 - 15s - loss: 0.4010 - accuracy: 0.8915 - val_loss: 0.5422 - val_accuracy: 0.8493 - 15s/epoch - 662ms/step
# Epoch 238/300
# 22/22 - 15s - loss: 0.2994 - accuracy: 0.9146 - val_loss: 0.6255 - val_accuracy: 0.8082 - 15s/epoch - 662ms/step
# Epoch 239/300
# 22/22 - 15s - loss: 0.2348 - accuracy: 0.9363 - val_loss: 0.5808 - val_accuracy: 0.8082 - 15s/epoch - 667ms/step
# Epoch 240/300
# 22/22 - 15s - loss: 0.3599 - accuracy: 0.8987 - val_loss: 0.7158 - val_accuracy: 0.7808 - 15s/epoch - 668ms/step
# Epoch 241/300
# 22/22 - 15s - loss: 0.3857 - accuracy: 0.8799 - val_loss: 0.7030 - val_accuracy: 0.8082 - 15s/epoch - 664ms/step
# Epoch 242/300
# 22/22 - 15s - loss: 0.3129 - accuracy: 0.8958 - val_loss: 0.7036 - val_accuracy: 0.7945 - 15s/epoch - 672ms/step
# Epoch 243/300
# 22/22 - 15s - loss: 0.2964 - accuracy: 0.9175 - val_loss: 0.5311 - val_accuracy: 0.8630 - 15s/epoch - 663ms/step
# Epoch 244/300
# 22/22 - 15s - loss: 0.2617 - accuracy: 0.9262 - val_loss: 0.6011 - val_accuracy: 0.8219 - 15s/epoch - 662ms/step
# Epoch 245/300
# 22/22 - 15s - loss: 0.2732 - accuracy: 0.9132 - val_loss: 0.6384 - val_accuracy: 0.8356 - 15s/epoch - 670ms/step
# Epoch 246/300
# 22/22 - 15s - loss: 0.2871 - accuracy: 0.9146 - val_loss: 0.6377 - val_accuracy: 0.8082 - 15s/epoch - 670ms/step
# Epoch 247/300
# 22/22 - 15s - loss: 0.3807 - accuracy: 0.8973 - val_loss: 0.6231 - val_accuracy: 0.8493 - 15s/epoch - 665ms/step
# Epoch 248/300
# 22/22 - 15s - loss: 0.2977 - accuracy: 0.9030 - val_loss: 0.6210 - val_accuracy: 0.8082 - 15s/epoch - 675ms/step
# Epoch 249/300
# 22/22 - 15s - loss: 0.3244 - accuracy: 0.9146 - val_loss: 0.4922 - val_accuracy: 0.8630 - 15s/epoch - 680ms/step
# Epoch 250/300
# 22/22 - 15s - loss: 0.3505 - accuracy: 0.9016 - val_loss: 0.5676 - val_accuracy: 0.8630 - 15s/epoch - 688ms/step
# Epoch 251/300
# 22/22 - 15s - loss: 0.3249 - accuracy: 0.9103 - val_loss: 0.6534 - val_accuracy: 0.8493 - 15s/epoch - 673ms/step
# Epoch 252/300
# 22/22 - 15s - loss: 0.4028 - accuracy: 0.8987 - val_loss: 0.5264 - val_accuracy: 0.8767 - 15s/epoch - 664ms/step
# Epoch 253/300
# 22/22 - 16s - loss: 0.3334 - accuracy: 0.9132 - val_loss: 0.6415 - val_accuracy: 0.8493 - 16s/epoch - 726ms/step
# Epoch 254/300
# 22/22 - 15s - loss: 0.4595 - accuracy: 0.8799 - val_loss: 0.5848 - val_accuracy: 0.8082 - 15s/epoch - 682ms/step
# Epoch 255/300
# 22/22 - 16s - loss: 0.2860 - accuracy: 0.9233 - val_loss: 0.5808 - val_accuracy: 0.8493 - 16s/epoch - 721ms/step
# Epoch 256/300
# 22/22 - 16s - loss: 0.3705 - accuracy: 0.8973 - val_loss: 0.6570 - val_accuracy: 0.8493 - 16s/epoch - 710ms/step
# Epoch 257/300
# 22/22 - 15s - loss: 0.3330 - accuracy: 0.8958 - val_loss: 1.0188 - val_accuracy: 0.7534 - 15s/epoch - 694ms/step
# Epoch 258/300
# 22/22 - 15s - loss: 0.4388 - accuracy: 0.8886 - val_loss: 0.6840 - val_accuracy: 0.8219 - 15s/epoch - 693ms/step
# Epoch 259/300
# 22/22 - 15s - loss: 0.2707 - accuracy: 0.9146 - val_loss: 0.6605 - val_accuracy: 0.7945 - 15s/epoch - 670ms/step
# Epoch 260/300
# 22/22 - 15s - loss: 0.2365 - accuracy: 0.9219 - val_loss: 0.6864 - val_accuracy: 0.7808 - 15s/epoch - 686ms/step
# Epoch 261/300
# 22/22 - 15s - loss: 0.3599 - accuracy: 0.9030 - val_loss: 0.7439 - val_accuracy: 0.7808 - 15s/epoch - 677ms/step
# Epoch 262/300
# 22/22 - 15s - loss: 0.2944 - accuracy: 0.8944 - val_loss: 1.0245 - val_accuracy: 0.7534 - 15s/epoch - 673ms/step
# Epoch 263/300
# 22/22 - 15s - loss: 0.3363 - accuracy: 0.8929 - val_loss: 0.7650 - val_accuracy: 0.7945 - 15s/epoch - 666ms/step
# Epoch 264/300
# 22/22 - 15s - loss: 0.2585 - accuracy: 0.9276 - val_loss: 0.6574 - val_accuracy: 0.8082 - 15s/epoch - 666ms/step
# Epoch 265/300
# 22/22 - 15s - loss: 0.3232 - accuracy: 0.9103 - val_loss: 0.8936 - val_accuracy: 0.7808 - 15s/epoch - 667ms/step
# Epoch 266/300
# 22/22 - 15s - loss: 0.2231 - accuracy: 0.9132 - val_loss: 0.6025 - val_accuracy: 0.7808 - 15s/epoch - 665ms/step
# Epoch 267/300
# 22/22 - 15s - loss: 0.2640 - accuracy: 0.9103 - val_loss: 0.7579 - val_accuracy: 0.8082 - 15s/epoch - 668ms/step
# Epoch 268/300
# 22/22 - 15s - loss: 0.3085 - accuracy: 0.9045 - val_loss: 0.8200 - val_accuracy: 0.7671 - 15s/epoch - 669ms/step
# Epoch 269/300
# 22/22 - 15s - loss: 0.2862 - accuracy: 0.9190 - val_loss: 0.7949 - val_accuracy: 0.7808 - 15s/epoch - 666ms/step
# Epoch 270/300
# 22/22 - 15s - loss: 0.2802 - accuracy: 0.9103 - val_loss: 0.6030 - val_accuracy: 0.8082 - 15s/epoch - 665ms/step
# Epoch 271/300
# 22/22 - 15s - loss: 0.2836 - accuracy: 0.9045 - val_loss: 0.7125 - val_accuracy: 0.7945 - 15s/epoch - 667ms/step
# Epoch 272/300
# 22/22 - 15s - loss: 0.3012 - accuracy: 0.9074 - val_loss: 0.7167 - val_accuracy: 0.8082 - 15s/epoch - 674ms/step
# Epoch 273/300
# 22/22 - 15s - loss: 0.2756 - accuracy: 0.9219 - val_loss: 0.7907 - val_accuracy: 0.7945 - 15s/epoch - 683ms/step
# Epoch 274/300
# 22/22 - 15s - loss: 0.3035 - accuracy: 0.9233 - val_loss: 0.6993 - val_accuracy: 0.8219 - 15s/epoch - 668ms/step
# Epoch 275/300
# 22/22 - 15s - loss: 0.2584 - accuracy: 0.9276 - val_loss: 0.8752 - val_accuracy: 0.7808 - 15s/epoch - 681ms/step
# Epoch 276/300
# 22/22 - 15s - loss: 0.3415 - accuracy: 0.9001 - val_loss: 0.6906 - val_accuracy: 0.8219 - 15s/epoch - 663ms/step
# Epoch 277/300
# 22/22 - 15s - loss: 0.2661 - accuracy: 0.9175 - val_loss: 0.8499 - val_accuracy: 0.8082 - 15s/epoch - 679ms/step
# Epoch 278/300
# 22/22 - 15s - loss: 0.3393 - accuracy: 0.9059 - val_loss: 0.8372 - val_accuracy: 0.8082 - 15s/epoch - 701ms/step
# Epoch 279/300
# 22/22 - 15s - loss: 0.2223 - accuracy: 0.9334 - val_loss: 0.7843 - val_accuracy: 0.8082 - 15s/epoch - 682ms/step
# Epoch 280/300
# 22/22 - 15s - loss: 0.2894 - accuracy: 0.9074 - val_loss: 0.6610 - val_accuracy: 0.7945 - 15s/epoch - 680ms/step
# Epoch 281/300
# 22/22 - 15s - loss: 0.3912 - accuracy: 0.8900 - val_loss: 0.8158 - val_accuracy: 0.8082 - 15s/epoch - 672ms/step
# Epoch 282/300
# 22/22 - 15s - loss: 0.2516 - accuracy: 0.9262 - val_loss: 0.7238 - val_accuracy: 0.7808 - 15s/epoch - 684ms/step
# Epoch 283/300
# 22/22 - 15s - loss: 0.2727 - accuracy: 0.9088 - val_loss: 0.7381 - val_accuracy: 0.7808 - 15s/epoch - 679ms/step
# Epoch 284/300
# 22/22 - 15s - loss: 0.3467 - accuracy: 0.8958 - val_loss: 0.7783 - val_accuracy: 0.7671 - 15s/epoch - 666ms/step
# Epoch 285/300
# 22/22 - 15s - loss: 0.2811 - accuracy: 0.9088 - val_loss: 0.8838 - val_accuracy: 0.7534 - 15s/epoch - 666ms/step
# Epoch 286/300
# 22/22 - 15s - loss: 0.3228 - accuracy: 0.9059 - val_loss: 0.6626 - val_accuracy: 0.8082 - 15s/epoch - 698ms/step
# Epoch 287/300
# 22/22 - 15s - loss: 0.3577 - accuracy: 0.8900 - val_loss: 0.7258 - val_accuracy: 0.7808 - 15s/epoch - 688ms/step
# Epoch 288/300
# 22/22 - 15s - loss: 0.2543 - accuracy: 0.9320 - val_loss: 0.5601 - val_accuracy: 0.8219 - 15s/epoch - 702ms/step
# Epoch 289/300
# 22/22 - 15s - loss: 0.2838 - accuracy: 0.9059 - val_loss: 0.7356 - val_accuracy: 0.7808 - 15s/epoch - 697ms/step
# Epoch 290/300
# 22/22 - 15s - loss: 0.2796 - accuracy: 0.9045 - val_loss: 0.5315 - val_accuracy: 0.8356 - 15s/epoch - 698ms/step
# Epoch 291/300
# 22/22 - 16s - loss: 0.3104 - accuracy: 0.9059 - val_loss: 0.7763 - val_accuracy: 0.7945 - 16s/epoch - 710ms/step
# Epoch 292/300
# 22/22 - 15s - loss: 0.3297 - accuracy: 0.9074 - val_loss: 0.6302 - val_accuracy: 0.8219 - 15s/epoch - 678ms/step
# Epoch 293/300
# 22/22 - 15s - loss: 0.3435 - accuracy: 0.8886 - val_loss: 0.7087 - val_accuracy: 0.7671 - 15s/epoch - 672ms/step
# Epoch 294/300
# 22/22 - 15s - loss: 0.3027 - accuracy: 0.8958 - val_loss: 0.6346 - val_accuracy: 0.8082 - 15s/epoch - 694ms/step
# Epoch 295/300
# 22/22 - 15s - loss: 0.2875 - accuracy: 0.9161 - val_loss: 0.6708 - val_accuracy: 0.8219 - 15s/epoch - 686ms/step
# Epoch 296/300
# 22/22 - 16s - loss: 0.2750 - accuracy: 0.9074 - val_loss: 0.8825 - val_accuracy: 0.7808 - 16s/epoch - 750ms/step
# Epoch 297/300
# 22/22 - 15s - loss: 0.3531 - accuracy: 0.9059 - val_loss: 0.5855 - val_accuracy: 0.8493 - 15s/epoch - 697ms/step
# Epoch 298/300
# 22/22 - 15s - loss: 0.3332 - accuracy: 0.8958 - val_loss: 0.9268 - val_accuracy: 0.7671 - 15s/epoch - 666ms/step
# Epoch 299/300
# 22/22 - 15s - loss: 0.3128 - accuracy: 0.9103 - val_loss: 0.6176 - val_accuracy: 0.7671 - 15s/epoch - 672ms/step
# Epoch 300/300
# 22/22 - 15s - loss: 0.3458 - accuracy: 0.8973 - val_loss: 0.7874 - val_accuracy: 0.7808 - 15s/epoch - 672ms/step

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# OPTIONAL: Decide if best weights should be loaded from previous model based on val_acc
# The model weights (that are considered the best) are loaded into the model.
result = model.load_weights(checkpoint_filepath)

# %% [markdown]
# <h3>Evaluate Test data</h3>

# %%
print(sum(cb.logs) / 150)

testLoss, testAcc = model.evaluate(test)
print('''
Test Loss: {}
Test Accuracy: {}
'''.format(testLoss, testAcc))
# Out:
# 30.40317343200043
# 3/3 [==============================] - 2s 546ms/step - loss: 1.1465 - accuracy: 0.8202
#
# Test Loss: 1.1465157270431519
# Test Accuracy: 0.8202247023582458

# %% [markdown]
# <h4>*Optional - Fine tune model with two-step training*</h4>

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

mobile.trainable = True

for layer in mobile.layers[:-2]:
    layer.trainable = False
    
#re-train the model at a very low learning rate
model.compile(optimizer=Adam(learning_rate=0.00006), loss='categorical_crossentropy', metrics=['accuracy'])

result = model.fit(x=train, validation_data=validation, epochs=100, verbose=2, callbacks=[cb, es])
# Out:
# Epoch 1/100
# 22/22 - 19s - loss: 0.3443 - accuracy: 0.9103 - val_loss: 0.5278 - val_accuracy: 0.9041 - 19s/epoch - 868ms/step
# Epoch 2/100
# 22/22 - 15s - loss: 0.2989 - accuracy: 0.9030 - val_loss: 0.5267 - val_accuracy: 0.9041 - 15s/epoch - 697ms/step
# Epoch 3/100
# 22/22 - 15s - loss: 0.2498 - accuracy: 0.9175 - val_loss: 0.5264 - val_accuracy: 0.9041 - 15s/epoch - 699ms/step
# Epoch 4/100
# 22/22 - 16s - loss: 0.2743 - accuracy: 0.9247 - val_loss: 0.5265 - val_accuracy: 0.9041 - 16s/epoch - 727ms/step
# Epoch 5/100
# 22/22 - 15s - loss: 0.2673 - accuracy: 0.9233 - val_loss: 0.5277 - val_accuracy: 0.9041 - 15s/epoch - 704ms/step
# Epoch 6/100
# 22/22 - 15s - loss: 0.2998 - accuracy: 0.9074 - val_loss: 0.5267 - val_accuracy: 0.9041 - 15s/epoch - 692ms/step
# Epoch 7/100
# 22/22 - 15s - loss: 0.2351 - accuracy: 0.9305 - val_loss: 0.5255 - val_accuracy: 0.9041 - 15s/epoch - 686ms/step
# Epoch 8/100
# 22/22 - 15s - loss: 0.2819 - accuracy: 0.9146 - val_loss: 0.5268 - val_accuracy: 0.9041 - 15s/epoch - 683ms/step
# Epoch 9/100
# 22/22 - 16s - loss: 0.3528 - accuracy: 0.8973 - val_loss: 0.5281 - val_accuracy: 0.8904 - 16s/epoch - 705ms/step
# Epoch 10/100
# 22/22 - 15s - loss: 0.3256 - accuracy: 0.9161 - val_loss: 0.5285 - val_accuracy: 0.8904 - 15s/epoch - 678ms/step
# Epoch 11/100
# 22/22 - 15s - loss: 0.3093 - accuracy: 0.9103 - val_loss: 0.5309 - val_accuracy: 0.8904 - 15s/epoch - 679ms/step
# Epoch 12/100
# 22/22 - 15s - loss: 0.2925 - accuracy: 0.9146 - val_loss: 0.5325 - val_accuracy: 0.8904 - 15s/epoch - 683ms/step
# Epoch 13/100
# 22/22 - 15s - loss: 0.2759 - accuracy: 0.9161 - val_loss: 0.5328 - val_accuracy: 0.9041 - 15s/epoch - 692ms/step
# Epoch 14/100
# 22/22 - 15s - loss: 0.2462 - accuracy: 0.9233 - val_loss: 0.5340 - val_accuracy: 0.9041 - 15s/epoch - 688ms/step
# Epoch 15/100
# 22/22 - 15s - loss: 0.1971 - accuracy: 0.9305 - val_loss: 0.5348 - val_accuracy: 0.9041 - 15s/epoch - 684ms/step
# Epoch 16/100
# 22/22 - 15s - loss: 0.2734 - accuracy: 0.9233 - val_loss: 0.5366 - val_accuracy: 0.9041 - 15s/epoch - 674ms/step
# Epoch 17/100
# 22/22 - 15s - loss: 0.2789 - accuracy: 0.9161 - val_loss: 0.5371 - val_accuracy: 0.9041 - 15s/epoch - 672ms/step
# Epoch 17: early stopping

# %% [markdown]
# <h3>Accuracy and Loss graph</h3>

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# <h3>Classification report</h3>

# %%
predictions = model.predict(test, verbose=0)
# predictions = predictions.reshape(1,-1)[0]
lst = np.argmax(predictions, axis= 1)

print(classification_report(test.classes, lst, target_names = test.class_indices))
# Out:
#               precision    recall  f1-score   support
#
#     Duracell       0.93      0.93      0.93        14
#    Energizer       1.00      1.00      1.00        14
#     Eveready       0.90      0.90      0.90        10
#        Exell       0.70      0.78      0.74         9
#           GP       0.75      0.75      0.75        12
#         Ikea       1.00      0.78      0.88         9
#       Klarus       0.89      0.73      0.80        11
#    Panasonic       0.69      0.90      0.78        10
#
#     accuracy                           0.85        89
#    macro avg       0.86      0.85      0.85        89
# weighted avg       0.87      0.85      0.86        89

# %% [markdown]
# <h3>Confusion matrix</h3>

# %%
result = confusion_matrix(test.classes, lst)
print(result)

def plot_confusion_matrix(result, classes, cmap=plt.cm.Blues):
    plt.subplots(figsize=(7, 7))
    plt.imshow(result, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

    thresh = result.max() / 2.
    for i, j in itertools.product(range(result.shape[0]), range(result.shape[1])):
        plt.text(j, i, result[i, j],
            horizontalalignment="center",
            color = "white" if result[i, j] > thresh else "black")
        
    #current matplotlib version will cut off top and bottom of the matrix, 
    #hence the manual workaround - remove if matplotlib version does not cut off
    b, t = plt.ylim() # discover bottom and top values
    b += 0.5 # Add 0.5 to bottom
    t -= 0.5 # Subtract 0.5 from top
    plt.ylim(b, t) # update ylim(bottom, top) values
    plt.show()
    
plot_confusion_matrix(result, list(test.class_indices.keys()))
# Out:
# [[13  0  1  0  0  0  0  0]
#  [ 0 14  0  0  0  0  0  0]
#  [ 0  0  9  0  0  0  0  1]
#  [ 0  0  0  7  1  0  1  0]
#  [ 0  0  0  2  9  0  0  1]
#  [ 0  0  0  1  1  7  0  0]
#  [ 1  0  0  0  0  0  8  2]
#  [ 0  0  0  0  1  0  0  9]]

# %% [markdown]
# <h3>Labels of wrong predictions</h3>

# %%
def getErrors(test, predictions):
    #get file names of all images in test data
    names = test.filenames

    #get IDs of all classes
    allClassesID = test.classes

    #get dictionary of classes and respective ID
    classLabelDict = test.class_indices
    
    #list of the names of all classes
    classLabels = list(classLabelDict.keys())

    print("The list of classes: ", classLabels)

    #get the most predicted class
    predictedClasses = np.argmax(predictions, axis=1)

    predictedErrors = np.where(predictedClasses != allClassesID)[0]

    print("Number of errors = {}/{}".format(len(predictedErrors),test.samples))

    return classLabels, predictedErrors, names

def showErrors(classLabels, predictedErrors, predictions, names):
    # Show the errors
    for i in range(len(errors)):
        predictedClass = np.argmax(predictions[predictedErrors[i]])

        predictedLabel = classLabels[predictedClass]

        title = 'Original Picture : {}, Prediction : {}, Confidence/Percentage : {:.3f}'.format\
                (names[predictedErrors[i]].split('/')[0],predictedLabel, predictions[errors[i]][predictedClass])
        print(title)

# %%
#get the list of class labels, prediction errors and file names
labels, errors, names = getErrors(test, predictions)

#show wrongly predicted images, prediction and and the percentage (confidence)
showErrors(labels, errors, predictions, names)
# Out:
# The list of classes:  ['Duracell', 'Energizer', 'Eveready', 'Exell', 'GP', 'Ikea', 'Klarus', 'Panasonic']
# Number of errors = 13/89
# Original Picture : Duracell\Image_50.jpg, Prediction : Eveready, Confidence/Percentage : 0.837
# Original Picture : Eveready\DSC_2030.jpg, Prediction : Panasonic, Confidence/Percentage : 0.500
# Original Picture : Exell\8.jpeg, Prediction : Klarus, Confidence/Percentage : 0.965
# Original Picture : Exell\Image_46.jpg, Prediction : GP, Confidence/Percentage : 1.000
# Original Picture : GP\23ae-500x500.jpg, Prediction : Exell, Confidence/Percentage : 0.821
# Original Picture : GP\9d4010b8-4047-4e5a-bc07-be0aca58ccea_1.094afa6d44f180aac038afafea59ca6a.jpg, Prediction : Panasonic, Confidence/Percentage : 0.929
# Original Picture : GP\image.jpg, Prediction : Exell, Confidence/Percentage : 0.865
# Original Picture : Ikea\2fwkb86.jpg, Prediction : Exell, Confidence/Percentage : 0.796
# Original Picture : Ikea\Image_28.jpg, Prediction : GP, Confidence/Percentage : 0.967
# Original Picture : Klarus\11.jpg, Prediction : Panasonic, Confidence/Percentage : 0.686
# Original Picture : Klarus\Image_21.jpg, Prediction : Panasonic, Confidence/Percentage : 0.608
# Original Picture : Klarus\Image_31.jpg, Prediction : Duracell, Confidence/Percentage : 0.897
# Original Picture : Panasonic\Image_62.jpg, Prediction : GP, Confidence/Percentage : 0.982

# %% [markdown]
# <h3>Save the model</h3>

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model so that it can be passed to edge device
model.save("image_classification.h5")
