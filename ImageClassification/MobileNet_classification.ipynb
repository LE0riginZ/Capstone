# %% [markdown]
# <h3>Import packages</h3>

# %%
from datetime import date
from timeit import default_timer as timer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import imagenet_utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Configure TensorFlow to use GPU for training
tf.config.list_physical_devices('GPU') 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
#Set GPU memory limit so my GPU doesn't crash
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <h3>Create class to record time taken to train the model</h3>

# %%
#class to record time taken to train per epoch
class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# <h3>Create train and test folder</h3>

# %%
#creates a folder each time the set of code is run to sort dataset into train and test
day = date.today()
formatDate = day.strftime("%b-%d-%Y")

#create folder with current date to group predictions ran in a day together, if it does not exists
if os.path.isdir('Prediction (' + formatDate + ')') is False:
    folder = os.mkdir('Prediction (' + formatDate + ')')
folder = 'Prediction (' + formatDate + ')'

#looping through to find if destination folder exists
i = 1
while True:
    if os.path.isdir(folder + '/Battery Images - ' + str(i)) is False:
        break
    i += 1

#destination path for unsorted folder
destination = folder + '/Battery Images - ' + str(i)

#source path for unsorted folder
# source = 'Battery Images/'
# source = 'Battery Images [Old]/'
# source = 'Battery Images [StreamLined]/'
source = 'Battery Images [Download]/'

#duplicate the unsorted folder from source to destination
shutil.copytree(source, destination)

os.mkdir(destination + '/train')
os.mkdir(destination + '/test')

# %% [markdown]
# <h3>Sort dataset into train and test folder</h3>

# %%
#function to split images into training (80%) and testing (20%) and return both
def split(data):
    # num = int(len(data) * 0.8)
    num = int(len(data) * 0.9) #90/10 split
#     num = int(len(data) * 0.7) #70/30 split
    random.shuffle(data)
    return data[:num], data[num:]

dir = os.chdir(destination)
for category in os.listdir(dir):
    #skip the iteration if folder is "train" or "test"
    skip = ['train', 'test']
    if category in skip:
        continue
    
    shutil.move(f'{category}', 'train')
    #create a subfolder with the same name in test
    os.mkdir(f'test/{category}')

    #get the images in each folder (battery type) for spltting of data into training and testing
    img = os.listdir(f'train/{category}')
    training, testing = split(img)
    
    for file in testing:
        shutil.move(f'train/{category}/{file}', f'test/{category}')

# %% [markdown]
# <h3>b) Transfer Learning - MobileNet</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.mobilenet.MobileNet(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
mobile.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
# =================================================================
# Total params: 3,228,864
# Trainable params: 3,206,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
for layer in mobile.layers[:-2]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = mobile(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
# x = tf.keras.layers.Dropout(0.65)(x) #Higher dropout to reduce overfitting (last best setting)
# output = tf.keras.layers.Dense(5, activation="softmax")(x)   
# output = tf.keras.layers.Dense(10, activation="softmax")(x)   #Changed to reflect new categories
output = tf.keras.layers.Dense(8, activation="softmax")(x)   #Changed to reflect new categories

model = keras.Model(inputs, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 8)                 8200
#
# =================================================================
# Total params: 3,237,064
# Trainable params: 10,248
# Non-trainable params: 3,226,816
# _________________________________________________________________

# %% [markdown]
# <h3>Process data</h3>

# %%
train_path = 'train'
test_path = 'test'

#for data augmentation on training data
datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet.preprocess_input,
    # validation_split=0.2,
    validation_split=0.1, #changes made for 90/10 split
    rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.2, # Randomly zoom image 
    width_shift_range = 0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range = 0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip = True,  # randomly flip images
#     vertical_flip = False,    # randomly flip images
    vertical_flip = True, #include vertical flip for better generalisation
    )  

#takes images from directory path and generates batches of augmented data
train = datagen.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='training',
        shuffle = False)

#for validation data
# validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
#                                         validation_split=0.2)
validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
                                        validation_split=0.1) #changes made for 90/10 split


validation = validation_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='validation',
        shuffle = False)

#for test data
test = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input)\
.flow_from_directory(directory=test_path, target_size=(224,224), batch_size=32, shuffle=False)
# Out:
# Found 691 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 89 images belonging to 8 classes.

# %% [markdown]
# <h3>Train model</h3>

# %%
model.compile(optimizer=Adam(learning_rate=0.006), loss='categorical_crossentropy', metrics=['accuracy']) #Last best setting
# model.compile(optimizer=Adam(learning_rate=0.0045), loss='categorical_crossentropy', metrics=['accuracy']) #Lower LR
# model.compile(optimizer=Adam(learning_rate=0.0075), loss='categorical_crossentropy', metrics=['accuracy']) 
checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True) #save best model

#more epochs for better results
result = model.fit(x=train, validation_data=validation, epochs=300, verbose=2, callbacks=[model_checkpoint_callback,cb])
# result = model.fit(x=train, validation_data=validation, epochs=200, verbose=2, callbacks=[cb])
# Out:
# Epoch 1/300
# c:\Users\ngden\anaconda3\lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 22/22 - 28s - loss: 7.5817 - accuracy: 0.0463 - val_loss: 2.8927 - val_accuracy: 0.1781 - 28s/epoch - 1s/step
# Epoch 2/300
# 22/22 - 16s - loss: 3.6496 - accuracy: 0.2721 - val_loss: 2.1462 - val_accuracy: 0.4521 - 16s/epoch - 742ms/step
# Epoch 3/300
# 22/22 - 15s - loss: 2.8127 - accuracy: 0.3647 - val_loss: 2.2376 - val_accuracy: 0.3973 - 15s/epoch - 673ms/step
# Epoch 4/300
# 22/22 - 15s - loss: 1.8861 - accuracy: 0.5036 - val_loss: 0.9877 - val_accuracy: 0.6164 - 15s/epoch - 682ms/step
# Epoch 5/300
# 22/22 - 15s - loss: 1.6341 - accuracy: 0.5123 - val_loss: 1.6147 - val_accuracy: 0.6164 - 15s/epoch - 662ms/step
# Epoch 6/300
# 22/22 - 15s - loss: 2.1129 - accuracy: 0.4935 - val_loss: 1.5733 - val_accuracy: 0.6438 - 15s/epoch - 680ms/step
# Epoch 7/300
# 22/22 - 15s - loss: 1.6430 - accuracy: 0.5832 - val_loss: 1.0766 - val_accuracy: 0.6027 - 15s/epoch - 667ms/step
# Epoch 8/300
# 22/22 - 15s - loss: 0.9336 - accuracy: 0.7091 - val_loss: 0.8066 - val_accuracy: 0.7260 - 15s/epoch - 676ms/step
# Epoch 9/300
# 22/22 - 15s - loss: 1.0815 - accuracy: 0.6541 - val_loss: 1.0386 - val_accuracy: 0.6027 - 15s/epoch - 670ms/step
# Epoch 10/300
# 22/22 - 15s - loss: 1.4894 - accuracy: 0.5847 - val_loss: 1.2788 - val_accuracy: 0.5616 - 15s/epoch - 698ms/step
# Epoch 11/300
# 22/22 - 16s - loss: 1.5130 - accuracy: 0.5847 - val_loss: 1.5028 - val_accuracy: 0.6301 - 16s/epoch - 710ms/step
# Epoch 12/300
# 22/22 - 17s - loss: 1.2246 - accuracy: 0.6281 - val_loss: 1.5346 - val_accuracy: 0.6301 - 17s/epoch - 791ms/step
# Epoch 13/300
# 22/22 - 17s - loss: 0.8848 - accuracy: 0.7352 - val_loss: 0.8715 - val_accuracy: 0.7260 - 17s/epoch - 766ms/step
# Epoch 14/300
# 22/22 - 17s - loss: 0.8017 - accuracy: 0.7482 - val_loss: 1.4282 - val_accuracy: 0.6575 - 17s/epoch - 779ms/step
# Epoch 15/300
# 22/22 - 17s - loss: 1.0297 - accuracy: 0.6961 - val_loss: 1.0245 - val_accuracy: 0.7123 - 17s/epoch - 782ms/step
# Epoch 16/300
# 22/22 - 16s - loss: 0.7560 - accuracy: 0.7757 - val_loss: 0.8151 - val_accuracy: 0.6712 - 16s/epoch - 748ms/step
# Epoch 17/300
# 22/22 - 16s - loss: 0.7832 - accuracy: 0.7569 - val_loss: 0.8176 - val_accuracy: 0.7397 - 16s/epoch - 749ms/step
# Epoch 18/300
# 22/22 - 16s - loss: 0.9755 - accuracy: 0.7164 - val_loss: 1.1930 - val_accuracy: 0.6438 - 16s/epoch - 741ms/step
# Epoch 19/300
# 22/22 - 15s - loss: 1.0099 - accuracy: 0.6831 - val_loss: 0.8706 - val_accuracy: 0.7534 - 15s/epoch - 700ms/step
# Epoch 20/300
# 22/22 - 15s - loss: 0.7407 - accuracy: 0.7713 - val_loss: 0.6998 - val_accuracy: 0.7397 - 15s/epoch - 691ms/step
# Epoch 21/300
# 22/22 - 15s - loss: 0.5371 - accuracy: 0.8307 - val_loss: 0.6241 - val_accuracy: 0.8082 - 15s/epoch - 682ms/step
# Epoch 22/300
# 22/22 - 15s - loss: 0.5397 - accuracy: 0.8119 - val_loss: 0.6511 - val_accuracy: 0.7260 - 15s/epoch - 681ms/step
# Epoch 23/300
# 22/22 - 15s - loss: 0.6890 - accuracy: 0.7786 - val_loss: 0.7237 - val_accuracy: 0.7123 - 15s/epoch - 692ms/step
# Epoch 24/300
# 22/22 - 16s - loss: 0.7010 - accuracy: 0.7612 - val_loss: 0.8196 - val_accuracy: 0.7260 - 16s/epoch - 709ms/step
# Epoch 25/300
# 22/22 - 15s - loss: 0.6230 - accuracy: 0.7974 - val_loss: 1.1583 - val_accuracy: 0.7123 - 15s/epoch - 704ms/step
# Epoch 26/300
# 22/22 - 16s - loss: 0.7166 - accuracy: 0.8090 - val_loss: 0.6731 - val_accuracy: 0.7260 - 16s/epoch - 707ms/step
# Epoch 27/300
# 22/22 - 16s - loss: 0.8608 - accuracy: 0.7844 - val_loss: 1.3792 - val_accuracy: 0.6712 - 16s/epoch - 706ms/step
# Epoch 28/300
# 22/22 - 16s - loss: 1.2506 - accuracy: 0.7106 - val_loss: 1.5170 - val_accuracy: 0.6027 - 16s/epoch - 706ms/step
# Epoch 29/300
# 22/22 - 15s - loss: 0.9868 - accuracy: 0.7192 - val_loss: 1.0306 - val_accuracy: 0.6986 - 15s/epoch - 700ms/step
# Epoch 30/300
# 22/22 - 15s - loss: 0.6470 - accuracy: 0.8017 - val_loss: 0.6050 - val_accuracy: 0.7945 - 15s/epoch - 690ms/step
# Epoch 31/300
# 22/22 - 15s - loss: 0.6036 - accuracy: 0.8090 - val_loss: 0.7594 - val_accuracy: 0.6986 - 15s/epoch - 697ms/step
# Epoch 32/300
# 22/22 - 15s - loss: 0.5777 - accuracy: 0.8061 - val_loss: 0.6821 - val_accuracy: 0.7397 - 15s/epoch - 700ms/step
# Epoch 33/300
# 22/22 - 15s - loss: 0.4373 - accuracy: 0.8509 - val_loss: 0.9262 - val_accuracy: 0.7123 - 15s/epoch - 687ms/step
# Epoch 34/300
# 22/22 - 15s - loss: 0.7454 - accuracy: 0.7771 - val_loss: 1.3297 - val_accuracy: 0.6849 - 15s/epoch - 687ms/step
# Epoch 35/300
# 22/22 - 15s - loss: 0.7085 - accuracy: 0.7959 - val_loss: 0.6124 - val_accuracy: 0.7945 - 15s/epoch - 693ms/step
# Epoch 36/300
# 22/22 - 15s - loss: 0.6769 - accuracy: 0.7945 - val_loss: 0.8694 - val_accuracy: 0.7534 - 15s/epoch - 685ms/step
# Epoch 37/300
# 22/22 - 15s - loss: 0.5421 - accuracy: 0.8249 - val_loss: 0.7572 - val_accuracy: 0.7808 - 15s/epoch - 698ms/step
# Epoch 38/300
# 22/22 - 15s - loss: 0.4137 - accuracy: 0.8596 - val_loss: 0.7007 - val_accuracy: 0.7945 - 15s/epoch - 690ms/step
# Epoch 39/300
# 22/22 - 15s - loss: 0.5748 - accuracy: 0.7974 - val_loss: 0.7992 - val_accuracy: 0.7671 - 15s/epoch - 691ms/step
# Epoch 40/300
# 22/22 - 15s - loss: 0.5289 - accuracy: 0.8249 - val_loss: 0.7777 - val_accuracy: 0.7534 - 15s/epoch - 705ms/step
# Epoch 41/300
# 22/22 - 15s - loss: 0.5255 - accuracy: 0.8191 - val_loss: 0.9324 - val_accuracy: 0.7671 - 15s/epoch - 690ms/step
# Epoch 42/300
# 22/22 - 15s - loss: 0.6076 - accuracy: 0.7873 - val_loss: 0.6131 - val_accuracy: 0.7534 - 15s/epoch - 685ms/step
# Epoch 43/300
# 22/22 - 15s - loss: 0.4641 - accuracy: 0.8480 - val_loss: 0.9552 - val_accuracy: 0.7534 - 15s/epoch - 680ms/step
# Epoch 44/300
# 22/22 - 15s - loss: 0.6904 - accuracy: 0.7742 - val_loss: 1.0665 - val_accuracy: 0.6986 - 15s/epoch - 686ms/step
# Epoch 45/300
# 22/22 - 15s - loss: 0.6884 - accuracy: 0.7786 - val_loss: 0.5773 - val_accuracy: 0.7945 - 15s/epoch - 678ms/step
# Epoch 46/300
# 22/22 - 15s - loss: 0.8165 - accuracy: 0.7525 - val_loss: 0.8228 - val_accuracy: 0.7671 - 15s/epoch - 682ms/step
# Epoch 47/300
# 22/22 - 15s - loss: 0.7596 - accuracy: 0.7786 - val_loss: 0.9909 - val_accuracy: 0.7123 - 15s/epoch - 692ms/step
# Epoch 48/300
# 22/22 - 15s - loss: 0.5955 - accuracy: 0.8177 - val_loss: 0.9151 - val_accuracy: 0.7808 - 15s/epoch - 696ms/step
# Epoch 49/300
# 22/22 - 15s - loss: 0.4649 - accuracy: 0.8278 - val_loss: 0.6829 - val_accuracy: 0.7671 - 15s/epoch - 685ms/step
# Epoch 50/300
# 22/22 - 15s - loss: 0.4253 - accuracy: 0.8567 - val_loss: 0.5461 - val_accuracy: 0.8082 - 15s/epoch - 681ms/step
# Epoch 51/300
# 22/22 - 15s - loss: 0.4120 - accuracy: 0.8524 - val_loss: 0.7533 - val_accuracy: 0.7671 - 15s/epoch - 684ms/step
# Epoch 52/300
# 22/22 - 15s - loss: 0.4550 - accuracy: 0.8582 - val_loss: 0.6904 - val_accuracy: 0.7808 - 15s/epoch - 686ms/step
# Epoch 53/300
# 22/22 - 15s - loss: 0.4587 - accuracy: 0.8582 - val_loss: 0.6438 - val_accuracy: 0.7671 - 15s/epoch - 681ms/step
# Epoch 54/300
# 22/22 - 15s - loss: 0.4889 - accuracy: 0.8321 - val_loss: 0.7578 - val_accuracy: 0.7671 - 15s/epoch - 683ms/step
# Epoch 55/300
# 22/22 - 15s - loss: 0.5113 - accuracy: 0.8466 - val_loss: 0.7177 - val_accuracy: 0.7808 - 15s/epoch - 688ms/step
# Epoch 56/300
# 22/22 - 15s - loss: 0.4572 - accuracy: 0.8538 - val_loss: 0.9672 - val_accuracy: 0.7671 - 15s/epoch - 684ms/step
# Epoch 57/300
# 22/22 - 15s - loss: 0.6032 - accuracy: 0.8292 - val_loss: 0.5859 - val_accuracy: 0.7534 - 15s/epoch - 661ms/step
# Epoch 58/300
# 22/22 - 14s - loss: 0.4782 - accuracy: 0.8437 - val_loss: 1.0061 - val_accuracy: 0.7260 - 14s/epoch - 652ms/step
# Epoch 59/300
# 22/22 - 14s - loss: 0.4362 - accuracy: 0.8582 - val_loss: 0.7181 - val_accuracy: 0.6986 - 14s/epoch - 659ms/step
# Epoch 60/300
# 22/22 - 14s - loss: 0.4327 - accuracy: 0.8423 - val_loss: 0.7819 - val_accuracy: 0.7671 - 14s/epoch - 652ms/step
# Epoch 61/300
# 22/22 - 14s - loss: 0.3772 - accuracy: 0.8813 - val_loss: 0.6804 - val_accuracy: 0.7534 - 14s/epoch - 651ms/step
# Epoch 62/300
# 22/22 - 14s - loss: 0.5032 - accuracy: 0.8553 - val_loss: 0.6063 - val_accuracy: 0.8082 - 14s/epoch - 653ms/step
# Epoch 63/300
# 22/22 - 15s - loss: 0.5900 - accuracy: 0.8220 - val_loss: 1.3205 - val_accuracy: 0.7534 - 15s/epoch - 661ms/step
# Epoch 64/300
# 22/22 - 14s - loss: 0.4957 - accuracy: 0.8379 - val_loss: 0.5993 - val_accuracy: 0.7808 - 14s/epoch - 657ms/step
# Epoch 65/300
# 22/22 - 15s - loss: 0.4819 - accuracy: 0.8394 - val_loss: 0.8334 - val_accuracy: 0.7534 - 15s/epoch - 662ms/step
# Epoch 66/300
# 22/22 - 15s - loss: 0.5572 - accuracy: 0.8046 - val_loss: 0.8151 - val_accuracy: 0.7808 - 15s/epoch - 661ms/step
# Epoch 67/300
# 22/22 - 14s - loss: 0.5502 - accuracy: 0.8234 - val_loss: 1.2537 - val_accuracy: 0.7397 - 14s/epoch - 654ms/step
# Epoch 68/300
# 22/22 - 14s - loss: 0.6135 - accuracy: 0.8162 - val_loss: 0.5085 - val_accuracy: 0.8219 - 14s/epoch - 659ms/step
# Epoch 69/300
# 22/22 - 15s - loss: 0.5195 - accuracy: 0.8524 - val_loss: 0.6317 - val_accuracy: 0.7808 - 15s/epoch - 666ms/step
# Epoch 70/300
# 22/22 - 14s - loss: 0.4991 - accuracy: 0.8234 - val_loss: 0.8592 - val_accuracy: 0.7808 - 14s/epoch - 655ms/step
# Epoch 71/300
# 22/22 - 14s - loss: 0.4916 - accuracy: 0.8466 - val_loss: 0.5748 - val_accuracy: 0.7671 - 14s/epoch - 658ms/step
# Epoch 72/300
# 22/22 - 14s - loss: 0.5300 - accuracy: 0.8394 - val_loss: 0.9250 - val_accuracy: 0.7808 - 14s/epoch - 654ms/step
# Epoch 73/300
# 22/22 - 14s - loss: 0.3738 - accuracy: 0.8900 - val_loss: 0.7135 - val_accuracy: 0.7671 - 14s/epoch - 652ms/step
# Epoch 74/300
# 22/22 - 14s - loss: 0.4119 - accuracy: 0.8712 - val_loss: 0.8631 - val_accuracy: 0.7534 - 14s/epoch - 655ms/step
# Epoch 75/300
# 22/22 - 14s - loss: 0.4431 - accuracy: 0.8466 - val_loss: 0.7498 - val_accuracy: 0.7945 - 14s/epoch - 656ms/step
# Epoch 76/300
# 22/22 - 14s - loss: 0.4262 - accuracy: 0.8712 - val_loss: 0.6087 - val_accuracy: 0.7671 - 14s/epoch - 656ms/step
# Epoch 77/300
# 22/22 - 15s - loss: 0.4713 - accuracy: 0.8582 - val_loss: 1.0027 - val_accuracy: 0.7534 - 15s/epoch - 663ms/step
# Epoch 78/300
# 22/22 - 16s - loss: 0.6900 - accuracy: 0.7931 - val_loss: 0.7280 - val_accuracy: 0.8082 - 16s/epoch - 705ms/step
# Epoch 79/300
# 22/22 - 15s - loss: 0.5806 - accuracy: 0.8191 - val_loss: 1.0085 - val_accuracy: 0.7123 - 15s/epoch - 696ms/step
# Epoch 80/300
# 22/22 - 17s - loss: 0.5758 - accuracy: 0.8321 - val_loss: 0.6292 - val_accuracy: 0.7671 - 17s/epoch - 751ms/step
# Epoch 81/300
# 22/22 - 15s - loss: 0.3966 - accuracy: 0.8625 - val_loss: 0.8971 - val_accuracy: 0.7671 - 15s/epoch - 702ms/step
# Epoch 82/300
# 22/22 - 15s - loss: 0.3744 - accuracy: 0.8842 - val_loss: 0.7650 - val_accuracy: 0.7534 - 15s/epoch - 697ms/step
# Epoch 83/300
# 22/22 - 16s - loss: 0.4956 - accuracy: 0.8596 - val_loss: 0.7167 - val_accuracy: 0.7808 - 16s/epoch - 726ms/step
# Epoch 84/300
# 22/22 - 16s - loss: 0.3905 - accuracy: 0.8755 - val_loss: 0.7865 - val_accuracy: 0.7808 - 16s/epoch - 716ms/step
# Epoch 85/300
# 22/22 - 16s - loss: 0.4498 - accuracy: 0.8669 - val_loss: 0.7542 - val_accuracy: 0.7260 - 16s/epoch - 708ms/step
# Epoch 86/300
# 22/22 - 15s - loss: 0.4549 - accuracy: 0.8741 - val_loss: 1.0556 - val_accuracy: 0.7397 - 15s/epoch - 696ms/step
# Epoch 87/300
# 22/22 - 16s - loss: 0.4717 - accuracy: 0.8495 - val_loss: 0.6381 - val_accuracy: 0.7671 - 16s/epoch - 739ms/step
# Epoch 88/300
# 22/22 - 15s - loss: 0.4889 - accuracy: 0.8408 - val_loss: 0.9323 - val_accuracy: 0.7123 - 15s/epoch - 701ms/step
# Epoch 89/300
# 22/22 - 16s - loss: 0.4012 - accuracy: 0.8799 - val_loss: 0.7163 - val_accuracy: 0.7671 - 16s/epoch - 718ms/step
# Epoch 90/300
# 22/22 - 16s - loss: 0.3769 - accuracy: 0.8784 - val_loss: 0.8806 - val_accuracy: 0.7671 - 16s/epoch - 725ms/step
# Epoch 91/300
# 22/22 - 16s - loss: 0.4067 - accuracy: 0.8553 - val_loss: 0.7896 - val_accuracy: 0.7534 - 16s/epoch - 728ms/step
# Epoch 92/300
# 22/22 - 17s - loss: 0.3716 - accuracy: 0.8900 - val_loss: 0.7490 - val_accuracy: 0.7808 - 17s/epoch - 775ms/step
# Epoch 93/300
# 22/22 - 16s - loss: 0.4566 - accuracy: 0.8582 - val_loss: 0.7227 - val_accuracy: 0.7808 - 16s/epoch - 741ms/step
# Epoch 94/300
# 22/22 - 17s - loss: 0.3901 - accuracy: 0.8857 - val_loss: 0.6580 - val_accuracy: 0.7808 - 17s/epoch - 763ms/step
# Epoch 95/300
# 22/22 - 16s - loss: 0.4862 - accuracy: 0.8553 - val_loss: 0.7620 - val_accuracy: 0.7808 - 16s/epoch - 732ms/step
# Epoch 96/300
# 22/22 - 17s - loss: 0.4722 - accuracy: 0.8509 - val_loss: 0.8513 - val_accuracy: 0.7397 - 17s/epoch - 755ms/step
# Epoch 97/300
# 22/22 - 17s - loss: 0.5211 - accuracy: 0.8307 - val_loss: 0.8849 - val_accuracy: 0.7808 - 17s/epoch - 753ms/step
# Epoch 98/300
# 22/22 - 17s - loss: 0.5012 - accuracy: 0.8408 - val_loss: 0.6504 - val_accuracy: 0.7808 - 17s/epoch - 763ms/step
# Epoch 99/300
# 22/22 - 16s - loss: 0.3834 - accuracy: 0.8770 - val_loss: 0.9218 - val_accuracy: 0.7671 - 16s/epoch - 721ms/step
# Epoch 100/300
# 22/22 - 17s - loss: 0.4513 - accuracy: 0.8654 - val_loss: 0.6799 - val_accuracy: 0.7945 - 17s/epoch - 766ms/step
# Epoch 101/300
# 22/22 - 16s - loss: 0.3839 - accuracy: 0.8799 - val_loss: 0.7693 - val_accuracy: 0.7671 - 16s/epoch - 707ms/step
# Epoch 102/300
# 22/22 - 16s - loss: 0.4692 - accuracy: 0.8567 - val_loss: 0.6481 - val_accuracy: 0.7671 - 16s/epoch - 726ms/step
# Epoch 103/300
# 22/22 - 17s - loss: 0.4858 - accuracy: 0.8452 - val_loss: 0.6942 - val_accuracy: 0.7945 - 17s/epoch - 753ms/step
# Epoch 104/300
# 22/22 - 15s - loss: 0.3500 - accuracy: 0.8944 - val_loss: 0.6233 - val_accuracy: 0.8219 - 15s/epoch - 701ms/step
# Epoch 105/300
# 22/22 - 16s - loss: 0.4082 - accuracy: 0.8698 - val_loss: 0.7606 - val_accuracy: 0.7671 - 16s/epoch - 717ms/step
# Epoch 106/300
# 22/22 - 15s - loss: 0.4123 - accuracy: 0.8683 - val_loss: 0.6746 - val_accuracy: 0.7945 - 15s/epoch - 694ms/step
# Epoch 107/300
# 22/22 - 16s - loss: 0.3748 - accuracy: 0.8871 - val_loss: 0.6712 - val_accuracy: 0.7671 - 16s/epoch - 722ms/step
# Epoch 108/300
# 22/22 - 15s - loss: 0.5658 - accuracy: 0.8205 - val_loss: 0.7794 - val_accuracy: 0.7808 - 15s/epoch - 702ms/step
# Epoch 109/300
# 22/22 - 16s - loss: 0.4971 - accuracy: 0.8452 - val_loss: 0.6094 - val_accuracy: 0.7808 - 16s/epoch - 708ms/step
# Epoch 110/300
# 22/22 - 15s - loss: 0.4656 - accuracy: 0.8567 - val_loss: 0.6769 - val_accuracy: 0.7808 - 15s/epoch - 703ms/step
# Epoch 111/300
# 22/22 - 15s - loss: 0.4273 - accuracy: 0.8842 - val_loss: 0.7322 - val_accuracy: 0.8082 - 15s/epoch - 700ms/step
# Epoch 112/300
# 22/22 - 15s - loss: 0.4949 - accuracy: 0.8495 - val_loss: 0.6674 - val_accuracy: 0.8219 - 15s/epoch - 699ms/step
# Epoch 113/300
# 22/22 - 15s - loss: 0.4451 - accuracy: 0.8669 - val_loss: 0.6949 - val_accuracy: 0.7945 - 15s/epoch - 671ms/step
# Epoch 114/300
# 22/22 - 15s - loss: 0.4002 - accuracy: 0.8625 - val_loss: 0.8840 - val_accuracy: 0.7808 - 15s/epoch - 697ms/step
# Epoch 115/300
# 22/22 - 16s - loss: 0.5392 - accuracy: 0.8394 - val_loss: 0.8828 - val_accuracy: 0.7260 - 16s/epoch - 708ms/step
# Epoch 116/300
# 22/22 - 15s - loss: 0.6411 - accuracy: 0.8394 - val_loss: 1.0860 - val_accuracy: 0.7123 - 15s/epoch - 675ms/step
# Epoch 117/300
# 22/22 - 15s - loss: 0.5500 - accuracy: 0.8350 - val_loss: 1.1077 - val_accuracy: 0.7260 - 15s/epoch - 671ms/step
# Epoch 118/300
# 22/22 - 15s - loss: 0.4033 - accuracy: 0.8842 - val_loss: 0.6697 - val_accuracy: 0.7945 - 15s/epoch - 693ms/step
# Epoch 119/300
# 22/22 - 15s - loss: 0.4249 - accuracy: 0.8726 - val_loss: 0.7758 - val_accuracy: 0.7671 - 15s/epoch - 675ms/step
# Epoch 120/300
# 22/22 - 15s - loss: 0.3425 - accuracy: 0.9016 - val_loss: 0.8059 - val_accuracy: 0.7534 - 15s/epoch - 684ms/step
# Epoch 121/300
# 22/22 - 15s - loss: 0.4070 - accuracy: 0.8726 - val_loss: 0.7615 - val_accuracy: 0.7945 - 15s/epoch - 677ms/step
# Epoch 122/300
# 22/22 - 15s - loss: 0.4347 - accuracy: 0.8654 - val_loss: 1.0266 - val_accuracy: 0.7397 - 15s/epoch - 666ms/step
# Epoch 123/300
# 22/22 - 15s - loss: 0.4592 - accuracy: 0.8726 - val_loss: 0.7290 - val_accuracy: 0.7945 - 15s/epoch - 669ms/step
# Epoch 124/300
# 22/22 - 14s - loss: 0.4464 - accuracy: 0.8712 - val_loss: 0.6098 - val_accuracy: 0.8082 - 14s/epoch - 657ms/step
# Epoch 125/300
# 22/22 - 14s - loss: 0.4463 - accuracy: 0.8755 - val_loss: 0.8193 - val_accuracy: 0.7671 - 14s/epoch - 656ms/step
# Epoch 126/300
# 22/22 - 14s - loss: 0.4567 - accuracy: 0.8741 - val_loss: 0.6663 - val_accuracy: 0.7671 - 14s/epoch - 654ms/step
# Epoch 127/300
# 22/22 - 14s - loss: 0.4077 - accuracy: 0.8741 - val_loss: 1.1047 - val_accuracy: 0.7397 - 14s/epoch - 653ms/step
# Epoch 128/300
# 22/22 - 14s - loss: 0.3335 - accuracy: 0.8813 - val_loss: 0.7813 - val_accuracy: 0.7534 - 14s/epoch - 655ms/step
# Epoch 129/300
# 22/22 - 14s - loss: 0.4836 - accuracy: 0.8553 - val_loss: 0.8389 - val_accuracy: 0.7534 - 14s/epoch - 657ms/step
# Epoch 130/300
# 22/22 - 14s - loss: 0.4544 - accuracy: 0.8611 - val_loss: 0.6483 - val_accuracy: 0.7534 - 14s/epoch - 651ms/step
# Epoch 131/300
# 22/22 - 14s - loss: 0.5507 - accuracy: 0.8220 - val_loss: 0.8228 - val_accuracy: 0.7534 - 14s/epoch - 656ms/step
# Epoch 132/300
# 22/22 - 14s - loss: 0.3023 - accuracy: 0.9016 - val_loss: 0.7903 - val_accuracy: 0.7534 - 14s/epoch - 652ms/step
# Epoch 133/300
# 22/22 - 14s - loss: 0.4999 - accuracy: 0.8466 - val_loss: 0.8047 - val_accuracy: 0.7671 - 14s/epoch - 650ms/step
# Epoch 134/300
# 22/22 - 14s - loss: 0.4810 - accuracy: 0.8596 - val_loss: 1.2959 - val_accuracy: 0.7808 - 14s/epoch - 657ms/step
# Epoch 135/300
# 22/22 - 15s - loss: 0.5076 - accuracy: 0.8582 - val_loss: 0.7926 - val_accuracy: 0.7534 - 15s/epoch - 662ms/step
# Epoch 136/300
# 22/22 - 14s - loss: 0.4674 - accuracy: 0.8480 - val_loss: 0.8029 - val_accuracy: 0.7397 - 14s/epoch - 657ms/step
# Epoch 137/300
# 22/22 - 14s - loss: 0.5810 - accuracy: 0.8495 - val_loss: 1.3106 - val_accuracy: 0.7534 - 14s/epoch - 652ms/step
# Epoch 138/300
# 22/22 - 14s - loss: 0.4488 - accuracy: 0.8755 - val_loss: 0.7862 - val_accuracy: 0.7671 - 14s/epoch - 654ms/step
# Epoch 139/300
# 22/22 - 14s - loss: 0.3729 - accuracy: 0.8755 - val_loss: 0.8800 - val_accuracy: 0.7808 - 14s/epoch - 650ms/step
# Epoch 140/300
# 22/22 - 15s - loss: 0.4402 - accuracy: 0.8567 - val_loss: 0.8296 - val_accuracy: 0.7808 - 15s/epoch - 660ms/step
# Epoch 141/300
# 22/22 - 15s - loss: 0.4318 - accuracy: 0.8654 - val_loss: 0.8569 - val_accuracy: 0.7534 - 15s/epoch - 660ms/step
# Epoch 142/300
# 22/22 - 15s - loss: 0.4016 - accuracy: 0.8669 - val_loss: 1.0323 - val_accuracy: 0.7671 - 15s/epoch - 661ms/step
# Epoch 143/300
# 22/22 - 14s - loss: 0.4064 - accuracy: 0.8683 - val_loss: 0.6896 - val_accuracy: 0.7808 - 14s/epoch - 654ms/step
# Epoch 144/300
# 22/22 - 14s - loss: 0.4247 - accuracy: 0.8582 - val_loss: 0.6980 - val_accuracy: 0.7945 - 14s/epoch - 658ms/step
# Epoch 145/300
# 22/22 - 15s - loss: 0.4628 - accuracy: 0.8683 - val_loss: 0.9032 - val_accuracy: 0.7671 - 15s/epoch - 661ms/step
# Epoch 146/300
# 22/22 - 14s - loss: 0.3955 - accuracy: 0.8770 - val_loss: 0.7072 - val_accuracy: 0.7945 - 14s/epoch - 652ms/step
# Epoch 147/300
# 22/22 - 14s - loss: 0.4208 - accuracy: 0.8813 - val_loss: 0.9468 - val_accuracy: 0.7808 - 14s/epoch - 659ms/step
# Epoch 148/300
# 22/22 - 14s - loss: 0.4748 - accuracy: 0.8712 - val_loss: 0.9327 - val_accuracy: 0.7671 - 14s/epoch - 650ms/step
# Epoch 149/300
# 22/22 - 14s - loss: 0.4815 - accuracy: 0.8596 - val_loss: 0.7567 - val_accuracy: 0.7945 - 14s/epoch - 653ms/step
# Epoch 150/300
# 22/22 - 14s - loss: 0.3685 - accuracy: 0.8871 - val_loss: 0.9939 - val_accuracy: 0.7534 - 14s/epoch - 655ms/step
# Epoch 151/300
# 22/22 - 14s - loss: 0.4594 - accuracy: 0.8611 - val_loss: 0.8906 - val_accuracy: 0.7534 - 14s/epoch - 652ms/step
# Epoch 152/300
# 22/22 - 14s - loss: 0.4012 - accuracy: 0.8915 - val_loss: 0.8182 - val_accuracy: 0.7808 - 14s/epoch - 648ms/step
# Epoch 153/300
# 22/22 - 14s - loss: 0.4847 - accuracy: 0.8524 - val_loss: 0.8039 - val_accuracy: 0.7534 - 14s/epoch - 657ms/step
# Epoch 154/300
# 22/22 - 14s - loss: 0.4974 - accuracy: 0.8654 - val_loss: 0.9742 - val_accuracy: 0.7808 - 14s/epoch - 658ms/step
# Epoch 155/300
# 22/22 - 14s - loss: 0.3980 - accuracy: 0.8799 - val_loss: 0.8694 - val_accuracy: 0.7671 - 14s/epoch - 659ms/step
# Epoch 156/300
# 22/22 - 14s - loss: 0.4236 - accuracy: 0.8755 - val_loss: 0.7998 - val_accuracy: 0.7808 - 14s/epoch - 656ms/step
# Epoch 157/300
# 22/22 - 14s - loss: 0.2749 - accuracy: 0.9074 - val_loss: 0.7913 - val_accuracy: 0.7671 - 14s/epoch - 652ms/step
# Epoch 158/300
# 22/22 - 14s - loss: 0.3525 - accuracy: 0.8929 - val_loss: 0.7812 - val_accuracy: 0.7808 - 14s/epoch - 656ms/step
# Epoch 159/300
# 22/22 - 14s - loss: 0.4089 - accuracy: 0.8669 - val_loss: 0.7924 - val_accuracy: 0.7671 - 14s/epoch - 655ms/step
# Epoch 160/300
# 22/22 - 14s - loss: 0.4050 - accuracy: 0.8871 - val_loss: 0.6975 - val_accuracy: 0.8082 - 14s/epoch - 650ms/step
# Epoch 161/300
# 22/22 - 14s - loss: 0.3041 - accuracy: 0.8900 - val_loss: 0.8189 - val_accuracy: 0.7945 - 14s/epoch - 654ms/step
# Epoch 162/300
# 22/22 - 15s - loss: 0.3647 - accuracy: 0.8871 - val_loss: 0.8480 - val_accuracy: 0.7945 - 15s/epoch - 660ms/step
# Epoch 163/300
# 22/22 - 14s - loss: 0.4076 - accuracy: 0.8712 - val_loss: 0.7927 - val_accuracy: 0.7808 - 14s/epoch - 657ms/step
# Epoch 164/300
# 22/22 - 15s - loss: 0.3564 - accuracy: 0.8857 - val_loss: 0.7755 - val_accuracy: 0.8082 - 15s/epoch - 659ms/step
# Epoch 165/300
# 22/22 - 14s - loss: 0.4362 - accuracy: 0.8726 - val_loss: 0.9230 - val_accuracy: 0.7397 - 14s/epoch - 650ms/step
# Epoch 166/300
# 22/22 - 14s - loss: 0.4915 - accuracy: 0.8741 - val_loss: 0.8047 - val_accuracy: 0.7808 - 14s/epoch - 656ms/step
# Epoch 167/300
# 22/22 - 14s - loss: 0.4597 - accuracy: 0.8582 - val_loss: 0.8782 - val_accuracy: 0.7397 - 14s/epoch - 653ms/step
# Epoch 168/300
# 22/22 - 14s - loss: 0.3994 - accuracy: 0.8755 - val_loss: 0.6976 - val_accuracy: 0.7671 - 14s/epoch - 653ms/step
# Epoch 169/300
# 22/22 - 14s - loss: 0.3884 - accuracy: 0.8770 - val_loss: 0.7529 - val_accuracy: 0.8082 - 14s/epoch - 653ms/step
# Epoch 170/300
# 22/22 - 14s - loss: 0.3874 - accuracy: 0.8755 - val_loss: 0.7120 - val_accuracy: 0.7808 - 14s/epoch - 653ms/step
# Epoch 171/300
# 22/22 - 14s - loss: 0.4191 - accuracy: 0.8726 - val_loss: 0.5833 - val_accuracy: 0.7808 - 14s/epoch - 649ms/step
# Epoch 172/300
# 22/22 - 14s - loss: 0.4528 - accuracy: 0.8683 - val_loss: 0.7335 - val_accuracy: 0.7808 - 14s/epoch - 653ms/step
# Epoch 173/300
# 22/22 - 14s - loss: 0.4018 - accuracy: 0.8799 - val_loss: 0.6486 - val_accuracy: 0.8082 - 14s/epoch - 651ms/step
# Epoch 174/300
# 22/22 - 14s - loss: 0.3263 - accuracy: 0.8857 - val_loss: 0.6581 - val_accuracy: 0.7945 - 14s/epoch - 657ms/step
# Epoch 175/300
# 22/22 - 14s - loss: 0.3683 - accuracy: 0.8828 - val_loss: 0.6750 - val_accuracy: 0.7945 - 14s/epoch - 657ms/step
# Epoch 176/300
# 22/22 - 14s - loss: 0.3796 - accuracy: 0.8886 - val_loss: 0.7577 - val_accuracy: 0.7945 - 14s/epoch - 654ms/step
# Epoch 177/300
# 22/22 - 14s - loss: 0.3244 - accuracy: 0.9030 - val_loss: 0.7000 - val_accuracy: 0.8082 - 14s/epoch - 656ms/step
# Epoch 178/300
# 22/22 - 14s - loss: 0.3401 - accuracy: 0.9045 - val_loss: 0.7020 - val_accuracy: 0.8082 - 14s/epoch - 651ms/step
# Epoch 179/300
# 22/22 - 14s - loss: 0.3929 - accuracy: 0.8712 - val_loss: 0.6468 - val_accuracy: 0.7945 - 14s/epoch - 652ms/step
# Epoch 180/300
# 22/22 - 15s - loss: 0.4030 - accuracy: 0.8755 - val_loss: 0.7849 - val_accuracy: 0.7808 - 15s/epoch - 659ms/step
# Epoch 181/300
# 22/22 - 14s - loss: 0.3655 - accuracy: 0.8683 - val_loss: 0.7684 - val_accuracy: 0.7945 - 14s/epoch - 651ms/step
# Epoch 182/300
# 22/22 - 15s - loss: 0.3989 - accuracy: 0.8669 - val_loss: 0.8635 - val_accuracy: 0.7671 - 15s/epoch - 668ms/step
# Epoch 183/300
# 22/22 - 15s - loss: 0.3656 - accuracy: 0.8857 - val_loss: 0.6821 - val_accuracy: 0.8082 - 15s/epoch - 671ms/step
# Epoch 184/300
# 22/22 - 15s - loss: 0.3532 - accuracy: 0.8886 - val_loss: 0.7277 - val_accuracy: 0.8082 - 15s/epoch - 675ms/step
# Epoch 185/300
# 22/22 - 14s - loss: 0.3964 - accuracy: 0.8770 - val_loss: 0.5989 - val_accuracy: 0.8082 - 14s/epoch - 657ms/step
# Epoch 186/300
# 22/22 - 14s - loss: 0.3617 - accuracy: 0.8871 - val_loss: 0.7606 - val_accuracy: 0.7945 - 14s/epoch - 655ms/step
# Epoch 187/300
# 22/22 - 14s - loss: 0.4150 - accuracy: 0.8698 - val_loss: 0.6676 - val_accuracy: 0.8219 - 14s/epoch - 659ms/step
# Epoch 188/300
# 22/22 - 15s - loss: 0.3910 - accuracy: 0.8813 - val_loss: 0.8115 - val_accuracy: 0.8082 - 15s/epoch - 661ms/step
# Epoch 189/300
# 22/22 - 14s - loss: 0.4372 - accuracy: 0.8654 - val_loss: 0.7300 - val_accuracy: 0.7945 - 14s/epoch - 657ms/step
# Epoch 190/300
# 22/22 - 15s - loss: 0.5510 - accuracy: 0.8495 - val_loss: 0.9417 - val_accuracy: 0.8082 - 15s/epoch - 663ms/step
# Epoch 191/300
# 22/22 - 15s - loss: 0.4514 - accuracy: 0.8770 - val_loss: 0.9436 - val_accuracy: 0.7671 - 15s/epoch - 668ms/step
# Epoch 192/300
# 22/22 - 14s - loss: 0.3503 - accuracy: 0.8958 - val_loss: 0.8302 - val_accuracy: 0.7945 - 14s/epoch - 657ms/step
# Epoch 193/300
# 22/22 - 15s - loss: 0.5825 - accuracy: 0.8205 - val_loss: 0.7969 - val_accuracy: 0.7945 - 15s/epoch - 659ms/step
# Epoch 194/300
# 22/22 - 15s - loss: 0.4467 - accuracy: 0.8726 - val_loss: 1.0773 - val_accuracy: 0.7808 - 15s/epoch - 671ms/step
# Epoch 195/300
# 22/22 - 14s - loss: 0.4153 - accuracy: 0.8813 - val_loss: 0.7414 - val_accuracy: 0.7808 - 14s/epoch - 656ms/step
# Epoch 196/300
# 22/22 - 14s - loss: 0.4560 - accuracy: 0.8741 - val_loss: 0.8786 - val_accuracy: 0.7671 - 14s/epoch - 654ms/step
# Epoch 197/300
# 22/22 - 14s - loss: 0.3252 - accuracy: 0.8958 - val_loss: 0.9248 - val_accuracy: 0.7534 - 14s/epoch - 652ms/step
# Epoch 198/300
# 22/22 - 14s - loss: 0.3983 - accuracy: 0.8698 - val_loss: 0.9988 - val_accuracy: 0.7671 - 14s/epoch - 659ms/step
# Epoch 199/300
# 22/22 - 14s - loss: 0.3820 - accuracy: 0.8944 - val_loss: 0.8813 - val_accuracy: 0.7945 - 14s/epoch - 651ms/step
# Epoch 200/300
# 22/22 - 14s - loss: 0.3559 - accuracy: 0.8813 - val_loss: 0.7113 - val_accuracy: 0.7945 - 14s/epoch - 652ms/step
# Epoch 201/300
# 22/22 - 15s - loss: 0.3553 - accuracy: 0.8857 - val_loss: 1.1044 - val_accuracy: 0.7534 - 15s/epoch - 659ms/step
# Epoch 202/300
# 22/22 - 15s - loss: 0.3850 - accuracy: 0.8886 - val_loss: 0.8212 - val_accuracy: 0.8082 - 15s/epoch - 661ms/step
# Epoch 203/300
# 22/22 - 14s - loss: 0.3055 - accuracy: 0.8929 - val_loss: 0.7382 - val_accuracy: 0.7808 - 14s/epoch - 658ms/step
# Epoch 204/300
# 22/22 - 14s - loss: 0.3237 - accuracy: 0.8987 - val_loss: 0.8391 - val_accuracy: 0.7671 - 14s/epoch - 657ms/step
# Epoch 205/300
# 22/22 - 14s - loss: 0.3423 - accuracy: 0.8828 - val_loss: 0.9176 - val_accuracy: 0.7808 - 14s/epoch - 650ms/step
# Epoch 206/300
# 22/22 - 14s - loss: 0.3236 - accuracy: 0.8958 - val_loss: 0.8071 - val_accuracy: 0.7808 - 14s/epoch - 649ms/step
# Epoch 207/300
# 22/22 - 15s - loss: 0.4146 - accuracy: 0.8698 - val_loss: 0.7666 - val_accuracy: 0.7945 - 15s/epoch - 660ms/step
# Epoch 208/300
# 22/22 - 14s - loss: 0.4077 - accuracy: 0.8712 - val_loss: 0.8089 - val_accuracy: 0.8219 - 14s/epoch - 654ms/step
# Epoch 209/300
# 22/22 - 15s - loss: 0.4289 - accuracy: 0.8611 - val_loss: 0.7560 - val_accuracy: 0.7808 - 15s/epoch - 682ms/step
# Epoch 210/300
# 22/22 - 15s - loss: 0.4316 - accuracy: 0.8654 - val_loss: 0.7609 - val_accuracy: 0.7397 - 15s/epoch - 702ms/step
# Epoch 211/300
# 22/22 - 15s - loss: 0.4005 - accuracy: 0.8944 - val_loss: 0.8393 - val_accuracy: 0.7945 - 15s/epoch - 703ms/step
# Epoch 212/300
# 22/22 - 16s - loss: 0.3044 - accuracy: 0.8987 - val_loss: 0.8164 - val_accuracy: 0.7534 - 16s/epoch - 712ms/step
# Epoch 213/300
# 22/22 - 15s - loss: 0.4107 - accuracy: 0.8915 - val_loss: 0.9476 - val_accuracy: 0.7808 - 15s/epoch - 679ms/step
# Epoch 214/300
# 22/22 - 15s - loss: 0.3347 - accuracy: 0.8900 - val_loss: 0.7086 - val_accuracy: 0.8082 - 15s/epoch - 685ms/step
# Epoch 215/300
# 22/22 - 15s - loss: 0.3117 - accuracy: 0.8958 - val_loss: 0.8317 - val_accuracy: 0.8082 - 15s/epoch - 659ms/step
# Epoch 216/300
# 22/22 - 15s - loss: 0.3016 - accuracy: 0.9103 - val_loss: 0.6850 - val_accuracy: 0.8219 - 15s/epoch - 669ms/step
# Epoch 217/300
# 22/22 - 15s - loss: 0.3224 - accuracy: 0.9045 - val_loss: 1.0009 - val_accuracy: 0.7671 - 15s/epoch - 697ms/step
# Epoch 218/300
# 22/22 - 15s - loss: 0.3666 - accuracy: 0.8741 - val_loss: 0.6806 - val_accuracy: 0.7945 - 15s/epoch - 678ms/step
# Epoch 219/300
# 22/22 - 15s - loss: 0.3722 - accuracy: 0.8784 - val_loss: 0.7873 - val_accuracy: 0.7945 - 15s/epoch - 675ms/step
# Epoch 220/300
# 22/22 - 15s - loss: 0.3885 - accuracy: 0.8857 - val_loss: 0.8200 - val_accuracy: 0.7945 - 15s/epoch - 684ms/step
# Epoch 221/300
# 22/22 - 15s - loss: 0.2710 - accuracy: 0.9059 - val_loss: 0.7994 - val_accuracy: 0.7945 - 15s/epoch - 689ms/step
# Epoch 222/300
# 22/22 - 16s - loss: 0.2713 - accuracy: 0.9059 - val_loss: 0.7166 - val_accuracy: 0.8082 - 16s/epoch - 720ms/step
# Epoch 223/300
# 22/22 - 15s - loss: 0.3474 - accuracy: 0.9088 - val_loss: 0.7490 - val_accuracy: 0.7945 - 15s/epoch - 698ms/step
# Epoch 224/300
# 22/22 - 15s - loss: 0.3005 - accuracy: 0.9045 - val_loss: 0.8047 - val_accuracy: 0.7945 - 15s/epoch - 689ms/step
# Epoch 225/300
# 22/22 - 15s - loss: 0.4074 - accuracy: 0.8799 - val_loss: 0.7703 - val_accuracy: 0.7945 - 15s/epoch - 699ms/step
# Epoch 226/300
# 22/22 - 15s - loss: 0.2889 - accuracy: 0.8900 - val_loss: 0.7502 - val_accuracy: 0.8082 - 15s/epoch - 690ms/step
# Epoch 227/300
# 22/22 - 15s - loss: 0.4153 - accuracy: 0.8712 - val_loss: 0.6508 - val_accuracy: 0.7808 - 15s/epoch - 683ms/step
# Epoch 228/300
# 22/22 - 15s - loss: 0.3878 - accuracy: 0.8828 - val_loss: 0.8334 - val_accuracy: 0.7808 - 15s/epoch - 681ms/step
# Epoch 229/300
# 22/22 - 14s - loss: 0.3847 - accuracy: 0.8799 - val_loss: 0.7454 - val_accuracy: 0.7808 - 14s/epoch - 659ms/step
# Epoch 230/300
# 22/22 - 15s - loss: 0.3772 - accuracy: 0.8741 - val_loss: 0.7476 - val_accuracy: 0.7945 - 15s/epoch - 662ms/step
# Epoch 231/300
# 22/22 - 15s - loss: 0.3692 - accuracy: 0.8784 - val_loss: 0.7423 - val_accuracy: 0.7671 - 15s/epoch - 676ms/step
# Epoch 232/300
# 22/22 - 15s - loss: 0.3773 - accuracy: 0.8958 - val_loss: 0.8997 - val_accuracy: 0.7808 - 15s/epoch - 686ms/step
# Epoch 233/300
# 22/22 - 14s - loss: 0.3923 - accuracy: 0.8842 - val_loss: 0.8460 - val_accuracy: 0.7808 - 14s/epoch - 659ms/step
# Epoch 234/300
# 22/22 - 15s - loss: 0.3445 - accuracy: 0.9001 - val_loss: 0.6601 - val_accuracy: 0.7945 - 15s/epoch - 675ms/step
# Epoch 235/300
# 22/22 - 14s - loss: 0.3303 - accuracy: 0.8857 - val_loss: 0.7600 - val_accuracy: 0.8082 - 14s/epoch - 656ms/step
# Epoch 236/300
# 22/22 - 15s - loss: 0.3690 - accuracy: 0.8799 - val_loss: 0.5847 - val_accuracy: 0.8082 - 15s/epoch - 677ms/step
# Epoch 237/300
# 22/22 - 15s - loss: 0.2719 - accuracy: 0.9045 - val_loss: 0.8263 - val_accuracy: 0.8219 - 15s/epoch - 676ms/step
# Epoch 238/300
# 22/22 - 15s - loss: 0.3448 - accuracy: 0.8987 - val_loss: 0.7670 - val_accuracy: 0.8219 - 15s/epoch - 671ms/step
# Epoch 239/300
# 22/22 - 15s - loss: 0.3179 - accuracy: 0.9088 - val_loss: 0.6953 - val_accuracy: 0.8219 - 15s/epoch - 669ms/step
# Epoch 240/300
# 22/22 - 15s - loss: 0.3649 - accuracy: 0.8886 - val_loss: 0.7837 - val_accuracy: 0.8082 - 15s/epoch - 702ms/step
# Epoch 241/300
# 22/22 - 15s - loss: 0.3195 - accuracy: 0.9030 - val_loss: 0.6627 - val_accuracy: 0.8219 - 15s/epoch - 693ms/step
# Epoch 242/300
# 22/22 - 15s - loss: 0.3454 - accuracy: 0.9016 - val_loss: 0.6713 - val_accuracy: 0.8219 - 15s/epoch - 678ms/step
# Epoch 243/300
# 22/22 - 15s - loss: 0.3508 - accuracy: 0.9016 - val_loss: 0.7423 - val_accuracy: 0.7808 - 15s/epoch - 675ms/step
# Epoch 244/300
# 22/22 - 15s - loss: 0.3235 - accuracy: 0.8915 - val_loss: 0.6206 - val_accuracy: 0.8082 - 15s/epoch - 661ms/step
# Epoch 245/300
# 22/22 - 14s - loss: 0.3422 - accuracy: 0.8770 - val_loss: 0.7738 - val_accuracy: 0.8082 - 14s/epoch - 652ms/step
# Epoch 246/300
# 22/22 - 14s - loss: 0.3531 - accuracy: 0.8915 - val_loss: 0.7976 - val_accuracy: 0.8082 - 14s/epoch - 652ms/step
# Epoch 247/300
# 22/22 - 14s - loss: 0.3414 - accuracy: 0.8886 - val_loss: 0.7104 - val_accuracy: 0.7945 - 14s/epoch - 659ms/step
# Epoch 248/300
# 22/22 - 14s - loss: 0.3508 - accuracy: 0.8871 - val_loss: 0.9563 - val_accuracy: 0.7945 - 14s/epoch - 656ms/step
# Epoch 249/300
# 22/22 - 14s - loss: 0.3593 - accuracy: 0.8828 - val_loss: 0.9548 - val_accuracy: 0.7945 - 14s/epoch - 654ms/step
# Epoch 250/300
# 22/22 - 15s - loss: 0.3077 - accuracy: 0.9074 - val_loss: 0.7765 - val_accuracy: 0.8356 - 15s/epoch - 666ms/step
# Epoch 251/300
# 22/22 - 15s - loss: 0.3021 - accuracy: 0.9030 - val_loss: 0.8386 - val_accuracy: 0.7671 - 15s/epoch - 670ms/step
# Epoch 252/300
# 22/22 - 14s - loss: 0.3453 - accuracy: 0.8886 - val_loss: 0.9348 - val_accuracy: 0.8082 - 14s/epoch - 657ms/step
# Epoch 253/300
# 22/22 - 14s - loss: 0.4036 - accuracy: 0.8799 - val_loss: 0.8440 - val_accuracy: 0.8082 - 14s/epoch - 657ms/step
# Epoch 254/300
# 22/22 - 15s - loss: 0.3810 - accuracy: 0.8828 - val_loss: 0.8082 - val_accuracy: 0.8219 - 15s/epoch - 671ms/step
# Epoch 255/300
# 22/22 - 15s - loss: 0.4304 - accuracy: 0.8886 - val_loss: 0.7564 - val_accuracy: 0.7808 - 15s/epoch - 674ms/step
# Epoch 256/300
# 22/22 - 15s - loss: 0.3424 - accuracy: 0.8929 - val_loss: 1.0185 - val_accuracy: 0.8082 - 15s/epoch - 700ms/step
# Epoch 257/300
# 22/22 - 15s - loss: 0.2695 - accuracy: 0.9001 - val_loss: 0.7306 - val_accuracy: 0.7945 - 15s/epoch - 691ms/step
# Epoch 258/300
# 22/22 - 15s - loss: 0.3636 - accuracy: 0.9001 - val_loss: 0.8769 - val_accuracy: 0.7671 - 15s/epoch - 696ms/step
# Epoch 259/300
# 22/22 - 15s - loss: 0.3747 - accuracy: 0.8770 - val_loss: 0.8313 - val_accuracy: 0.8082 - 15s/epoch - 681ms/step
# Epoch 260/300
# 22/22 - 15s - loss: 0.4024 - accuracy: 0.8915 - val_loss: 0.6052 - val_accuracy: 0.8219 - 15s/epoch - 668ms/step
# Epoch 261/300
# 22/22 - 15s - loss: 0.4254 - accuracy: 0.8611 - val_loss: 0.6956 - val_accuracy: 0.8082 - 15s/epoch - 681ms/step
# Epoch 262/300
# 22/22 - 15s - loss: 0.3565 - accuracy: 0.8799 - val_loss: 0.7597 - val_accuracy: 0.7945 - 15s/epoch - 664ms/step
# Epoch 263/300
# 22/22 - 15s - loss: 0.2850 - accuracy: 0.8944 - val_loss: 0.7048 - val_accuracy: 0.8082 - 15s/epoch - 659ms/step
# Epoch 264/300
# 22/22 - 15s - loss: 0.3935 - accuracy: 0.8755 - val_loss: 0.6699 - val_accuracy: 0.7945 - 15s/epoch - 661ms/step
# Epoch 265/300
# 22/22 - 15s - loss: 0.2879 - accuracy: 0.9074 - val_loss: 0.7337 - val_accuracy: 0.7534 - 15s/epoch - 667ms/step
# Epoch 266/300
# 22/22 - 15s - loss: 0.3337 - accuracy: 0.8929 - val_loss: 0.6830 - val_accuracy: 0.8082 - 15s/epoch - 669ms/step
# Epoch 267/300
# 22/22 - 15s - loss: 0.3766 - accuracy: 0.8857 - val_loss: 0.7740 - val_accuracy: 0.7808 - 15s/epoch - 681ms/step
# Epoch 268/300
# 22/22 - 14s - loss: 0.4432 - accuracy: 0.8770 - val_loss: 0.5826 - val_accuracy: 0.8219 - 14s/epoch - 658ms/step
# Epoch 269/300
# 22/22 - 15s - loss: 0.3375 - accuracy: 0.9030 - val_loss: 0.6265 - val_accuracy: 0.8219 - 15s/epoch - 672ms/step
# Epoch 270/300
# 22/22 - 15s - loss: 0.3749 - accuracy: 0.8929 - val_loss: 0.8906 - val_accuracy: 0.7808 - 15s/epoch - 677ms/step
# Epoch 271/300
# 22/22 - 15s - loss: 0.3993 - accuracy: 0.8755 - val_loss: 0.7091 - val_accuracy: 0.8082 - 15s/epoch - 674ms/step
# Epoch 272/300
# 22/22 - 15s - loss: 0.4260 - accuracy: 0.8698 - val_loss: 0.7722 - val_accuracy: 0.8082 - 15s/epoch - 686ms/step
# Epoch 273/300
# 22/22 - 15s - loss: 0.3090 - accuracy: 0.9175 - val_loss: 0.7136 - val_accuracy: 0.8219 - 15s/epoch - 690ms/step
# Epoch 274/300
# 22/22 - 16s - loss: 0.4100 - accuracy: 0.8886 - val_loss: 0.7342 - val_accuracy: 0.7671 - 16s/epoch - 739ms/step
# Epoch 275/300
# 22/22 - 15s - loss: 0.2482 - accuracy: 0.9204 - val_loss: 0.8781 - val_accuracy: 0.8082 - 15s/epoch - 700ms/step
# Epoch 276/300
# 22/22 - 15s - loss: 0.3444 - accuracy: 0.8944 - val_loss: 0.8253 - val_accuracy: 0.7534 - 15s/epoch - 685ms/step
# Epoch 277/300
# 22/22 - 15s - loss: 0.3312 - accuracy: 0.9016 - val_loss: 0.7995 - val_accuracy: 0.7945 - 15s/epoch - 678ms/step
# Epoch 278/300
# 22/22 - 15s - loss: 0.5303 - accuracy: 0.8538 - val_loss: 1.0323 - val_accuracy: 0.7808 - 15s/epoch - 675ms/step
# Epoch 279/300
# 22/22 - 15s - loss: 0.3626 - accuracy: 0.8929 - val_loss: 0.8640 - val_accuracy: 0.7808 - 15s/epoch - 680ms/step
# Epoch 280/300
# 22/22 - 15s - loss: 0.3756 - accuracy: 0.8857 - val_loss: 0.6979 - val_accuracy: 0.7808 - 15s/epoch - 676ms/step
# Epoch 281/300
# 22/22 - 15s - loss: 0.2857 - accuracy: 0.9117 - val_loss: 0.8357 - val_accuracy: 0.7808 - 15s/epoch - 680ms/step
# Epoch 282/300
# 22/22 - 15s - loss: 0.3962 - accuracy: 0.8755 - val_loss: 0.7962 - val_accuracy: 0.7945 - 15s/epoch - 677ms/step
# Epoch 283/300
# 22/22 - 15s - loss: 0.3478 - accuracy: 0.8987 - val_loss: 0.6775 - val_accuracy: 0.7945 - 15s/epoch - 679ms/step
# Epoch 284/300
# 22/22 - 15s - loss: 0.2778 - accuracy: 0.9059 - val_loss: 0.6927 - val_accuracy: 0.8082 - 15s/epoch - 683ms/step
# Epoch 285/300
# 22/22 - 15s - loss: 0.3068 - accuracy: 0.8929 - val_loss: 0.7405 - val_accuracy: 0.8082 - 15s/epoch - 688ms/step
# Epoch 286/300
# 22/22 - 15s - loss: 0.3716 - accuracy: 0.8813 - val_loss: 0.7445 - val_accuracy: 0.7945 - 15s/epoch - 678ms/step
# Epoch 287/300
# 22/22 - 15s - loss: 0.3189 - accuracy: 0.8929 - val_loss: 0.5512 - val_accuracy: 0.8219 - 15s/epoch - 682ms/step
# Epoch 288/300
# 22/22 - 15s - loss: 0.3111 - accuracy: 0.8973 - val_loss: 0.8555 - val_accuracy: 0.8082 - 15s/epoch - 687ms/step
# Epoch 289/300
# 22/22 - 15s - loss: 0.3543 - accuracy: 0.8929 - val_loss: 0.5584 - val_accuracy: 0.8219 - 15s/epoch - 681ms/step
# Epoch 290/300
# 22/22 - 15s - loss: 0.3092 - accuracy: 0.8958 - val_loss: 0.8529 - val_accuracy: 0.8082 - 15s/epoch - 686ms/step
# Epoch 291/300
# 22/22 - 15s - loss: 0.3725 - accuracy: 0.8828 - val_loss: 0.6625 - val_accuracy: 0.8082 - 15s/epoch - 689ms/step
# Epoch 292/300
# 22/22 - 15s - loss: 0.3247 - accuracy: 0.8958 - val_loss: 0.8114 - val_accuracy: 0.8219 - 15s/epoch - 681ms/step
# Epoch 293/300
# 22/22 - 15s - loss: 0.4254 - accuracy: 0.8871 - val_loss: 0.7315 - val_accuracy: 0.8082 - 15s/epoch - 676ms/step
# Epoch 294/300
# 22/22 - 15s - loss: 0.2978 - accuracy: 0.9074 - val_loss: 0.7283 - val_accuracy: 0.7808 - 15s/epoch - 679ms/step
# Epoch 295/300
# 22/22 - 15s - loss: 0.3118 - accuracy: 0.9030 - val_loss: 0.6328 - val_accuracy: 0.8082 - 15s/epoch - 678ms/step
# Epoch 296/300
# 22/22 - 15s - loss: 0.3140 - accuracy: 0.9001 - val_loss: 0.6305 - val_accuracy: 0.8082 - 15s/epoch - 688ms/step
# Epoch 297/300
# 22/22 - 15s - loss: 0.2927 - accuracy: 0.8987 - val_loss: 0.6182 - val_accuracy: 0.8219 - 15s/epoch - 692ms/step
# Epoch 298/300
# 22/22 - 15s - loss: 0.3749 - accuracy: 0.8784 - val_loss: 0.6066 - val_accuracy: 0.8082 - 15s/epoch - 694ms/step
# Epoch 299/300
# 22/22 - 15s - loss: 0.3251 - accuracy: 0.9001 - val_loss: 0.7867 - val_accuracy: 0.8219 - 15s/epoch - 686ms/step
# Epoch 300/300
# 22/22 - 15s - loss: 0.3439 - accuracy: 0.8958 - val_loss: 0.6403 - val_accuracy: 0.7671 - 15s/epoch - 693ms/step

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# OPTIONAL: Decide if best weights should be loaded from previous model based on val_acc
# The model weights (that are considered the best) are loaded into the model.
result = model.load_weights(checkpoint_filepath)

# %% [markdown]
# <h3>Evaluate Test data</h3>

# %%
print(sum(cb.logs) / 150)

testLoss, testAcc = model.evaluate(test)
print('''
Test Loss: {}
Test Accuracy: {}
'''.format(testLoss, testAcc))
# Out:
# 30.007033491333278
# 3/3 [==============================] - 1s 239ms/step - loss: 0.9894 - accuracy: 0.8539
#
# Test Loss: 0.9894437193870544
# Test Accuracy: 0.8539325594902039

# %% [markdown]
# <h4>*Optional - Fine tune model with two-step training*</h4>

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

mobile.trainable = True

for layer in mobile.layers[:-2]:
    layer.trainable = False
    
#re-train the model at a very low learning rate
model.compile(optimizer=Adam(learning_rate=0.00006), loss='categorical_crossentropy', metrics=['accuracy'])

result = model.fit(x=train, validation_data=validation, epochs=100, verbose=2, callbacks=[cb, es])
# Out:
# Epoch 1/100
# 22/22 - 17s - loss: 0.3233 - accuracy: 0.8987 - val_loss: 0.7717 - val_accuracy: 0.8356 - 17s/epoch - 775ms/step
# Epoch 2/100
# 22/22 - 15s - loss: 0.3603 - accuracy: 0.8987 - val_loss: 0.7743 - val_accuracy: 0.8356 - 15s/epoch - 684ms/step
# Epoch 3/100
# 22/22 - 15s - loss: 0.3194 - accuracy: 0.8944 - val_loss: 0.7737 - val_accuracy: 0.8356 - 15s/epoch - 688ms/step
# Epoch 4/100
# 22/22 - 15s - loss: 0.2626 - accuracy: 0.9175 - val_loss: 0.7749 - val_accuracy: 0.8356 - 15s/epoch - 679ms/step
# Epoch 5/100
# 22/22 - 15s - loss: 0.2340 - accuracy: 0.9132 - val_loss: 0.7741 - val_accuracy: 0.8356 - 15s/epoch - 691ms/step
# Epoch 6/100
# 22/22 - 16s - loss: 0.2985 - accuracy: 0.9146 - val_loss: 0.7719 - val_accuracy: 0.8356 - 16s/epoch - 730ms/step
# Epoch 7/100
# 22/22 - 15s - loss: 0.2570 - accuracy: 0.9247 - val_loss: 0.7730 - val_accuracy: 0.8356 - 15s/epoch - 681ms/step
# Epoch 8/100
# 22/22 - 15s - loss: 0.2327 - accuracy: 0.9190 - val_loss: 0.7701 - val_accuracy: 0.8356 - 15s/epoch - 674ms/step
# Epoch 9/100
# 22/22 - 15s - loss: 0.2714 - accuracy: 0.9175 - val_loss: 0.7666 - val_accuracy: 0.8356 - 15s/epoch - 661ms/step
# Epoch 10/100
# 22/22 - 15s - loss: 0.2337 - accuracy: 0.9175 - val_loss: 0.7640 - val_accuracy: 0.8356 - 15s/epoch - 664ms/step
# Epoch 11/100
# 22/22 - 15s - loss: 0.2955 - accuracy: 0.9132 - val_loss: 0.7618 - val_accuracy: 0.8356 - 15s/epoch - 702ms/step
# Epoch 12/100
# 22/22 - 15s - loss: 0.2693 - accuracy: 0.9161 - val_loss: 0.7620 - val_accuracy: 0.8356 - 15s/epoch - 677ms/step
# Epoch 13/100
# 22/22 - 15s - loss: 0.3168 - accuracy: 0.9030 - val_loss: 0.7607 - val_accuracy: 0.8356 - 15s/epoch - 664ms/step
# Epoch 14/100
# 22/22 - 15s - loss: 0.2726 - accuracy: 0.9103 - val_loss: 0.7603 - val_accuracy: 0.8356 - 15s/epoch - 673ms/step
# Epoch 15/100
# 22/22 - 15s - loss: 0.2498 - accuracy: 0.9262 - val_loss: 0.7592 - val_accuracy: 0.8356 - 15s/epoch - 663ms/step
# Epoch 16/100
# 22/22 - 15s - loss: 0.3040 - accuracy: 0.8915 - val_loss: 0.7572 - val_accuracy: 0.8219 - 15s/epoch - 660ms/step
# Epoch 17/100
# 22/22 - 15s - loss: 0.2688 - accuracy: 0.9088 - val_loss: 0.7567 - val_accuracy: 0.8219 - 15s/epoch - 692ms/step
# Epoch 18/100
# 22/22 - 15s - loss: 0.2843 - accuracy: 0.9175 - val_loss: 0.7539 - val_accuracy: 0.8219 - 15s/epoch - 703ms/step
# Epoch 19/100
# 22/22 - 16s - loss: 0.2855 - accuracy: 0.9074 - val_loss: 0.7550 - val_accuracy: 0.8219 - 16s/epoch - 709ms/step
# Epoch 20/100
# 22/22 - 15s - loss: 0.3143 - accuracy: 0.8973 - val_loss: 0.7529 - val_accuracy: 0.8219 - 15s/epoch - 702ms/step
# Epoch 21/100
# 22/22 - 16s - loss: 0.3407 - accuracy: 0.9059 - val_loss: 0.7555 - val_accuracy: 0.8219 - 16s/epoch - 706ms/step
# Epoch 22/100
# 22/22 - 15s - loss: 0.2635 - accuracy: 0.9233 - val_loss: 0.7550 - val_accuracy: 0.8082 - 15s/epoch - 698ms/step
# Epoch 23/100
# 22/22 - 15s - loss: 0.2718 - accuracy: 0.9045 - val_loss: 0.7548 - val_accuracy: 0.8082 - 15s/epoch - 698ms/step
# Epoch 24/100
# 22/22 - 15s - loss: 0.3148 - accuracy: 0.9030 - val_loss: 0.7510 - val_accuracy: 0.8082 - 15s/epoch - 696ms/step
# Epoch 25/100
# 22/22 - 15s - loss: 0.2804 - accuracy: 0.9088 - val_loss: 0.7479 - val_accuracy: 0.7945 - 15s/epoch - 687ms/step
# Epoch 26/100
# 22/22 - 15s - loss: 0.2183 - accuracy: 0.9262 - val_loss: 0.7491 - val_accuracy: 0.8082 - 15s/epoch - 694ms/step
# Epoch 27/100
# 22/22 - 16s - loss: 0.3016 - accuracy: 0.9103 - val_loss: 0.7498 - val_accuracy: 0.8082 - 16s/epoch - 707ms/step
# Epoch 28/100
# 22/22 - 15s - loss: 0.2989 - accuracy: 0.9117 - val_loss: 0.7469 - val_accuracy: 0.7945 - 15s/epoch - 704ms/step
# Epoch 29/100
# 22/22 - 16s - loss: 0.2685 - accuracy: 0.9190 - val_loss: 0.7472 - val_accuracy: 0.8082 - 16s/epoch - 710ms/step
# Epoch 30/100
# 22/22 - 16s - loss: 0.2976 - accuracy: 0.9016 - val_loss: 0.7482 - val_accuracy: 0.8082 - 16s/epoch - 706ms/step
# Epoch 31/100
# 22/22 - 16s - loss: 0.3011 - accuracy: 0.9074 - val_loss: 0.7515 - val_accuracy: 0.8082 - 16s/epoch - 706ms/step
# Epoch 32/100
# 22/22 - 16s - loss: 0.2543 - accuracy: 0.9204 - val_loss: 0.7464 - val_accuracy: 0.8082 - 16s/epoch - 705ms/step
# Epoch 33/100
# 22/22 - 15s - loss: 0.2451 - accuracy: 0.9219 - val_loss: 0.7468 - val_accuracy: 0.7945 - 15s/epoch - 698ms/step
# Epoch 34/100
# 22/22 - 15s - loss: 0.2632 - accuracy: 0.9103 - val_loss: 0.7491 - val_accuracy: 0.7945 - 15s/epoch - 690ms/step
# Epoch 35/100
# 22/22 - 15s - loss: 0.2338 - accuracy: 0.9161 - val_loss: 0.7476 - val_accuracy: 0.7945 - 15s/epoch - 670ms/step
# Epoch 36/100
# 22/22 - 15s - loss: 0.2903 - accuracy: 0.8929 - val_loss: 0.7451 - val_accuracy: 0.7945 - 15s/epoch - 672ms/step
# Epoch 37/100
# 22/22 - 15s - loss: 0.2582 - accuracy: 0.9204 - val_loss: 0.7459 - val_accuracy: 0.7945 - 15s/epoch - 669ms/step
# Epoch 38/100
# 22/22 - 15s - loss: 0.2539 - accuracy: 0.9190 - val_loss: 0.7483 - val_accuracy: 0.7945 - 15s/epoch - 673ms/step
# Epoch 39/100
# 22/22 - 15s - loss: 0.2878 - accuracy: 0.9030 - val_loss: 0.7476 - val_accuracy: 0.7945 - 15s/epoch - 672ms/step
# Epoch 40/100
# 22/22 - 16s - loss: 0.2172 - accuracy: 0.9190 - val_loss: 0.7469 - val_accuracy: 0.7945 - 16s/epoch - 718ms/step
# Epoch 41/100
# 22/22 - 16s - loss: 0.3089 - accuracy: 0.9146 - val_loss: 0.7496 - val_accuracy: 0.7945 - 16s/epoch - 705ms/step
# Epoch 42/100
# 22/22 - 16s - loss: 0.2816 - accuracy: 0.9103 - val_loss: 0.7513 - val_accuracy: 0.7945 - 16s/epoch - 726ms/step
# Epoch 43/100
# 22/22 - 16s - loss: 0.2797 - accuracy: 0.9030 - val_loss: 0.7515 - val_accuracy: 0.7945 - 16s/epoch - 718ms/step
# Epoch 44/100
# 22/22 - 16s - loss: 0.2425 - accuracy: 0.9117 - val_loss: 0.7496 - val_accuracy: 0.8082 - 16s/epoch - 725ms/step
# Epoch 45/100
# 22/22 - 16s - loss: 0.1753 - accuracy: 0.9349 - val_loss: 0.7488 - val_accuracy: 0.8082 - 16s/epoch - 709ms/step
# Epoch 46/100
# 22/22 - 16s - loss: 0.2340 - accuracy: 0.9320 - val_loss: 0.7483 - val_accuracy: 0.8082 - 16s/epoch - 716ms/step
# Epoch 46: early stopping

# %% [markdown]
# <h3>Accuracy and Loss graph</h3>

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# <h3>Classification report</h3>

# %%
predictions = model.predict(test, verbose=0)
# predictions = predictions.reshape(1,-1)[0]
lst = np.argmax(predictions, axis= 1)

print(classification_report(test.classes, lst, target_names = test.class_indices))
# Out:
#               precision    recall  f1-score   support
#
#     Duracell       0.76      0.93      0.84        14
#    Energizer       0.78      1.00      0.88        14
#     Eveready       0.89      0.80      0.84        10
#        Exell       1.00      0.89      0.94         9
#           GP       0.79      0.92      0.85        12
#         Ikea       1.00      0.89      0.94         9
#       Klarus       1.00      0.82      0.90        11
#    Panasonic       0.67      0.40      0.50        10
#
#     accuracy                           0.84        89
#    macro avg       0.86      0.83      0.84        89
# weighted avg       0.85      0.84      0.84        89

# %% [markdown]
# <h3>Confusion matrix</h3>

# %%
result = confusion_matrix(test.classes, lst)
print(result)

def plot_confusion_matrix(result, classes, cmap=plt.cm.Blues):
    plt.subplots(figsize=(7, 7))
    plt.imshow(result, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

    thresh = result.max() / 2.
    for i, j in itertools.product(range(result.shape[0]), range(result.shape[1])):
        plt.text(j, i, result[i, j],
            horizontalalignment="center",
            color = "white" if result[i, j] > thresh else "black")
        
    #current matplotlib version will cut off top and bottom of the matrix, 
    #hence the manual workaround - remove if matplotlib version does not cut off
    b, t = plt.ylim() # discover bottom and top values
    b += 0.5 # Add 0.5 to bottom
    t -= 0.5 # Subtract 0.5 from top
    plt.ylim(b, t) # update ylim(bottom, top) values
    plt.show()
    
plot_confusion_matrix(result, list(test.class_indices.keys()))
# Out:
# [[13  0  0  0  1  0  0  0]
#  [ 0 14  0  0  0  0  0  0]
#  [ 0  2  8  0  0  0  0  0]
#  [ 0  0  0  8  0  0  0  1]
#  [ 1  0  0  0 11  0  0  0]
#  [ 0  0  0  0  0  8  0  1]
#  [ 1  0  1  0  0  0  9  0]
#  [ 2  2  0  0  2  0  0  4]]

# %% [markdown]
# <h3>Labels of wrong predictions</h3>

# %%
def getErrors(test, predictions):
    #get file names of all images in test data
    names = test.filenames

    #get IDs of all classes
    allClassesID = test.classes

    #get dictionary of classes and respective ID
    classLabelDict = test.class_indices
    
    #list of the names of all classes
    classLabels = list(classLabelDict.keys())

    print("The list of classes: ", classLabels)

    #get the most predicted class
    predictedClasses = np.argmax(predictions, axis=1)

    predictedErrors = np.where(predictedClasses != allClassesID)[0]

    print("Number of errors = {}/{}".format(len(predictedErrors),test.samples))

    return classLabels, predictedErrors, names

def showErrors(classLabels, predictedErrors, predictions, names):
    # Show the errors
    for i in range(len(errors)):
        predictedClass = np.argmax(predictions[predictedErrors[i]])

        predictedLabel = classLabels[predictedClass]

        title = 'Original Picture : {}, Prediction : {}, Confidence/Percentage : {:.3f}'.format\
                (names[predictedErrors[i]].split('/')[0],predictedLabel, predictions[errors[i]][predictedClass])
        print(title)

# %%
#get the list of class labels, prediction errors and file names
labels, errors, names = getErrors(test, predictions)

#show wrongly predicted images, prediction and and the percentage (confidence)
showErrors(labels, errors, predictions, names)
# Out:
# The list of classes:  ['Duracell', 'Energizer', 'Eveready', 'Exell', 'GP', 'Ikea', 'Klarus', 'Panasonic']
# Number of errors = 14/89
# Original Picture : Duracell\norwich-norfolk-uk-november-15-2021-duracell-batteries-cut-out-isolated-on-a-plain-white-background-2H71GYA.jpg, Prediction : GP, Confidence/Percentage : 0.477
# Original Picture : Eveready\1 (2).jpeg, Prediction : Energizer, Confidence/Percentage : 0.993
# Original Picture : Eveready\41302b.jpg, Prediction : Energizer, Confidence/Percentage : 1.000
# Original Picture : Exell\Image_58.jpg, Prediction : Panasonic, Confidence/Percentage : 0.785
# Original Picture : GP\Image_43.png, Prediction : Duracell, Confidence/Percentage : 0.949
# Original Picture : Ikea\15 (2).jpeg, Prediction : Panasonic, Confidence/Percentage : 0.986
# Original Picture : Klarus\Image_21.jpg, Prediction : Eveready, Confidence/Percentage : 0.997
# Original Picture : Klarus\Image_42.jpg, Prediction : Duracell, Confidence/Percentage : 0.890
# Original Picture : Panasonic\11.jpg, Prediction : Energizer, Confidence/Percentage : 0.459
# Original Picture : Panasonic\22.jpg, Prediction : Energizer, Confidence/Percentage : 0.806
# Original Picture : Panasonic\26.jpg, Prediction : Duracell, Confidence/Percentage : 0.824
# Original Picture : Panasonic\30.jpg, Prediction : Duracell, Confidence/Percentage : 0.485
# Original Picture : Panasonic\33.jpg, Prediction : GP, Confidence/Percentage : 0.968
# Original Picture : Panasonic\Image_61.jpg, Prediction : GP, Confidence/Percentage : 0.796

# %% [markdown]
# <h3>Save the model</h3>

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model so that it can be passed to edge device
model.save("image_classification.h5")
