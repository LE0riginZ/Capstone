# %% [markdown]
# <h3>Import packages</h3>

# %%
from datetime import date
from timeit import default_timer as timer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import imagenet_utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Configure TensorFlow to use GPU for training
tf.config.list_physical_devices('GPU') 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
#Set GPU memory limit so my GPU doesn't crash
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <h3>Create class to record time taken to train the model</h3>

# %%
#class to record time taken to train per epoch
class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# <h3>Create train and test folder</h3>

# %%
#creates a folder each time the set of code is run to sort dataset into train and test
day = date.today()
formatDate = day.strftime("%b-%d-%Y")

#create folder with current date to group predictions ran in a day together, if it does not exists
if os.path.isdir('Prediction (' + formatDate + ')') is False:
    folder = os.mkdir('Prediction (' + formatDate + ')')
folder = 'Prediction (' + formatDate + ')'

#looping through to find if destination folder exists
i = 1
while True:
    if os.path.isdir(folder + '/Battery Images - ' + str(i)) is False:
        break
    i += 1

#destination path for unsorted folder
destination = folder + '/Battery Images - ' + str(i)

#source path for unsorted folder
# source = 'Battery Images/'
# source = 'Battery Images [Old]/'
# source = 'Battery Images [StreamLined]/'
source = 'Battery Images [Download]/'

#duplicate the unsorted folder from source to destination
shutil.copytree(source, destination)

os.mkdir(destination + '/train')
os.mkdir(destination + '/test')

# %% [markdown]
# <h3>Sort dataset into train and test folder</h3>

# %%
#function to split images into training (80%) and testing (20%) and return both
def split(data):
    # num = int(len(data) * 0.8)
    num = int(len(data) * 0.9) #90/10 split
#     num = int(len(data) * 0.7) #70/30 split
    random.shuffle(data)
    return data[:num], data[num:]

dir = os.chdir(destination)
for category in os.listdir(dir):
    #skip the iteration if folder is "train" or "test"
    skip = ['train', 'test']
    if category in skip:
        continue
    
    shutil.move(f'{category}', 'train')
    #create a subfolder with the same name in test
    os.mkdir(f'test/{category}')

    #get the images in each folder (battery type) for spltting of data into training and testing
    img = os.listdir(f'train/{category}')
    training, testing = split(img)
    
    for file in testing:
        shutil.move(f'train/{category}/{file}', f'test/{category}')

# %% [markdown]
# <h3>b) Transfer Learning - MobileNet</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.mobilenet.MobileNet(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %% [markdown]
# <h3>c) Transfer Learning - MobileNetV2</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.MobileNetV2(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
mobile.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_2[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
for layer in mobile.layers[:-2]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = mobile(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
# x = tf.keras.layers.Dropout(0.65)(x) #Higher dropout to reduce overfitting (last best setting)
# output = tf.keras.layers.Dense(5, activation="softmax")(x)   
# output = tf.keras.layers.Dense(10, activation="softmax")(x)   #Changed to reflect new categories
output = tf.keras.layers.Dense(8, activation="softmax")(x)   #Changed to reflect new categories

model = keras.Model(inputs, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 8)                 10248
#
# =================================================================
# Total params: 2,268,232
# Trainable params: 12,808
# Non-trainable params: 2,255,424
# _________________________________________________________________

# %% [markdown]
# <h3>Process data</h3>

# %%
train_path = 'train'
test_path = 'test'

#for data augmentation on training data
datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet.preprocess_input,
    # validation_split=0.2,
    validation_split=0.1, #changes made for 90/10 split
    rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.2, # Randomly zoom image 
    width_shift_range = 0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range = 0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip = True,  # randomly flip images
#     vertical_flip = False,    # randomly flip images
    vertical_flip = True, #include vertical flip for better generalisation
    )  

#takes images from directory path and generates batches of augmented data
train = datagen.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='training',
        shuffle = False)

#for validation data
# validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
#                                         validation_split=0.2)
validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
                                        validation_split=0.1) #changes made for 90/10 split


validation = validation_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='validation',
        shuffle = False)

#for test data
test = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input)\
.flow_from_directory(directory=test_path, target_size=(224,224), batch_size=32, shuffle=False)
# Out:
# Found 691 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 89 images belonging to 8 classes.

# %% [markdown]
# <h3>Train model</h3>

# %%
model.compile(optimizer=Adam(learning_rate=0.006), loss='categorical_crossentropy', metrics=['accuracy']) #Last best setting
# model.compile(optimizer=Adam(learning_rate=0.0045), loss='categorical_crossentropy', metrics=['accuracy']) #Lower LR
# model.compile(optimizer=Adam(learning_rate=0.0075), loss='categorical_crossentropy', metrics=['accuracy']) 
checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True) #save best model

#more epochs for better results
result = model.fit(x=train, validation_data=validation, epochs=300, verbose=2, callbacks=[model_checkpoint_callback,cb])
# result = model.fit(x=train, validation_data=validation, epochs=200, verbose=2, callbacks=[cb])
# Out:
# Epoch 1/300
# c:\Users\ngden\anaconda3\lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 22/22 - 25s - loss: 6.2371 - accuracy: 0.1013 - val_loss: 2.8076 - val_accuracy: 0.3014 - 25s/epoch - 1s/step
# Epoch 2/300
# 22/22 - 14s - loss: 3.6211 - accuracy: 0.2272 - val_loss: 2.0143 - val_accuracy: 0.5890 - 14s/epoch - 638ms/step
# Epoch 3/300
# 22/22 - 14s - loss: 1.6171 - accuracy: 0.5007 - val_loss: 1.6247 - val_accuracy: 0.4932 - 14s/epoch - 623ms/step
# Epoch 4/300
# 22/22 - 14s - loss: 1.3501 - accuracy: 0.5716 - val_loss: 1.5454 - val_accuracy: 0.6164 - 14s/epoch - 641ms/step
# Epoch 5/300
# 22/22 - 14s - loss: 1.1801 - accuracy: 0.6266 - val_loss: 1.5312 - val_accuracy: 0.5479 - 14s/epoch - 626ms/step
# Epoch 6/300
# 22/22 - 14s - loss: 1.0530 - accuracy: 0.6889 - val_loss: 1.2928 - val_accuracy: 0.6164 - 14s/epoch - 630ms/step
# Epoch 7/300
# 22/22 - 14s - loss: 0.8685 - accuracy: 0.7207 - val_loss: 1.1716 - val_accuracy: 0.6575 - 14s/epoch - 636ms/step
# Epoch 8/300
# 22/22 - 14s - loss: 0.8737 - accuracy: 0.7192 - val_loss: 1.2570 - val_accuracy: 0.5479 - 14s/epoch - 627ms/step
# Epoch 9/300
# 22/22 - 14s - loss: 0.7618 - accuracy: 0.7525 - val_loss: 1.0156 - val_accuracy: 0.7260 - 14s/epoch - 643ms/step
# Epoch 10/300
# 22/22 - 14s - loss: 0.7670 - accuracy: 0.7467 - val_loss: 0.8532 - val_accuracy: 0.7123 - 14s/epoch - 625ms/step
# Epoch 11/300
# 22/22 - 14s - loss: 0.6393 - accuracy: 0.7858 - val_loss: 1.2195 - val_accuracy: 0.7123 - 14s/epoch - 626ms/step
# Epoch 12/300
# 22/22 - 14s - loss: 0.6366 - accuracy: 0.7728 - val_loss: 0.8126 - val_accuracy: 0.6849 - 14s/epoch - 628ms/step
# Epoch 13/300
# 22/22 - 14s - loss: 0.6261 - accuracy: 0.7699 - val_loss: 1.3134 - val_accuracy: 0.5753 - 14s/epoch - 634ms/step
# Epoch 14/300
# 22/22 - 14s - loss: 0.7154 - accuracy: 0.7887 - val_loss: 1.4398 - val_accuracy: 0.6575 - 14s/epoch - 623ms/step
# Epoch 15/300
# 22/22 - 14s - loss: 0.6622 - accuracy: 0.7974 - val_loss: 0.6605 - val_accuracy: 0.8082 - 14s/epoch - 640ms/step
# Epoch 16/300
# 22/22 - 14s - loss: 0.6389 - accuracy: 0.7873 - val_loss: 1.1664 - val_accuracy: 0.6712 - 14s/epoch - 627ms/step
# Epoch 17/300
# 22/22 - 14s - loss: 0.6875 - accuracy: 0.7902 - val_loss: 0.9287 - val_accuracy: 0.7397 - 14s/epoch - 628ms/step
# Epoch 18/300
# 22/22 - 14s - loss: 0.4899 - accuracy: 0.8336 - val_loss: 0.8622 - val_accuracy: 0.7123 - 14s/epoch - 623ms/step
# Epoch 19/300
# 22/22 - 14s - loss: 0.4917 - accuracy: 0.8365 - val_loss: 0.8586 - val_accuracy: 0.7123 - 14s/epoch - 624ms/step
# Epoch 20/300
# 22/22 - 14s - loss: 0.6312 - accuracy: 0.7945 - val_loss: 0.9167 - val_accuracy: 0.6575 - 14s/epoch - 625ms/step
# Epoch 21/300
# 22/22 - 14s - loss: 0.6110 - accuracy: 0.7988 - val_loss: 0.8906 - val_accuracy: 0.7397 - 14s/epoch - 625ms/step
# Epoch 22/300
# 22/22 - 14s - loss: 0.4819 - accuracy: 0.8452 - val_loss: 0.9183 - val_accuracy: 0.7397 - 14s/epoch - 629ms/step
# Epoch 23/300
# 22/22 - 14s - loss: 0.4219 - accuracy: 0.8712 - val_loss: 0.6942 - val_accuracy: 0.7260 - 14s/epoch - 626ms/step
# Epoch 24/300
# 22/22 - 14s - loss: 0.4069 - accuracy: 0.8452 - val_loss: 0.8275 - val_accuracy: 0.7260 - 14s/epoch - 623ms/step
# Epoch 25/300
# 22/22 - 14s - loss: 0.4365 - accuracy: 0.8350 - val_loss: 0.8486 - val_accuracy: 0.7260 - 14s/epoch - 630ms/step
# Epoch 26/300
# 22/22 - 14s - loss: 0.4967 - accuracy: 0.8249 - val_loss: 1.1865 - val_accuracy: 0.6438 - 14s/epoch - 623ms/step
# Epoch 27/300
# 22/22 - 14s - loss: 0.5815 - accuracy: 0.8061 - val_loss: 0.7034 - val_accuracy: 0.7260 - 14s/epoch - 625ms/step
# Epoch 28/300
# 22/22 - 14s - loss: 0.3948 - accuracy: 0.8755 - val_loss: 0.8063 - val_accuracy: 0.7260 - 14s/epoch - 622ms/step
# Epoch 29/300
# 22/22 - 14s - loss: 0.4403 - accuracy: 0.8466 - val_loss: 0.9701 - val_accuracy: 0.7260 - 14s/epoch - 622ms/step
# Epoch 30/300
# 22/22 - 14s - loss: 0.5097 - accuracy: 0.8365 - val_loss: 0.6564 - val_accuracy: 0.8219 - 14s/epoch - 631ms/step
# Epoch 31/300
# 22/22 - 14s - loss: 0.4063 - accuracy: 0.8683 - val_loss: 1.0706 - val_accuracy: 0.7671 - 14s/epoch - 624ms/step
# Epoch 32/300
# 22/22 - 14s - loss: 0.4269 - accuracy: 0.8495 - val_loss: 1.0800 - val_accuracy: 0.7397 - 14s/epoch - 620ms/step
# Epoch 33/300
# 22/22 - 14s - loss: 0.6280 - accuracy: 0.7902 - val_loss: 0.8534 - val_accuracy: 0.7534 - 14s/epoch - 625ms/step
# Epoch 34/300
# 22/22 - 14s - loss: 0.4228 - accuracy: 0.8640 - val_loss: 0.9451 - val_accuracy: 0.7260 - 14s/epoch - 623ms/step
# Epoch 35/300
# 22/22 - 14s - loss: 0.4235 - accuracy: 0.8365 - val_loss: 0.9407 - val_accuracy: 0.7260 - 14s/epoch - 629ms/step
# Epoch 36/300
# 22/22 - 14s - loss: 0.3873 - accuracy: 0.8712 - val_loss: 0.7265 - val_accuracy: 0.7808 - 14s/epoch - 622ms/step
# Epoch 37/300
# 22/22 - 14s - loss: 0.3402 - accuracy: 0.8857 - val_loss: 0.8089 - val_accuracy: 0.7808 - 14s/epoch - 622ms/step
# Epoch 38/300
# 22/22 - 14s - loss: 0.4007 - accuracy: 0.8799 - val_loss: 0.9222 - val_accuracy: 0.7123 - 14s/epoch - 639ms/step
# Epoch 39/300
# 22/22 - 15s - loss: 0.3344 - accuracy: 0.8915 - val_loss: 0.8133 - val_accuracy: 0.7397 - 15s/epoch - 660ms/step
# Epoch 40/300
# 22/22 - 15s - loss: 0.3415 - accuracy: 0.8770 - val_loss: 0.8346 - val_accuracy: 0.7534 - 15s/epoch - 665ms/step
# Epoch 41/300
# 22/22 - 15s - loss: 0.3286 - accuracy: 0.8828 - val_loss: 0.9053 - val_accuracy: 0.7534 - 15s/epoch - 662ms/step
# Epoch 42/300
# 22/22 - 14s - loss: 0.4763 - accuracy: 0.8480 - val_loss: 0.9517 - val_accuracy: 0.7397 - 14s/epoch - 655ms/step
# Epoch 43/300
# 22/22 - 14s - loss: 0.4201 - accuracy: 0.8625 - val_loss: 1.0720 - val_accuracy: 0.7260 - 14s/epoch - 620ms/step
# Epoch 44/300
# 22/22 - 14s - loss: 0.2735 - accuracy: 0.9030 - val_loss: 0.9473 - val_accuracy: 0.7671 - 14s/epoch - 619ms/step
# Epoch 45/300
# 22/22 - 14s - loss: 0.3804 - accuracy: 0.8726 - val_loss: 0.8653 - val_accuracy: 0.7808 - 14s/epoch - 623ms/step
# Epoch 46/300
# 22/22 - 14s - loss: 0.2933 - accuracy: 0.8915 - val_loss: 0.9713 - val_accuracy: 0.7397 - 14s/epoch - 621ms/step
# Epoch 47/300
# 22/22 - 14s - loss: 0.3574 - accuracy: 0.8900 - val_loss: 0.7990 - val_accuracy: 0.7397 - 14s/epoch - 624ms/step
# Epoch 48/300
# 22/22 - 14s - loss: 0.3205 - accuracy: 0.8900 - val_loss: 1.0782 - val_accuracy: 0.7534 - 14s/epoch - 619ms/step
# Epoch 49/300
# 22/22 - 14s - loss: 0.3139 - accuracy: 0.8900 - val_loss: 0.7959 - val_accuracy: 0.7671 - 14s/epoch - 622ms/step
# Epoch 50/300
# 22/22 - 14s - loss: 0.3064 - accuracy: 0.8915 - val_loss: 0.9617 - val_accuracy: 0.7397 - 14s/epoch - 626ms/step
# Epoch 51/300
# 22/22 - 14s - loss: 0.3194 - accuracy: 0.8857 - val_loss: 0.9403 - val_accuracy: 0.7260 - 14s/epoch - 621ms/step
# Epoch 52/300
# 22/22 - 14s - loss: 0.3904 - accuracy: 0.8625 - val_loss: 0.9300 - val_accuracy: 0.7534 - 14s/epoch - 620ms/step
# Epoch 53/300
# 22/22 - 14s - loss: 0.2742 - accuracy: 0.9016 - val_loss: 1.0253 - val_accuracy: 0.7123 - 14s/epoch - 619ms/step
# Epoch 54/300
# 22/22 - 14s - loss: 0.2707 - accuracy: 0.9117 - val_loss: 0.9257 - val_accuracy: 0.7397 - 14s/epoch - 619ms/step
# Epoch 55/300
# 22/22 - 14s - loss: 0.2466 - accuracy: 0.9074 - val_loss: 1.0930 - val_accuracy: 0.7808 - 14s/epoch - 628ms/step
# Epoch 56/300
# 22/22 - 14s - loss: 0.3497 - accuracy: 0.8813 - val_loss: 0.8857 - val_accuracy: 0.7671 - 14s/epoch - 619ms/step
# Epoch 57/300
# 22/22 - 14s - loss: 0.3803 - accuracy: 0.8596 - val_loss: 1.0989 - val_accuracy: 0.7397 - 14s/epoch - 628ms/step
# Epoch 58/300
# 22/22 - 14s - loss: 0.3530 - accuracy: 0.8900 - val_loss: 1.1877 - val_accuracy: 0.6986 - 14s/epoch - 622ms/step
# Epoch 59/300
# 22/22 - 14s - loss: 0.4874 - accuracy: 0.8452 - val_loss: 1.2098 - val_accuracy: 0.7123 - 14s/epoch - 615ms/step
# Epoch 60/300
# 22/22 - 14s - loss: 0.3474 - accuracy: 0.8828 - val_loss: 1.0949 - val_accuracy: 0.7260 - 14s/epoch - 618ms/step
# Epoch 61/300
# 22/22 - 14s - loss: 0.5241 - accuracy: 0.8423 - val_loss: 1.1933 - val_accuracy: 0.6849 - 14s/epoch - 619ms/step
# Epoch 62/300
# 22/22 - 14s - loss: 0.3364 - accuracy: 0.8944 - val_loss: 0.9080 - val_accuracy: 0.7397 - 14s/epoch - 618ms/step
# Epoch 63/300
# 22/22 - 14s - loss: 0.4205 - accuracy: 0.8669 - val_loss: 1.2403 - val_accuracy: 0.7260 - 14s/epoch - 618ms/step
# Epoch 64/300
# 22/22 - 14s - loss: 0.5632 - accuracy: 0.8437 - val_loss: 1.2201 - val_accuracy: 0.7123 - 14s/epoch - 622ms/step
# Epoch 65/300
# 22/22 - 14s - loss: 0.3637 - accuracy: 0.8813 - val_loss: 0.8791 - val_accuracy: 0.7808 - 14s/epoch - 616ms/step
# Epoch 66/300
# 22/22 - 14s - loss: 0.3324 - accuracy: 0.8886 - val_loss: 0.9890 - val_accuracy: 0.7397 - 14s/epoch - 618ms/step
# Epoch 67/300
# 22/22 - 14s - loss: 0.3776 - accuracy: 0.8741 - val_loss: 1.1204 - val_accuracy: 0.7397 - 14s/epoch - 619ms/step
# Epoch 68/300
# 22/22 - 14s - loss: 0.3316 - accuracy: 0.9001 - val_loss: 0.9017 - val_accuracy: 0.7534 - 14s/epoch - 619ms/step
# Epoch 69/300
# 22/22 - 14s - loss: 0.2560 - accuracy: 0.9161 - val_loss: 0.8533 - val_accuracy: 0.7671 - 14s/epoch - 620ms/step
# Epoch 70/300
# 22/22 - 14s - loss: 0.2870 - accuracy: 0.9045 - val_loss: 0.9116 - val_accuracy: 0.7123 - 14s/epoch - 616ms/step
# Epoch 71/300
# 22/22 - 14s - loss: 0.2448 - accuracy: 0.9103 - val_loss: 1.1200 - val_accuracy: 0.7534 - 14s/epoch - 624ms/step
# Epoch 72/300
# 22/22 - 14s - loss: 0.3674 - accuracy: 0.8698 - val_loss: 1.0475 - val_accuracy: 0.7534 - 14s/epoch - 619ms/step
# Epoch 73/300
# 22/22 - 14s - loss: 0.3074 - accuracy: 0.8842 - val_loss: 0.9459 - val_accuracy: 0.7260 - 14s/epoch - 617ms/step
# Epoch 74/300
# 22/22 - 14s - loss: 0.3464 - accuracy: 0.8799 - val_loss: 1.0277 - val_accuracy: 0.7808 - 14s/epoch - 619ms/step
# Epoch 75/300
# 22/22 - 14s - loss: 0.2873 - accuracy: 0.8915 - val_loss: 1.0946 - val_accuracy: 0.7397 - 14s/epoch - 621ms/step
# Epoch 76/300
# 22/22 - 14s - loss: 0.3074 - accuracy: 0.8987 - val_loss: 1.1240 - val_accuracy: 0.7534 - 14s/epoch - 622ms/step
# Epoch 77/300
# 22/22 - 14s - loss: 0.3519 - accuracy: 0.8987 - val_loss: 0.9718 - val_accuracy: 0.7671 - 14s/epoch - 619ms/step
# Epoch 78/300
# 22/22 - 14s - loss: 0.2405 - accuracy: 0.9161 - val_loss: 0.9609 - val_accuracy: 0.7671 - 14s/epoch - 626ms/step
# Epoch 79/300
# 22/22 - 14s - loss: 0.3128 - accuracy: 0.8886 - val_loss: 0.9204 - val_accuracy: 0.7260 - 14s/epoch - 617ms/step
# Epoch 80/300
# 22/22 - 14s - loss: 0.3674 - accuracy: 0.8958 - val_loss: 1.3315 - val_accuracy: 0.7534 - 14s/epoch - 627ms/step
# Epoch 81/300
# 22/22 - 14s - loss: 0.4716 - accuracy: 0.8567 - val_loss: 0.9731 - val_accuracy: 0.7671 - 14s/epoch - 621ms/step
# Epoch 82/300
# 22/22 - 14s - loss: 0.3027 - accuracy: 0.9030 - val_loss: 0.8148 - val_accuracy: 0.7808 - 14s/epoch - 620ms/step
# Epoch 83/300
# 22/22 - 14s - loss: 0.3438 - accuracy: 0.8973 - val_loss: 0.8498 - val_accuracy: 0.7808 - 14s/epoch - 624ms/step
# Epoch 84/300
# 22/22 - 14s - loss: 0.3839 - accuracy: 0.8712 - val_loss: 1.1075 - val_accuracy: 0.7534 - 14s/epoch - 617ms/step
# Epoch 85/300
# 22/22 - 14s - loss: 0.2537 - accuracy: 0.9059 - val_loss: 1.0462 - val_accuracy: 0.7671 - 14s/epoch - 637ms/step
# Epoch 86/300
# 22/22 - 14s - loss: 0.2712 - accuracy: 0.8973 - val_loss: 1.0413 - val_accuracy: 0.7671 - 14s/epoch - 633ms/step
# Epoch 87/300
# 22/22 - 14s - loss: 0.2718 - accuracy: 0.9045 - val_loss: 0.9545 - val_accuracy: 0.7808 - 14s/epoch - 620ms/step
# Epoch 88/300
# 22/22 - 14s - loss: 0.2577 - accuracy: 0.9059 - val_loss: 1.3072 - val_accuracy: 0.7534 - 14s/epoch - 618ms/step
# Epoch 89/300
# 22/22 - 14s - loss: 0.3105 - accuracy: 0.8973 - val_loss: 0.8742 - val_accuracy: 0.7808 - 14s/epoch - 618ms/step
# Epoch 90/300
# 22/22 - 14s - loss: 0.2568 - accuracy: 0.9219 - val_loss: 1.0837 - val_accuracy: 0.7671 - 14s/epoch - 621ms/step
# Epoch 91/300
# 22/22 - 14s - loss: 0.2591 - accuracy: 0.8958 - val_loss: 1.0292 - val_accuracy: 0.7397 - 14s/epoch - 623ms/step
# Epoch 92/300
# 22/22 - 14s - loss: 0.2609 - accuracy: 0.9161 - val_loss: 1.1020 - val_accuracy: 0.7534 - 14s/epoch - 617ms/step
# Epoch 93/300
# 22/22 - 14s - loss: 0.3942 - accuracy: 0.8813 - val_loss: 0.9097 - val_accuracy: 0.7808 - 14s/epoch - 616ms/step
# Epoch 94/300
# 22/22 - 14s - loss: 0.2741 - accuracy: 0.9175 - val_loss: 1.2382 - val_accuracy: 0.7260 - 14s/epoch - 618ms/step
# Epoch 95/300
# 22/22 - 14s - loss: 0.2200 - accuracy: 0.9219 - val_loss: 0.9152 - val_accuracy: 0.7671 - 14s/epoch - 622ms/step
# Epoch 96/300
# 22/22 - 14s - loss: 0.3139 - accuracy: 0.8987 - val_loss: 0.9827 - val_accuracy: 0.7671 - 14s/epoch - 624ms/step
# Epoch 97/300
# 22/22 - 14s - loss: 0.3145 - accuracy: 0.8900 - val_loss: 1.0401 - val_accuracy: 0.7534 - 14s/epoch - 625ms/step
# Epoch 98/300
# 22/22 - 14s - loss: 0.3411 - accuracy: 0.8973 - val_loss: 0.9042 - val_accuracy: 0.8356 - 14s/epoch - 643ms/step
# Epoch 99/300
# 22/22 - 14s - loss: 0.2535 - accuracy: 0.9103 - val_loss: 1.2226 - val_accuracy: 0.7534 - 14s/epoch - 627ms/step
# Epoch 100/300
# 22/22 - 14s - loss: 0.3380 - accuracy: 0.8857 - val_loss: 1.2405 - val_accuracy: 0.7534 - 14s/epoch - 625ms/step
# Epoch 101/300
# 22/22 - 14s - loss: 0.3630 - accuracy: 0.8799 - val_loss: 1.1577 - val_accuracy: 0.7671 - 14s/epoch - 622ms/step
# Epoch 102/300
# 22/22 - 14s - loss: 0.3089 - accuracy: 0.9045 - val_loss: 0.9245 - val_accuracy: 0.7534 - 14s/epoch - 626ms/step
# Epoch 103/300
# 22/22 - 14s - loss: 0.2465 - accuracy: 0.9161 - val_loss: 0.9486 - val_accuracy: 0.7808 - 14s/epoch - 621ms/step
# Epoch 104/300
# 22/22 - 14s - loss: 0.2894 - accuracy: 0.9045 - val_loss: 0.9830 - val_accuracy: 0.7534 - 14s/epoch - 625ms/step
# Epoch 105/300
# 22/22 - 14s - loss: 0.2762 - accuracy: 0.9045 - val_loss: 0.8896 - val_accuracy: 0.7945 - 14s/epoch - 622ms/step
# Epoch 106/300
# 22/22 - 14s - loss: 0.2315 - accuracy: 0.9262 - val_loss: 0.9554 - val_accuracy: 0.7397 - 14s/epoch - 623ms/step
# Epoch 107/300
# 22/22 - 14s - loss: 0.2767 - accuracy: 0.9175 - val_loss: 0.8797 - val_accuracy: 0.7945 - 14s/epoch - 630ms/step
# Epoch 108/300
# 22/22 - 14s - loss: 0.3241 - accuracy: 0.9001 - val_loss: 0.9837 - val_accuracy: 0.7397 - 14s/epoch - 619ms/step
# Epoch 109/300
# 22/22 - 14s - loss: 0.3264 - accuracy: 0.8915 - val_loss: 0.8786 - val_accuracy: 0.7397 - 14s/epoch - 619ms/step
# Epoch 110/300
# 22/22 - 14s - loss: 0.3720 - accuracy: 0.8842 - val_loss: 0.9948 - val_accuracy: 0.7123 - 14s/epoch - 618ms/step
# Epoch 111/300
# 22/22 - 14s - loss: 0.3385 - accuracy: 0.9059 - val_loss: 1.0469 - val_accuracy: 0.7397 - 14s/epoch - 621ms/step
# Epoch 112/300
# 22/22 - 14s - loss: 0.2551 - accuracy: 0.9088 - val_loss: 0.9862 - val_accuracy: 0.7534 - 14s/epoch - 624ms/step
# Epoch 113/300
# 22/22 - 14s - loss: 0.2392 - accuracy: 0.9247 - val_loss: 1.2655 - val_accuracy: 0.7260 - 14s/epoch - 639ms/step
# Epoch 114/300
# 22/22 - 14s - loss: 0.3050 - accuracy: 0.8987 - val_loss: 0.8281 - val_accuracy: 0.7671 - 14s/epoch - 647ms/step
# Epoch 115/300
# 22/22 - 14s - loss: 0.2525 - accuracy: 0.9204 - val_loss: 1.0052 - val_accuracy: 0.7397 - 14s/epoch - 628ms/step
# Epoch 116/300
# 22/22 - 14s - loss: 0.2725 - accuracy: 0.9117 - val_loss: 1.2391 - val_accuracy: 0.7397 - 14s/epoch - 635ms/step
# Epoch 117/300
# 22/22 - 14s - loss: 0.2813 - accuracy: 0.9103 - val_loss: 1.2052 - val_accuracy: 0.7671 - 14s/epoch - 644ms/step
# Epoch 118/300
# 22/22 - 16s - loss: 0.1939 - accuracy: 0.9262 - val_loss: 0.9571 - val_accuracy: 0.7808 - 16s/epoch - 745ms/step
# Epoch 119/300
# 22/22 - 15s - loss: 0.2670 - accuracy: 0.9088 - val_loss: 1.0284 - val_accuracy: 0.7671 - 15s/epoch - 668ms/step
# Epoch 120/300
# 22/22 - 15s - loss: 0.2664 - accuracy: 0.9132 - val_loss: 1.0370 - val_accuracy: 0.7534 - 15s/epoch - 660ms/step
# Epoch 121/300
# 22/22 - 14s - loss: 0.2038 - accuracy: 0.9334 - val_loss: 1.1482 - val_accuracy: 0.7534 - 14s/epoch - 645ms/step
# Epoch 122/300
# 22/22 - 15s - loss: 0.2609 - accuracy: 0.9117 - val_loss: 0.9328 - val_accuracy: 0.7671 - 15s/epoch - 659ms/step
# Epoch 123/300
# 22/22 - 14s - loss: 0.3495 - accuracy: 0.9030 - val_loss: 1.2836 - val_accuracy: 0.7397 - 14s/epoch - 641ms/step
# Epoch 124/300
# 22/22 - 14s - loss: 0.3257 - accuracy: 0.8871 - val_loss: 1.0508 - val_accuracy: 0.7534 - 14s/epoch - 647ms/step
# Epoch 125/300
# 22/22 - 14s - loss: 0.2731 - accuracy: 0.9117 - val_loss: 1.1270 - val_accuracy: 0.7671 - 14s/epoch - 647ms/step
# Epoch 126/300
# 22/22 - 14s - loss: 0.2975 - accuracy: 0.9247 - val_loss: 0.9433 - val_accuracy: 0.7945 - 14s/epoch - 640ms/step
# Epoch 127/300
# 22/22 - 14s - loss: 0.2435 - accuracy: 0.9146 - val_loss: 1.3280 - val_accuracy: 0.7397 - 14s/epoch - 654ms/step
# Epoch 128/300
# 22/22 - 15s - loss: 0.3465 - accuracy: 0.8784 - val_loss: 0.9497 - val_accuracy: 0.7671 - 15s/epoch - 662ms/step
# Epoch 129/300
# 22/22 - 14s - loss: 0.3267 - accuracy: 0.8958 - val_loss: 1.0369 - val_accuracy: 0.7534 - 14s/epoch - 635ms/step
# Epoch 130/300
# 22/22 - 14s - loss: 0.3462 - accuracy: 0.9016 - val_loss: 1.0064 - val_accuracy: 0.7671 - 14s/epoch - 641ms/step
# Epoch 131/300
# 22/22 - 14s - loss: 0.2987 - accuracy: 0.9132 - val_loss: 0.9928 - val_accuracy: 0.7808 - 14s/epoch - 651ms/step
# Epoch 132/300
# 22/22 - 14s - loss: 0.1886 - accuracy: 0.9378 - val_loss: 1.0843 - val_accuracy: 0.7534 - 14s/epoch - 649ms/step
# Epoch 133/300
# 22/22 - 14s - loss: 0.2622 - accuracy: 0.9045 - val_loss: 1.0845 - val_accuracy: 0.7397 - 14s/epoch - 642ms/step
# Epoch 134/300
# 22/22 - 14s - loss: 0.2193 - accuracy: 0.9204 - val_loss: 1.0399 - val_accuracy: 0.7534 - 14s/epoch - 650ms/step
# Epoch 135/300
# 22/22 - 14s - loss: 0.2541 - accuracy: 0.9074 - val_loss: 1.1434 - val_accuracy: 0.7397 - 14s/epoch - 652ms/step
# Epoch 136/300
# 22/22 - 14s - loss: 0.2624 - accuracy: 0.9045 - val_loss: 1.0012 - val_accuracy: 0.7671 - 14s/epoch - 649ms/step
# Epoch 137/300
# 22/22 - 14s - loss: 0.2962 - accuracy: 0.9103 - val_loss: 1.2905 - val_accuracy: 0.7534 - 14s/epoch - 645ms/step
# Epoch 138/300
# 22/22 - 14s - loss: 0.3995 - accuracy: 0.8886 - val_loss: 0.9781 - val_accuracy: 0.7671 - 14s/epoch - 649ms/step
# Epoch 139/300
# 22/22 - 14s - loss: 0.2446 - accuracy: 0.9132 - val_loss: 1.0267 - val_accuracy: 0.7397 - 14s/epoch - 649ms/step
# Epoch 140/300
# 22/22 - 14s - loss: 0.2262 - accuracy: 0.9334 - val_loss: 1.0996 - val_accuracy: 0.7123 - 14s/epoch - 645ms/step
# Epoch 141/300
# 22/22 - 14s - loss: 0.2906 - accuracy: 0.9146 - val_loss: 0.9038 - val_accuracy: 0.8082 - 14s/epoch - 649ms/step
# Epoch 142/300
# 22/22 - 14s - loss: 0.2500 - accuracy: 0.9233 - val_loss: 1.0840 - val_accuracy: 0.7397 - 14s/epoch - 657ms/step
# Epoch 143/300
# 22/22 - 14s - loss: 0.2477 - accuracy: 0.9247 - val_loss: 0.9820 - val_accuracy: 0.7671 - 14s/epoch - 652ms/step
# Epoch 144/300
# 22/22 - 15s - loss: 0.2489 - accuracy: 0.9175 - val_loss: 0.9620 - val_accuracy: 0.7671 - 15s/epoch - 663ms/step
# Epoch 145/300
# 22/22 - 14s - loss: 0.2527 - accuracy: 0.9190 - val_loss: 1.2206 - val_accuracy: 0.7534 - 14s/epoch - 654ms/step
# Epoch 146/300
# 22/22 - 15s - loss: 0.2838 - accuracy: 0.9146 - val_loss: 1.1536 - val_accuracy: 0.7123 - 15s/epoch - 660ms/step
# Epoch 147/300
# 22/22 - 15s - loss: 0.4356 - accuracy: 0.8524 - val_loss: 1.0549 - val_accuracy: 0.7260 - 15s/epoch - 659ms/step
# Epoch 148/300
# 22/22 - 14s - loss: 0.3003 - accuracy: 0.9088 - val_loss: 1.1260 - val_accuracy: 0.7808 - 14s/epoch - 653ms/step
# Epoch 149/300
# 22/22 - 14s - loss: 0.2642 - accuracy: 0.9204 - val_loss: 0.9630 - val_accuracy: 0.7945 - 14s/epoch - 646ms/step
# Epoch 150/300
# 22/22 - 14s - loss: 0.2492 - accuracy: 0.9146 - val_loss: 0.9024 - val_accuracy: 0.7808 - 14s/epoch - 648ms/step
# Epoch 151/300
# 22/22 - 14s - loss: 0.2808 - accuracy: 0.9059 - val_loss: 1.2043 - val_accuracy: 0.7534 - 14s/epoch - 644ms/step
# Epoch 152/300
# 22/22 - 14s - loss: 0.3195 - accuracy: 0.9161 - val_loss: 1.0805 - val_accuracy: 0.8082 - 14s/epoch - 651ms/step
# Epoch 153/300
# 22/22 - 14s - loss: 0.2552 - accuracy: 0.9233 - val_loss: 1.2899 - val_accuracy: 0.7397 - 14s/epoch - 632ms/step
# Epoch 154/300
# 22/22 - 14s - loss: 0.2591 - accuracy: 0.9030 - val_loss: 1.2122 - val_accuracy: 0.7260 - 14s/epoch - 621ms/step
# Epoch 155/300
# 22/22 - 14s - loss: 0.2480 - accuracy: 0.9262 - val_loss: 0.9703 - val_accuracy: 0.7671 - 14s/epoch - 626ms/step
# Epoch 156/300
# 22/22 - 14s - loss: 0.2837 - accuracy: 0.9074 - val_loss: 1.0665 - val_accuracy: 0.7260 - 14s/epoch - 620ms/step
# Epoch 157/300
# 22/22 - 14s - loss: 0.3109 - accuracy: 0.9074 - val_loss: 1.1539 - val_accuracy: 0.7260 - 14s/epoch - 618ms/step
# Epoch 158/300
# 22/22 - 14s - loss: 0.2566 - accuracy: 0.9161 - val_loss: 1.1891 - val_accuracy: 0.7123 - 14s/epoch - 658ms/step
# Epoch 159/300
# 22/22 - 15s - loss: 0.2574 - accuracy: 0.9291 - val_loss: 1.0595 - val_accuracy: 0.7808 - 15s/epoch - 662ms/step
# Epoch 160/300
# 22/22 - 14s - loss: 0.3218 - accuracy: 0.9074 - val_loss: 0.9986 - val_accuracy: 0.7397 - 14s/epoch - 642ms/step
# Epoch 161/300
# 22/22 - 14s - loss: 0.3246 - accuracy: 0.8944 - val_loss: 1.0289 - val_accuracy: 0.7671 - 14s/epoch - 644ms/step
# Epoch 162/300
# 22/22 - 14s - loss: 0.3125 - accuracy: 0.9103 - val_loss: 1.0510 - val_accuracy: 0.7808 - 14s/epoch - 640ms/step
# Epoch 163/300
# 22/22 - 14s - loss: 0.3040 - accuracy: 0.9059 - val_loss: 1.0366 - val_accuracy: 0.7808 - 14s/epoch - 640ms/step
# Epoch 164/300
# 22/22 - 14s - loss: 0.1806 - accuracy: 0.9276 - val_loss: 1.1306 - val_accuracy: 0.7945 - 14s/epoch - 639ms/step
# Epoch 165/300
# 22/22 - 14s - loss: 0.2244 - accuracy: 0.9291 - val_loss: 1.1139 - val_accuracy: 0.7808 - 14s/epoch - 649ms/step
# Epoch 166/300
# 22/22 - 15s - loss: 0.3085 - accuracy: 0.9132 - val_loss: 1.1141 - val_accuracy: 0.7534 - 15s/epoch - 662ms/step
# Epoch 167/300
# 22/22 - 14s - loss: 0.3160 - accuracy: 0.9103 - val_loss: 1.1608 - val_accuracy: 0.7534 - 14s/epoch - 625ms/step
# Epoch 168/300
# 22/22 - 14s - loss: 0.2611 - accuracy: 0.9117 - val_loss: 1.0130 - val_accuracy: 0.7534 - 14s/epoch - 641ms/step
# Epoch 169/300
# 22/22 - 14s - loss: 0.2499 - accuracy: 0.9161 - val_loss: 1.1944 - val_accuracy: 0.7671 - 14s/epoch - 657ms/step
# Epoch 170/300
# 22/22 - 15s - loss: 0.3467 - accuracy: 0.8857 - val_loss: 1.2909 - val_accuracy: 0.7260 - 15s/epoch - 672ms/step
# Epoch 171/300
# 22/22 - 14s - loss: 0.3024 - accuracy: 0.9045 - val_loss: 1.0480 - val_accuracy: 0.7808 - 14s/epoch - 626ms/step
# Epoch 172/300
# 22/22 - 14s - loss: 0.2141 - accuracy: 0.9305 - val_loss: 0.9675 - val_accuracy: 0.7397 - 14s/epoch - 624ms/step
# Epoch 173/300
# 22/22 - 14s - loss: 0.2851 - accuracy: 0.9204 - val_loss: 1.0449 - val_accuracy: 0.7534 - 14s/epoch - 626ms/step
# Epoch 174/300
# 22/22 - 14s - loss: 0.2320 - accuracy: 0.9276 - val_loss: 1.1607 - val_accuracy: 0.8082 - 14s/epoch - 625ms/step
# Epoch 175/300
# 22/22 - 14s - loss: 0.3091 - accuracy: 0.9016 - val_loss: 1.1891 - val_accuracy: 0.7260 - 14s/epoch - 624ms/step
# Epoch 176/300
# 22/22 - 14s - loss: 0.3170 - accuracy: 0.8944 - val_loss: 1.0734 - val_accuracy: 0.7671 - 14s/epoch - 625ms/step
# Epoch 177/300
# 22/22 - 14s - loss: 0.2089 - accuracy: 0.9291 - val_loss: 1.0010 - val_accuracy: 0.7671 - 14s/epoch - 624ms/step
# Epoch 178/300
# 22/22 - 14s - loss: 0.2964 - accuracy: 0.9132 - val_loss: 0.9648 - val_accuracy: 0.7534 - 14s/epoch - 652ms/step
# Epoch 179/300
# 22/22 - 14s - loss: 0.3316 - accuracy: 0.8987 - val_loss: 1.1444 - val_accuracy: 0.7671 - 14s/epoch - 652ms/step
# Epoch 180/300
# 22/22 - 15s - loss: 0.2555 - accuracy: 0.9291 - val_loss: 1.0296 - val_accuracy: 0.8219 - 15s/epoch - 661ms/step
# Epoch 181/300
# 22/22 - 14s - loss: 0.2564 - accuracy: 0.9132 - val_loss: 1.0527 - val_accuracy: 0.8356 - 14s/epoch - 639ms/step
# Epoch 182/300
# 22/22 - 14s - loss: 0.2547 - accuracy: 0.9276 - val_loss: 1.0502 - val_accuracy: 0.7945 - 14s/epoch - 639ms/step
# Epoch 183/300
# 22/22 - 14s - loss: 0.1882 - accuracy: 0.9291 - val_loss: 0.9076 - val_accuracy: 0.8493 - 14s/epoch - 638ms/step
# Epoch 184/300
# 22/22 - 14s - loss: 0.2676 - accuracy: 0.9088 - val_loss: 1.0488 - val_accuracy: 0.7945 - 14s/epoch - 624ms/step
# Epoch 185/300
# 22/22 - 14s - loss: 0.2091 - accuracy: 0.9392 - val_loss: 1.0035 - val_accuracy: 0.8219 - 14s/epoch - 624ms/step
# Epoch 186/300
# 22/22 - 14s - loss: 0.2559 - accuracy: 0.9146 - val_loss: 1.1069 - val_accuracy: 0.7945 - 14s/epoch - 625ms/step
# Epoch 187/300
# 22/22 - 14s - loss: 0.3245 - accuracy: 0.9016 - val_loss: 1.1935 - val_accuracy: 0.8082 - 14s/epoch - 630ms/step
# Epoch 188/300
# 22/22 - 14s - loss: 0.2651 - accuracy: 0.9175 - val_loss: 1.1685 - val_accuracy: 0.8082 - 14s/epoch - 625ms/step
# Epoch 189/300
# 22/22 - 14s - loss: 0.2252 - accuracy: 0.9190 - val_loss: 1.0610 - val_accuracy: 0.8493 - 14s/epoch - 628ms/step
# Epoch 190/300
# 22/22 - 14s - loss: 0.2518 - accuracy: 0.9175 - val_loss: 0.9549 - val_accuracy: 0.7945 - 14s/epoch - 629ms/step
# Epoch 191/300
# 22/22 - 14s - loss: 0.2669 - accuracy: 0.9059 - val_loss: 1.0981 - val_accuracy: 0.7945 - 14s/epoch - 626ms/step
# Epoch 192/300
# 22/22 - 14s - loss: 0.2811 - accuracy: 0.9233 - val_loss: 1.1164 - val_accuracy: 0.7945 - 14s/epoch - 628ms/step
# Epoch 193/300
# 22/22 - 14s - loss: 0.2325 - accuracy: 0.9291 - val_loss: 1.0767 - val_accuracy: 0.7945 - 14s/epoch - 626ms/step
# Epoch 194/300
# 22/22 - 14s - loss: 0.2276 - accuracy: 0.9247 - val_loss: 1.1144 - val_accuracy: 0.7671 - 14s/epoch - 627ms/step
# Epoch 195/300
# 22/22 - 14s - loss: 0.2939 - accuracy: 0.8987 - val_loss: 1.1965 - val_accuracy: 0.7945 - 14s/epoch - 628ms/step
# Epoch 196/300
# 22/22 - 14s - loss: 0.2732 - accuracy: 0.9117 - val_loss: 0.9227 - val_accuracy: 0.8082 - 14s/epoch - 623ms/step
# Epoch 197/300
# 22/22 - 14s - loss: 0.2627 - accuracy: 0.9247 - val_loss: 0.9767 - val_accuracy: 0.7671 - 14s/epoch - 628ms/step
# Epoch 198/300
# 22/22 - 14s - loss: 0.2348 - accuracy: 0.9247 - val_loss: 1.1179 - val_accuracy: 0.7808 - 14s/epoch - 632ms/step
# Epoch 199/300
# 22/22 - 14s - loss: 0.2509 - accuracy: 0.9204 - val_loss: 1.0245 - val_accuracy: 0.8219 - 14s/epoch - 630ms/step
# Epoch 200/300
# 22/22 - 14s - loss: 0.1855 - accuracy: 0.9421 - val_loss: 1.1384 - val_accuracy: 0.7808 - 14s/epoch - 630ms/step
# Epoch 201/300
# 22/22 - 14s - loss: 0.2397 - accuracy: 0.9175 - val_loss: 1.0241 - val_accuracy: 0.7808 - 14s/epoch - 624ms/step
# Epoch 202/300
# 22/22 - 14s - loss: 0.3076 - accuracy: 0.9190 - val_loss: 1.1143 - val_accuracy: 0.7808 - 14s/epoch - 632ms/step
# Epoch 203/300
# 22/22 - 14s - loss: 0.2141 - accuracy: 0.9320 - val_loss: 1.0205 - val_accuracy: 0.7534 - 14s/epoch - 630ms/step
# Epoch 204/300
# 22/22 - 14s - loss: 0.2341 - accuracy: 0.9320 - val_loss: 1.1816 - val_accuracy: 0.7397 - 14s/epoch - 627ms/step
# Epoch 205/300
# 22/22 - 14s - loss: 0.2159 - accuracy: 0.9276 - val_loss: 1.3600 - val_accuracy: 0.7671 - 14s/epoch - 628ms/step
# Epoch 206/300
# 22/22 - 14s - loss: 0.2037 - accuracy: 0.9407 - val_loss: 1.0942 - val_accuracy: 0.7671 - 14s/epoch - 624ms/step
# Epoch 207/300
# 22/22 - 14s - loss: 0.3300 - accuracy: 0.9059 - val_loss: 1.2810 - val_accuracy: 0.7534 - 14s/epoch - 635ms/step
# Epoch 208/300
# 22/22 - 14s - loss: 0.2047 - accuracy: 0.9450 - val_loss: 1.1083 - val_accuracy: 0.7808 - 14s/epoch - 628ms/step
# Epoch 209/300
# 22/22 - 14s - loss: 0.2552 - accuracy: 0.9233 - val_loss: 1.3443 - val_accuracy: 0.7397 - 14s/epoch - 626ms/step
# Epoch 210/300
# 22/22 - 14s - loss: 0.2148 - accuracy: 0.9291 - val_loss: 1.3558 - val_accuracy: 0.7534 - 14s/epoch - 623ms/step
# Epoch 211/300
# 22/22 - 14s - loss: 0.3216 - accuracy: 0.9074 - val_loss: 1.1926 - val_accuracy: 0.7671 - 14s/epoch - 627ms/step
# Epoch 212/300
# 22/22 - 14s - loss: 0.1982 - accuracy: 0.9320 - val_loss: 1.1722 - val_accuracy: 0.7945 - 14s/epoch - 623ms/step
# Epoch 213/300
# 22/22 - 14s - loss: 0.2420 - accuracy: 0.9146 - val_loss: 1.1303 - val_accuracy: 0.8082 - 14s/epoch - 626ms/step
# Epoch 214/300
# 22/22 - 14s - loss: 0.2551 - accuracy: 0.9320 - val_loss: 1.2708 - val_accuracy: 0.7397 - 14s/epoch - 624ms/step
# Epoch 215/300
# 22/22 - 14s - loss: 0.2639 - accuracy: 0.9175 - val_loss: 1.4074 - val_accuracy: 0.7123 - 14s/epoch - 633ms/step
# Epoch 216/300
# 22/22 - 14s - loss: 0.2169 - accuracy: 0.9247 - val_loss: 1.1712 - val_accuracy: 0.7808 - 14s/epoch - 625ms/step
# Epoch 217/300
# 22/22 - 14s - loss: 0.2205 - accuracy: 0.9204 - val_loss: 1.1712 - val_accuracy: 0.7671 - 14s/epoch - 629ms/step
# Epoch 218/300
# 22/22 - 14s - loss: 0.1910 - accuracy: 0.9407 - val_loss: 1.1945 - val_accuracy: 0.7671 - 14s/epoch - 626ms/step
# Epoch 219/300
# 22/22 - 14s - loss: 0.2807 - accuracy: 0.9161 - val_loss: 1.2466 - val_accuracy: 0.7534 - 14s/epoch - 624ms/step
# Epoch 220/300
# 22/22 - 14s - loss: 0.2527 - accuracy: 0.9146 - val_loss: 1.1193 - val_accuracy: 0.7945 - 14s/epoch - 631ms/step
# Epoch 221/300
# 22/22 - 14s - loss: 0.2002 - accuracy: 0.9436 - val_loss: 1.3300 - val_accuracy: 0.7260 - 14s/epoch - 628ms/step
# Epoch 222/300
# 22/22 - 14s - loss: 0.2268 - accuracy: 0.9190 - val_loss: 1.1612 - val_accuracy: 0.7671 - 14s/epoch - 630ms/step
# Epoch 223/300
# 22/22 - 14s - loss: 0.3004 - accuracy: 0.9117 - val_loss: 1.3645 - val_accuracy: 0.7808 - 14s/epoch - 628ms/step
# Epoch 224/300
# 22/22 - 14s - loss: 0.2570 - accuracy: 0.9334 - val_loss: 1.3412 - val_accuracy: 0.7671 - 14s/epoch - 628ms/step
# Epoch 225/300
# 22/22 - 14s - loss: 0.2558 - accuracy: 0.9190 - val_loss: 1.1535 - val_accuracy: 0.7534 - 14s/epoch - 629ms/step
# Epoch 226/300
# 22/22 - 14s - loss: 0.1902 - accuracy: 0.9320 - val_loss: 1.0920 - val_accuracy: 0.7808 - 14s/epoch - 623ms/step
# Epoch 227/300
# 22/22 - 14s - loss: 0.2609 - accuracy: 0.9132 - val_loss: 1.2503 - val_accuracy: 0.7671 - 14s/epoch - 634ms/step
# Epoch 228/300
# 22/22 - 14s - loss: 0.2704 - accuracy: 0.9117 - val_loss: 1.5153 - val_accuracy: 0.7123 - 14s/epoch - 628ms/step
# Epoch 229/300
# 22/22 - 14s - loss: 0.2342 - accuracy: 0.9247 - val_loss: 1.4048 - val_accuracy: 0.7260 - 14s/epoch - 632ms/step
# Epoch 230/300
# 22/22 - 14s - loss: 0.2374 - accuracy: 0.9175 - val_loss: 1.2216 - val_accuracy: 0.7671 - 14s/epoch - 623ms/step
# Epoch 231/300
# 22/22 - 14s - loss: 0.1792 - accuracy: 0.9291 - val_loss: 1.3385 - val_accuracy: 0.7123 - 14s/epoch - 632ms/step
# Epoch 232/300
# 22/22 - 14s - loss: 0.2672 - accuracy: 0.9175 - val_loss: 1.2340 - val_accuracy: 0.7534 - 14s/epoch - 627ms/step
# Epoch 233/300
# 22/22 - 14s - loss: 0.2742 - accuracy: 0.9190 - val_loss: 1.2368 - val_accuracy: 0.7671 - 14s/epoch - 630ms/step
# Epoch 234/300
# 22/22 - 14s - loss: 0.3004 - accuracy: 0.9045 - val_loss: 1.3561 - val_accuracy: 0.7260 - 14s/epoch - 625ms/step
# Epoch 235/300
# 22/22 - 14s - loss: 0.2591 - accuracy: 0.9204 - val_loss: 1.3114 - val_accuracy: 0.7397 - 14s/epoch - 623ms/step
# Epoch 236/300
# 22/22 - 14s - loss: 0.1879 - accuracy: 0.9334 - val_loss: 1.1639 - val_accuracy: 0.7534 - 14s/epoch - 626ms/step
# Epoch 237/300
# 22/22 - 14s - loss: 0.1991 - accuracy: 0.9320 - val_loss: 1.3706 - val_accuracy: 0.7123 - 14s/epoch - 623ms/step
# Epoch 238/300
# 22/22 - 14s - loss: 0.2554 - accuracy: 0.9219 - val_loss: 1.4204 - val_accuracy: 0.7397 - 14s/epoch - 626ms/step
# Epoch 239/300
# 22/22 - 14s - loss: 0.3058 - accuracy: 0.9117 - val_loss: 1.2800 - val_accuracy: 0.7260 - 14s/epoch - 626ms/step
# Epoch 240/300
# 22/22 - 14s - loss: 0.2479 - accuracy: 0.9161 - val_loss: 1.2922 - val_accuracy: 0.7260 - 14s/epoch - 627ms/step
# Epoch 241/300
# 22/22 - 14s - loss: 0.2395 - accuracy: 0.9305 - val_loss: 1.3471 - val_accuracy: 0.7397 - 14s/epoch - 631ms/step
# Epoch 242/300
# 22/22 - 14s - loss: 0.2659 - accuracy: 0.9117 - val_loss: 1.2227 - val_accuracy: 0.7534 - 14s/epoch - 626ms/step
# Epoch 243/300
# 22/22 - 14s - loss: 0.2360 - accuracy: 0.9233 - val_loss: 1.2165 - val_accuracy: 0.7808 - 14s/epoch - 635ms/step
# Epoch 244/300
# 22/22 - 14s - loss: 0.2044 - accuracy: 0.9276 - val_loss: 1.3709 - val_accuracy: 0.7397 - 14s/epoch - 623ms/step
# Epoch 245/300
# 22/22 - 14s - loss: 0.1586 - accuracy: 0.9363 - val_loss: 1.0532 - val_accuracy: 0.7945 - 14s/epoch - 626ms/step
# Epoch 246/300
# 22/22 - 14s - loss: 0.2967 - accuracy: 0.9190 - val_loss: 1.1454 - val_accuracy: 0.7534 - 14s/epoch - 628ms/step
# Epoch 247/300
# 22/22 - 14s - loss: 0.3225 - accuracy: 0.9132 - val_loss: 1.1395 - val_accuracy: 0.7945 - 14s/epoch - 629ms/step
# Epoch 248/300
# 22/22 - 14s - loss: 0.1965 - accuracy: 0.9508 - val_loss: 1.0720 - val_accuracy: 0.7945 - 14s/epoch - 629ms/step
# Epoch 249/300
# 22/22 - 14s - loss: 0.2119 - accuracy: 0.9276 - val_loss: 1.1120 - val_accuracy: 0.7808 - 14s/epoch - 628ms/step
# Epoch 250/300
# 22/22 - 14s - loss: 0.1426 - accuracy: 0.9551 - val_loss: 1.0696 - val_accuracy: 0.7945 - 14s/epoch - 633ms/step
# Epoch 251/300
# 22/22 - 14s - loss: 0.2592 - accuracy: 0.9175 - val_loss: 1.0908 - val_accuracy: 0.7808 - 14s/epoch - 633ms/step
# Epoch 252/300
# 22/22 - 14s - loss: 0.2602 - accuracy: 0.9247 - val_loss: 1.2566 - val_accuracy: 0.7534 - 14s/epoch - 632ms/step
# Epoch 253/300
# 22/22 - 14s - loss: 0.2288 - accuracy: 0.9320 - val_loss: 1.0987 - val_accuracy: 0.8219 - 14s/epoch - 637ms/step
# Epoch 254/300
# 22/22 - 14s - loss: 0.1685 - accuracy: 0.9407 - val_loss: 1.2014 - val_accuracy: 0.7945 - 14s/epoch - 640ms/step
# Epoch 255/300
# 22/22 - 14s - loss: 0.2179 - accuracy: 0.9276 - val_loss: 1.1337 - val_accuracy: 0.8493 - 14s/epoch - 634ms/step
# Epoch 256/300
# 22/22 - 14s - loss: 0.2647 - accuracy: 0.9233 - val_loss: 1.1038 - val_accuracy: 0.8082 - 14s/epoch - 636ms/step
# Epoch 257/300
# 22/22 - 14s - loss: 0.1926 - accuracy: 0.9276 - val_loss: 1.1054 - val_accuracy: 0.7945 - 14s/epoch - 629ms/step
# Epoch 258/300
# 22/22 - 14s - loss: 0.2120 - accuracy: 0.9320 - val_loss: 1.2099 - val_accuracy: 0.8219 - 14s/epoch - 644ms/step
# Epoch 259/300
# 22/22 - 14s - loss: 0.1938 - accuracy: 0.9392 - val_loss: 1.1487 - val_accuracy: 0.8219 - 14s/epoch - 641ms/step
# Epoch 260/300
# 22/22 - 14s - loss: 0.1997 - accuracy: 0.9305 - val_loss: 1.1422 - val_accuracy: 0.8356 - 14s/epoch - 640ms/step
# Epoch 261/300
# 22/22 - 14s - loss: 0.2451 - accuracy: 0.9233 - val_loss: 1.3171 - val_accuracy: 0.7671 - 14s/epoch - 633ms/step
# Epoch 262/300
# 22/22 - 14s - loss: 0.2010 - accuracy: 0.9320 - val_loss: 1.2471 - val_accuracy: 0.7534 - 14s/epoch - 647ms/step
# Epoch 263/300
# 22/22 - 14s - loss: 0.1864 - accuracy: 0.9421 - val_loss: 1.1532 - val_accuracy: 0.7808 - 14s/epoch - 640ms/step
# Epoch 264/300
# 22/22 - 14s - loss: 0.1577 - accuracy: 0.9436 - val_loss: 1.2153 - val_accuracy: 0.7671 - 14s/epoch - 636ms/step
# Epoch 265/300
# 22/22 - 15s - loss: 0.1818 - accuracy: 0.9493 - val_loss: 1.1410 - val_accuracy: 0.8082 - 15s/epoch - 663ms/step
# Epoch 266/300
# 22/22 - 14s - loss: 0.2736 - accuracy: 0.9262 - val_loss: 1.0790 - val_accuracy: 0.8082 - 14s/epoch - 656ms/step
# Epoch 267/300
# 22/22 - 15s - loss: 0.1939 - accuracy: 0.9291 - val_loss: 1.1725 - val_accuracy: 0.7945 - 15s/epoch - 677ms/step
# Epoch 268/300
# 22/22 - 14s - loss: 0.2130 - accuracy: 0.9334 - val_loss: 1.0767 - val_accuracy: 0.7945 - 14s/epoch - 657ms/step
# Epoch 269/300
# 22/22 - 14s - loss: 0.2354 - accuracy: 0.9204 - val_loss: 1.2258 - val_accuracy: 0.7534 - 14s/epoch - 653ms/step
# Epoch 270/300
# 22/22 - 14s - loss: 0.1571 - accuracy: 0.9421 - val_loss: 1.1243 - val_accuracy: 0.8082 - 14s/epoch - 644ms/step
# Epoch 271/300
# 22/22 - 14s - loss: 0.2567 - accuracy: 0.9190 - val_loss: 1.1362 - val_accuracy: 0.7808 - 14s/epoch - 656ms/step
# Epoch 272/300
# 22/22 - 14s - loss: 0.2595 - accuracy: 0.9117 - val_loss: 1.0742 - val_accuracy: 0.8082 - 14s/epoch - 653ms/step
# Epoch 273/300
# 22/22 - 14s - loss: 0.1880 - accuracy: 0.9349 - val_loss: 1.0595 - val_accuracy: 0.8219 - 14s/epoch - 654ms/step
# Epoch 274/300
# 22/22 - 14s - loss: 0.2769 - accuracy: 0.9132 - val_loss: 1.1751 - val_accuracy: 0.7808 - 14s/epoch - 652ms/step
# Epoch 275/300
# 22/22 - 14s - loss: 0.3041 - accuracy: 0.9233 - val_loss: 1.1425 - val_accuracy: 0.7945 - 14s/epoch - 654ms/step
# Epoch 276/300
# 22/22 - 14s - loss: 0.2584 - accuracy: 0.9204 - val_loss: 1.1640 - val_accuracy: 0.7808 - 14s/epoch - 651ms/step
# Epoch 277/300
# 22/22 - 14s - loss: 0.2305 - accuracy: 0.9262 - val_loss: 1.1060 - val_accuracy: 0.8219 - 14s/epoch - 657ms/step
# Epoch 278/300
# 22/22 - 14s - loss: 0.2108 - accuracy: 0.9378 - val_loss: 1.1431 - val_accuracy: 0.8219 - 14s/epoch - 656ms/step
# Epoch 279/300
# 22/22 - 14s - loss: 0.2143 - accuracy: 0.9146 - val_loss: 1.1278 - val_accuracy: 0.7945 - 14s/epoch - 652ms/step
# Epoch 280/300
# 22/22 - 14s - loss: 0.1970 - accuracy: 0.9262 - val_loss: 1.1176 - val_accuracy: 0.7397 - 14s/epoch - 650ms/step
# Epoch 281/300
# 22/22 - 14s - loss: 0.1748 - accuracy: 0.9334 - val_loss: 1.0235 - val_accuracy: 0.8219 - 14s/epoch - 645ms/step
# Epoch 282/300
# 22/22 - 15s - loss: 0.2121 - accuracy: 0.9334 - val_loss: 1.1208 - val_accuracy: 0.7945 - 15s/epoch - 667ms/step
# Epoch 283/300
# 22/22 - 14s - loss: 0.2188 - accuracy: 0.9320 - val_loss: 1.2512 - val_accuracy: 0.7534 - 14s/epoch - 655ms/step
# Epoch 284/300
# 22/22 - 14s - loss: 0.2173 - accuracy: 0.9349 - val_loss: 1.1786 - val_accuracy: 0.7945 - 14s/epoch - 652ms/step
# Epoch 285/300
# 22/22 - 15s - loss: 0.2415 - accuracy: 0.9334 - val_loss: 1.1433 - val_accuracy: 0.8082 - 15s/epoch - 665ms/step
# Epoch 286/300
# 22/22 - 14s - loss: 0.2241 - accuracy: 0.9233 - val_loss: 1.1588 - val_accuracy: 0.8082 - 14s/epoch - 655ms/step
# Epoch 287/300
# 22/22 - 15s - loss: 0.1910 - accuracy: 0.9421 - val_loss: 1.0433 - val_accuracy: 0.8082 - 15s/epoch - 681ms/step
# Epoch 288/300
# 22/22 - 15s - loss: 0.1683 - accuracy: 0.9407 - val_loss: 1.2352 - val_accuracy: 0.7808 - 15s/epoch - 694ms/step
# Epoch 289/300
# 22/22 - 15s - loss: 0.2525 - accuracy: 0.9175 - val_loss: 1.1643 - val_accuracy: 0.7945 - 15s/epoch - 673ms/step
# Epoch 290/300
# 22/22 - 15s - loss: 0.2676 - accuracy: 0.9161 - val_loss: 1.1520 - val_accuracy: 0.7534 - 15s/epoch - 666ms/step
# Epoch 291/300
# 22/22 - 15s - loss: 0.2086 - accuracy: 0.9363 - val_loss: 0.9512 - val_accuracy: 0.7808 - 15s/epoch - 693ms/step
# Epoch 292/300
# 22/22 - 14s - loss: 0.1583 - accuracy: 0.9407 - val_loss: 1.1878 - val_accuracy: 0.7671 - 14s/epoch - 652ms/step
# Epoch 293/300
# 22/22 - 14s - loss: 0.2413 - accuracy: 0.9305 - val_loss: 1.3846 - val_accuracy: 0.7397 - 14s/epoch - 644ms/step
# Epoch 294/300
# 22/22 - 14s - loss: 0.2279 - accuracy: 0.9334 - val_loss: 1.0847 - val_accuracy: 0.7945 - 14s/epoch - 628ms/step
# Epoch 295/300
# 22/22 - 14s - loss: 0.1790 - accuracy: 0.9334 - val_loss: 1.0455 - val_accuracy: 0.7671 - 14s/epoch - 623ms/step
# Epoch 296/300
# 22/22 - 14s - loss: 0.2291 - accuracy: 0.9190 - val_loss: 1.2599 - val_accuracy: 0.7534 - 14s/epoch - 626ms/step
# Epoch 297/300
# 22/22 - 14s - loss: 0.2504 - accuracy: 0.9233 - val_loss: 1.2007 - val_accuracy: 0.7397 - 14s/epoch - 627ms/step
# Epoch 298/300
# 22/22 - 14s - loss: 0.2436 - accuracy: 0.9219 - val_loss: 1.2537 - val_accuracy: 0.7671 - 14s/epoch - 622ms/step
# Epoch 299/300
# 22/22 - 14s - loss: 0.2218 - accuracy: 0.9320 - val_loss: 1.3544 - val_accuracy: 0.7945 - 14s/epoch - 624ms/step
# Epoch 300/300
# 22/22 - 14s - loss: 0.1817 - accuracy: 0.9320 - val_loss: 1.2413 - val_accuracy: 0.7671 - 14s/epoch - 625ms/step

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# OPTIONAL: Decide if best weights should be loaded from previous model based on val_acc
# The model weights (that are considered the best) are loaded into the model.
result = model.load_weights(checkpoint_filepath)

# %% [markdown]
# <h3>Evaluate Test data</h3>

# %%
print(sum(cb.logs) / 150)

testLoss, testAcc = model.evaluate(test)
print('''
Test Loss: {}
Test Accuracy: {}
'''.format(testLoss, testAcc))
# Out:
# 27.99330856733334
# 3/3 [==============================] - 2s 449ms/step - loss: 0.9219 - accuracy: 0.7978
#
# Test Loss: 0.9218781590461731
# Test Accuracy: 0.7977527976036072

# %% [markdown]
# <h4>*Optional - Fine tune model with two-step training*</h4>

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

mobile.trainable = True

for layer in mobile.layers[:-2]:
    layer.trainable = False
    
#re-train the model at a very low learning rate
model.compile(optimizer=Adam(learning_rate=0.00006), loss='categorical_crossentropy', metrics=['accuracy'])

result = model.fit(x=train, validation_data=validation, epochs=100, verbose=2, callbacks=[cb, es])
# Out:
# Epoch 1/100
# 22/22 - 16s - loss: 0.1986 - accuracy: 0.9305 - val_loss: 0.9087 - val_accuracy: 0.8493 - 16s/epoch - 750ms/step
# Epoch 2/100
# 22/22 - 14s - loss: 0.1992 - accuracy: 0.9291 - val_loss: 0.9104 - val_accuracy: 0.8493 - 14s/epoch - 622ms/step
# Epoch 3/100
# 22/22 - 14s - loss: 0.1639 - accuracy: 0.9479 - val_loss: 0.9122 - val_accuracy: 0.8493 - 14s/epoch - 627ms/step
# Epoch 4/100
# 22/22 - 14s - loss: 0.2060 - accuracy: 0.9276 - val_loss: 0.9133 - val_accuracy: 0.8630 - 14s/epoch - 624ms/step
# Epoch 5/100
# 22/22 - 14s - loss: 0.2297 - accuracy: 0.9247 - val_loss: 0.9196 - val_accuracy: 0.8630 - 14s/epoch - 622ms/step
# Epoch 6/100
# 22/22 - 14s - loss: 0.1817 - accuracy: 0.9378 - val_loss: 0.9180 - val_accuracy: 0.8630 - 14s/epoch - 626ms/step
# Epoch 7/100
# 22/22 - 14s - loss: 0.1739 - accuracy: 0.9349 - val_loss: 0.9237 - val_accuracy: 0.8356 - 14s/epoch - 618ms/step
# Epoch 8/100
# 22/22 - 14s - loss: 0.1933 - accuracy: 0.9378 - val_loss: 0.9268 - val_accuracy: 0.8356 - 14s/epoch - 630ms/step
# Epoch 9/100
# 22/22 - 14s - loss: 0.2033 - accuracy: 0.9363 - val_loss: 0.9293 - val_accuracy: 0.8356 - 14s/epoch - 630ms/step
# Epoch 10/100
# 22/22 - 14s - loss: 0.1878 - accuracy: 0.9349 - val_loss: 0.9324 - val_accuracy: 0.8356 - 14s/epoch - 617ms/step
# Epoch 11/100
# 22/22 - 14s - loss: 0.1888 - accuracy: 0.9392 - val_loss: 0.9319 - val_accuracy: 0.8356 - 14s/epoch - 624ms/step
# Epoch 11: early stopping

# %% [markdown]
# <h3>Accuracy and Loss graph</h3>

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# <h3>Classification report</h3>

# %%
predictions = model.predict(test, verbose=0)
# predictions = predictions.reshape(1,-1)[0]
lst = np.argmax(predictions, axis= 1)

print(classification_report(test.classes, lst, target_names = test.class_indices))
# Out:
#               precision    recall  f1-score   support
#
#     Duracell       1.00      0.79      0.88        14
#    Energizer       0.72      0.93      0.81        14
#     Eveready       0.62      0.80      0.70        10
#        Exell       0.78      0.78      0.78         9
#           GP       0.77      0.83      0.80        12
#         Ikea       1.00      0.89      0.94         9
#       Klarus       1.00      0.73      0.84        11
#    Panasonic       0.67      0.60      0.63        10
#
#     accuracy                           0.80        89
#    macro avg       0.82      0.79      0.80        89
# weighted avg       0.82      0.80      0.80        89

# %% [markdown]
# <h3>Confusion matrix</h3>

# %%
result = confusion_matrix(test.classes, lst)
print(result)

def plot_confusion_matrix(result, classes, cmap=plt.cm.Blues):
    plt.subplots(figsize=(7, 7))
    plt.imshow(result, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

    thresh = result.max() / 2.
    for i, j in itertools.product(range(result.shape[0]), range(result.shape[1])):
        plt.text(j, i, result[i, j],
            horizontalalignment="center",
            color = "white" if result[i, j] > thresh else "black")
        
    #current matplotlib version will cut off top and bottom of the matrix, 
    #hence the manual workaround - remove if matplotlib version does not cut off
    b, t = plt.ylim() # discover bottom and top values
    b += 0.5 # Add 0.5 to bottom
    t -= 0.5 # Subtract 0.5 from top
    plt.ylim(b, t) # update ylim(bottom, top) values
    plt.show()
    
plot_confusion_matrix(result, list(test.class_indices.keys()))
# Out:
# [[11  1  0  0  2  0  0  0]
#  [ 0 13  0  0  0  0  0  1]
#  [ 0  1  8  0  0  0  0  1]
#  [ 0  0  1  7  1  0  0  0]
#  [ 0  1  0  0 10  0  0  1]
#  [ 0  0  0  1  0  8  0  0]
#  [ 0  0  3  0  0  0  8  0]
#  [ 0  2  1  1  0  0  0  6]]

# %% [markdown]
# <h3>Labels of wrong predictions</h3>

# %%
def getErrors(test, predictions):
    #get file names of all images in test data
    names = test.filenames

    #get IDs of all classes
    allClassesID = test.classes

    #get dictionary of classes and respective ID
    classLabelDict = test.class_indices
    
    #list of the names of all classes
    classLabels = list(classLabelDict.keys())

    print("The list of classes: ", classLabels)

    #get the most predicted class
    predictedClasses = np.argmax(predictions, axis=1)

    predictedErrors = np.where(predictedClasses != allClassesID)[0]

    print("Number of errors = {}/{}".format(len(predictedErrors),test.samples))

    return classLabels, predictedErrors, names

def showErrors(classLabels, predictedErrors, predictions, names):
    # Show the errors
    for i in range(len(errors)):
        predictedClass = np.argmax(predictions[predictedErrors[i]])

        predictedLabel = classLabels[predictedClass]

        title = 'Original Picture : {}, Prediction : {}, Confidence/Percentage : {:.3f}'.format\
                (names[predictedErrors[i]].split('/')[0],predictedLabel, predictions[errors[i]][predictedClass])
        print(title)

# %%
#get the list of class labels, prediction errors and file names
labels, errors, names = getErrors(test, predictions)

#show wrongly predicted images, prediction and and the percentage (confidence)
showErrors(labels, errors, predictions, names)
# Out:
# The list of classes:  ['Duracell', 'Energizer', 'Eveready', 'Exell', 'GP', 'Ikea', 'Klarus', 'Panasonic']
# Number of errors = 18/89
# Original Picture : Duracell\Image_16.jpg, Prediction : GP, Confidence/Percentage : 0.951
# Original Picture : Duracell\Image_46.jpg, Prediction : Energizer, Confidence/Percentage : 0.698
# Original Picture : Duracell\norwich-norfolk-uk-november-15-2021-duracell-batteries-cut-out-isolated-on-a-plain-white-background-2H71GYA.jpg, Prediction : GP, Confidence/Percentage : 1.000
# Original Picture : Energizer\12 (2).jpeg, Prediction : Panasonic, Confidence/Percentage : 0.751
# Original Picture : Eveready\Image_49.jpg, Prediction : Energizer, Confidence/Percentage : 1.000
# Original Picture : Eveready\energizer-eveready-super-heavy-duty-1215-aa-1100mah-1-5v-zinc-carbon-button-top-batteries-bulk-56.jpg, Prediction : Panasonic, Confidence/Percentage : 0.623
# Original Picture : Exell\46.jpg, Prediction : Eveready, Confidence/Percentage : 0.709
# Original Picture : Exell\58.jpg, Prediction : GP, Confidence/Percentage : 0.888
# Original Picture : GP\Image_62.jpg, Prediction : Energizer, Confidence/Percentage : 0.909
# Original Picture : GP\gp-23ae-new.jpg, Prediction : Panasonic, Confidence/Percentage : 0.993
# Original Picture : Ikea\Image_29.JPG, Prediction : Exell, Confidence/Percentage : 0.788
# Original Picture : Klarus\11.jpg, Prediction : Eveready, Confidence/Percentage : 0.841
# Original Picture : Klarus\Image_21.jpg, Prediction : Eveready, Confidence/Percentage : 0.620
# Original Picture : Klarus\Image_53.jpg, Prediction : Eveready, Confidence/Percentage : 0.960
# Original Picture : Panasonic\11.jpg, Prediction : Energizer, Confidence/Percentage : 0.776
# Original Picture : Panasonic\16.jpg, Prediction : Exell, Confidence/Percentage : 0.762
# Original Picture : Panasonic\29.jpeg, Prediction : Eveready, Confidence/Percentage : 0.783
# Original Picture : Panasonic\37.jpg, Prediction : Energizer, Confidence/Percentage : 0.902

# %% [markdown]
# <h3>Save the model</h3>

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model so that it can be passed to edge device
model.save("image_classification.h5")
