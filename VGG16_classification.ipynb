# %% [markdown]
# <h3>Import packages</h3>

# %%
from datetime import date
from timeit import default_timer as timer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import imagenet_utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Configure TensorFlow to use GPU for training
tf.config.list_physical_devices('GPU') 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
#Set GPU memory limit so my GPU doesn't crash
if gpus:
    try:
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <h3>Create class to record time taken to train the model</h3>

# %%
#class to record time taken to train per epoch
class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# <h3>Create train and test folder</h3>

# %%
#creates a folder each time the set of code is run to sort dataset into train and test
day = date.today()
formatDate = day.strftime("%b-%d-%Y")

#create folder with current date to group predictions ran in a day together, if it does not exists
if os.path.isdir('Prediction (' + formatDate + ')') is False:
    folder = os.mkdir('Prediction (' + formatDate + ')')
folder = 'Prediction (' + formatDate + ')'

#looping through to find if destination folder exists
i = 1
while True:
    if os.path.isdir(folder + '/Battery Images - ' + str(i)) is False:
        break
    i += 1

#destination path for unsorted folder
destination = folder + '/Battery Images - ' + str(i)

#source path for unsorted folder
# source = 'Battery Images/'
# source = 'Battery Images [Old]/'
# source = 'Battery Images [StreamLined]/'
source = 'Battery Images [Download]/'

#duplicate the unsorted folder from source to destination
shutil.copytree(source, destination)

os.mkdir(destination + '/train')
os.mkdir(destination + '/test')

# %% [markdown]
# <h3>Sort dataset into train and test folder</h3>

# %%
#function to split images into training (80%) and testing (20%) and return both
def split(data):
    # num = int(len(data) * 0.8)
    num = int(len(data) * 0.9) #90/10 split
#     num = int(len(data) * 0.7) #70/30 split
    random.shuffle(data)
    return data[:num], data[num:]

dir = os.chdir(destination)
for category in os.listdir(dir):
    #skip the iteration if folder is "train" or "test"
    skip = ['train', 'test']
    if category in skip:
        continue
    
    shutil.move(f'{category}', 'train')
    #create a subfolder with the same name in test
    os.mkdir(f'test/{category}')

    #get the images in each folder (battery type) for spltting of data into training and testing
    img = os.listdir(f'train/{category}')
    training, testing = split(img)
    
    for file in testing:
        shutil.move(f'train/{category}/{file}', f'test/{category}')

# %% [markdown]
# <h3>b) Transfer Learning - MobileNet</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.mobilenet.MobileNet(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %% [markdown]
# <h3>c) Transfer Learning - MobileNetV2</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.MobileNetV2(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %% [markdown]
# <h3>c) Transfer Learning - VGG16</h3>

# %%
#"include_top=False argument" will load a network that excluding the classification layers at the top
mobile = tf.keras.applications.vgg16.VGG16(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")

# %%
mobile.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in mobile.layers[:-2]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = mobile(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
# x = tf.keras.layers.Dropout(0.65)(x) #Higher dropout to reduce overfitting (last best setting)
# output = tf.keras.layers.Dense(5, activation="softmax")(x)   
# output = tf.keras.layers.Dense(10, activation="softmax")(x)   #Changed to reflect new categories
output = tf.keras.layers.Dense(8, activation="softmax")(x)   #Changed to reflect new categories

model = keras.Model(inputs, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 8)                 4104
#
# =================================================================
# Total params: 14,718,792
# Trainable params: 2,363,912
# Non-trainable params: 12,354,880
# _________________________________________________________________

# %% [markdown]
# <h3>Process data</h3>

# %%
train_path = 'train'
test_path = 'test'

#for data augmentation on training data
datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet.preprocess_input,
    # validation_split=0.2,
    validation_split=0.1, #changes made for 90/10 split
    rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.2, # Randomly zoom image 
    width_shift_range = 0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range = 0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip = True,  # randomly flip images
#     vertical_flip = False,    # randomly flip images
    vertical_flip = True, #include vertical flip for better generalisation
    )  

#takes images from directory path and generates batches of augmented data
train = datagen.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='training',
        shuffle = False)

#for validation data
# validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
#                                         validation_split=0.2)
validation_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input, 
                                        validation_split=0.1) #changes made for 90/10 split


validation = validation_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    batch_size=32,
    subset='validation',
        shuffle = False)

#for test data
test = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input)\
.flow_from_directory(directory=test_path, target_size=(224,224), batch_size=32, shuffle=False)
# Out:
# Found 691 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 89 images belonging to 8 classes.

# %% [markdown]
# <h3>Train model</h3>

# %%
model.compile(optimizer=Adam(learning_rate=0.006), loss='categorical_crossentropy', metrics=['accuracy']) #Last best setting
# model.compile(optimizer=Adam(learning_rate=0.0045), loss='categorical_crossentropy', metrics=['accuracy']) #Lower LR
# model.compile(optimizer=Adam(learning_rate=0.0075), loss='categorical_crossentropy', metrics=['accuracy']) 
checkpoint_filepath = './tmp/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True) #save best model

#more epochs for better results
result = model.fit(x=train, validation_data=validation, epochs=300, verbose=2, callbacks=[model_checkpoint_callback,cb])
# result = model.fit(x=train, validation_data=validation, epochs=200, verbose=2, callbacks=[cb])
# Out:
# Epoch 1/300
# c:\Users\ngden\anaconda3\lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 22/22 - 63s - loss: 13.4019 - accuracy: 0.1012 - val_loss: 2.0790 - val_accuracy: 0.1781 - 63s/epoch - 3s/step
# Epoch 2/300
# 22/22 - 18s - loss: 2.0929 - accuracy: 0.1474 - val_loss: 2.0785 - val_accuracy: 0.1370 - 18s/epoch - 798ms/step
# Epoch 3/300
# Epoch 22/300
# 22/22 - 14s - loss: 1.9446 - accuracy: 0.2197 - val_loss: 1.7274 - val_accuracy: 0.3562 - 14s/epoch - 631ms/step
# Epoch 23/300
# 22/22 - 15s - loss: 1.8978 - accuracy: 0.2312 - val_loss: 1.8265 - val_accuracy: 0.3562 - 15s/epoch - 662ms/step
# Epoch 24/300
# 22/22 - 15s - loss: 1.9078 - accuracy: 0.2399 - val_loss: 1.6440 - val_accuracy: 0.3973 - 15s/epoch - 673ms/step
# Epoch 25/300
# 22/22 - 14s - loss: 1.8686 - accuracy: 0.2514 - val_loss: 1.7200 - val_accuracy: 0.3425 - 14s/epoch - 659ms/step
# Epoch 26/300
# 22/22 - 14s - loss: 1.8841 - accuracy: 0.2601 - val_loss: 1.7595 - val_accuracy: 0.3699 - 14s/epoch - 639ms/step
# Epoch 27/300
# 22/22 - 14s - loss: 1.8263 - accuracy: 0.2876 - val_loss: 1.6417 - val_accuracy: 0.4658 - 14s/epoch - 649ms/step
# Epoch 28/300
# 22/22 - 14s - loss: 1.8309 - accuracy: 0.2832 - val_loss: 1.5480 - val_accuracy: 0.4521 - 14s/epoch - 642ms/step
# Epoch 29/300
# 22/22 - 14s - loss: 1.7690 - accuracy: 0.2746 - val_loss: 1.5272 - val_accuracy: 0.4110 - 14s/epoch - 641ms/step
# Epoch 30/300
# 22/22 - 14s - loss: 1.7640 - accuracy: 0.2818 - val_loss: 1.5828 - val_accuracy: 0.4521 - 14s/epoch - 646ms/step
# Epoch 31/300
# 22/22 - 14s - loss: 1.8040 - accuracy: 0.2832 - val_loss: 1.4933 - val_accuracy: 0.4795 - 14s/epoch - 647ms/step
# Epoch 32/300
# 22/22 - 15s - loss: 1.7326 - accuracy: 0.2919 - val_loss: 1.5089 - val_accuracy: 0.4110 - 15s/epoch - 663ms/step
# Epoch 33/300
# 22/22 - 14s - loss: 1.8025 - accuracy: 0.2775 - val_loss: 1.4888 - val_accuracy: 0.4658 - 14s/epoch - 644ms/step
# Epoch 34/300
# 22/22 - 14s - loss: 1.7531 - accuracy: 0.2832 - val_loss: 1.5321 - val_accuracy: 0.5068 - 14s/epoch - 648ms/step
# Epoch 35/300
# 22/22 - 14s - loss: 1.7669 - accuracy: 0.2991 - val_loss: 1.5275 - val_accuracy: 0.4521 - 14s/epoch - 639ms/step
# Epoch 36/300
# 22/22 - 14s - loss: 1.7270 - accuracy: 0.2977 - val_loss: 1.4560 - val_accuracy: 0.4521 - 14s/epoch - 638ms/step
# Epoch 37/300
# 22/22 - 15s - loss: 1.7541 - accuracy: 0.2832 - val_loss: 1.4605 - val_accuracy: 0.4932 - 15s/epoch - 676ms/step
# Epoch 38/300
# 22/22 - 15s - loss: 1.7074 - accuracy: 0.3020 - val_loss: 1.4289 - val_accuracy: 0.5205 - 15s/epoch - 670ms/step
# Epoch 39/300
# 22/22 - 15s - loss: 1.7282 - accuracy: 0.2890 - val_loss: 1.4793 - val_accuracy: 0.4521 - 15s/epoch - 663ms/step
# Epoch 40/300
# Epoch 296/300
# 22/22 - 15s - loss: 1.3571 - accuracy: 0.4523 - val_loss: 1.0291 - val_accuracy: 0.7123 - 15s/epoch - 684ms/step
# Epoch 297/300
# 22/22 - 15s - loss: 1.3564 - accuracy: 0.4682 - val_loss: 1.0064 - val_accuracy: 0.6849 - 15s/epoch - 681ms/step
# Epoch 298/300
# 22/22 - 15s - loss: 1.3401 - accuracy: 0.4682 - val_loss: 1.0026 - val_accuracy: 0.6849 - 15s/epoch - 702ms/step
# Epoch 299/300
# 22/22 - 15s - loss: 1.2864 - accuracy: 0.4913 - val_loss: 1.0436 - val_accuracy: 0.6986 - 15s/epoch - 680ms/step
# Epoch 300/300
# 22/22 - 15s - loss: 1.2991 - accuracy: 0.4754 - val_loss: 1.0141 - val_accuracy: 0.7260 - 15s/epoch - 677ms/step

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# OPTIONAL: Decide if best weights should be loaded from previous model based on val_acc
# The model weights (that are considered the best) are loaded into the model.
result = model.load_weights(checkpoint_filepath)

# %% [markdown]
# <h3>Evaluate Test data</h3>

# %%
print(sum(cb.logs) / 150)

testLoss, testAcc = model.evaluate(test)
print('''
Test Loss: {}
Test Accuracy: {}
'''.format(testLoss, testAcc))
# Out:
# 29.566165101332786
# 3/3 [==============================] - 9s 4s/step - loss: 1.4909 - accuracy: 0.7303
#
# Test Loss: 1.4908607006072998
# Test Accuracy: 0.7303370833396912

# %% [markdown]
# <h4>*Optional - Fine tune model with two-step training*</h4>

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

mobile.trainable = True

for layer in mobile.layers[:-2]:
    layer.trainable = False
    
#re-train the model at a very low learning rate
model.compile(optimizer=Adam(learning_rate=0.00006), loss='categorical_crossentropy', metrics=['accuracy'])

result = model.fit(x=train, validation_data=validation, epochs=100, verbose=2, callbacks=[cb, es])
# Out:
# Epoch 1/100
# 22/22 - 16s - loss: 1.3246 - accuracy: 0.4798 - val_loss: 1.0002 - val_accuracy: 0.8356 - 16s/epoch - 719ms/step
# Epoch 2/100
# 22/22 - 15s - loss: 1.4065 - accuracy: 0.4306 - val_loss: 0.9964 - val_accuracy: 0.8219 - 15s/epoch - 679ms/step
# Epoch 3/100
# 22/22 - 15s - loss: 1.4062 - accuracy: 0.4321 - val_loss: 0.9936 - val_accuracy: 0.8219 - 15s/epoch - 697ms/step
# Epoch 4/100
# 22/22 - 16s - loss: 1.3666 - accuracy: 0.4494 - val_loss: 0.9911 - val_accuracy: 0.8219 - 16s/epoch - 737ms/step
# Epoch 5/100
# 22/22 - 16s - loss: 1.3499 - accuracy: 0.4566 - val_loss: 0.9886 - val_accuracy: 0.8356 - 16s/epoch - 718ms/step
# Epoch 6/100
# 22/22 - 15s - loss: 1.4143 - accuracy: 0.4205 - val_loss: 0.9874 - val_accuracy: 0.8356 - 15s/epoch - 698ms/step
# Epoch 7/100
# 22/22 - 15s - loss: 1.2856 - accuracy: 0.4913 - val_loss: 0.9854 - val_accuracy: 0.8356 - 15s/epoch - 694ms/step
# Epoch 8/100
# 22/22 - 15s - loss: 1.3526 - accuracy: 0.4234 - val_loss: 0.9836 - val_accuracy: 0.8219 - 15s/epoch - 692ms/step
# Epoch 9/100
# 22/22 - 15s - loss: 1.3488 - accuracy: 0.4566 - val_loss: 0.9822 - val_accuracy: 0.8082 - 15s/epoch - 687ms/step
# Epoch 10/100
# 22/22 - 15s - loss: 1.3763 - accuracy: 0.4379 - val_loss: 0.9807 - val_accuracy: 0.7945 - 15s/epoch - 682ms/step
# Epoch 11/100
# 22/22 - 15s - loss: 1.3144 - accuracy: 0.4928 - val_loss: 0.9796 - val_accuracy: 0.8082 - 15s/epoch - 684ms/step
# Epoch 12/100
# 22/22 - 15s - loss: 1.3492 - accuracy: 0.4639 - val_loss: 0.9785 - val_accuracy: 0.7808 - 15s/epoch - 692ms/step
# Epoch 13/100
# 22/22 - 15s - loss: 1.3102 - accuracy: 0.4697 - val_loss: 0.9778 - val_accuracy: 0.7808 - 15s/epoch - 690ms/step
# Epoch 14/100
# 22/22 - 15s - loss: 1.3435 - accuracy: 0.4436 - val_loss: 0.9761 - val_accuracy: 0.8082 - 15s/epoch - 686ms/step
# Epoch 15/100
# 22/22 - 15s - loss: 1.3269 - accuracy: 0.4725 - val_loss: 0.9750 - val_accuracy: 0.8082 - 15s/epoch - 687ms/step
# Epoch 16/100
# 22/22 - 15s - loss: 1.2917 - accuracy: 0.4928 - val_loss: 0.9749 - val_accuracy: 0.8082 - 15s/epoch - 688ms/step
# Epoch 17/100
# 22/22 - 15s - loss: 1.3058 - accuracy: 0.4682 - val_loss: 0.9744 - val_accuracy: 0.8082 - 15s/epoch - 702ms/step
# Epoch 18/100
# 22/22 - 16s - loss: 1.2915 - accuracy: 0.4754 - val_loss: 0.9732 - val_accuracy: 0.8082 - 16s/epoch - 744ms/step
# Epoch 19/100
# 22/22 - 17s - loss: 1.3539 - accuracy: 0.4624 - val_loss: 0.9724 - val_accuracy: 0.8082 - 17s/epoch - 756ms/step
# Epoch 20/100
# 22/22 - 16s - loss: 1.3618 - accuracy: 0.4465 - val_loss: 0.9726 - val_accuracy: 0.8082 - 16s/epoch - 732ms/step
# Epoch 21/100
# 22/22 - 16s - loss: 1.3185 - accuracy: 0.4754 - val_loss: 0.9723 - val_accuracy: 0.8082 - 16s/epoch - 714ms/step
# Epoch 22/100
# 22/22 - 16s - loss: 1.3364 - accuracy: 0.4595 - val_loss: 0.9722 - val_accuracy: 0.8082 - 16s/epoch - 729ms/step
# Epoch 23/100
# 22/22 - 15s - loss: 1.3622 - accuracy: 0.4523 - val_loss: 0.9718 - val_accuracy: 0.8082 - 15s/epoch - 702ms/step
# Epoch 24/100
# 22/22 - 15s - loss: 1.3294 - accuracy: 0.4668 - val_loss: 0.9712 - val_accuracy: 0.8082 - 15s/epoch - 698ms/step
# Epoch 25/100
# 22/22 - 15s - loss: 1.3291 - accuracy: 0.4740 - val_loss: 0.9720 - val_accuracy: 0.8082 - 15s/epoch - 704ms/step
# Epoch 26/100
# 22/22 - 15s - loss: 1.3319 - accuracy: 0.4624 - val_loss: 0.9717 - val_accuracy: 0.8082 - 15s/epoch - 698ms/step
# Epoch 27/100
# 22/22 - 15s - loss: 1.3617 - accuracy: 0.4408 - val_loss: 0.9707 - val_accuracy: 0.8082 - 15s/epoch - 699ms/step
# Epoch 28/100
# 22/22 - 15s - loss: 1.3605 - accuracy: 0.4610 - val_loss: 0.9702 - val_accuracy: 0.8082 - 15s/epoch - 702ms/step
# Epoch 29/100
# 22/22 - 15s - loss: 1.2987 - accuracy: 0.4812 - val_loss: 0.9697 - val_accuracy: 0.8082 - 15s/epoch - 703ms/step
# Epoch 30/100
# 22/22 - 15s - loss: 1.3257 - accuracy: 0.4639 - val_loss: 0.9688 - val_accuracy: 0.8082 - 15s/epoch - 691ms/step
# Epoch 31/100
# 22/22 - 15s - loss: 1.3906 - accuracy: 0.4451 - val_loss: 0.9685 - val_accuracy: 0.8082 - 15s/epoch - 693ms/step
# Epoch 32/100
# 22/22 - 15s - loss: 1.3550 - accuracy: 0.4581 - val_loss: 0.9680 - val_accuracy: 0.8082 - 15s/epoch - 693ms/step
# Epoch 33/100
# 22/22 - 15s - loss: 1.3451 - accuracy: 0.4624 - val_loss: 0.9689 - val_accuracy: 0.8082 - 15s/epoch - 681ms/step
# Epoch 34/100
# 22/22 - 16s - loss: 1.3390 - accuracy: 0.4509 - val_loss: 0.9697 - val_accuracy: 0.8082 - 16s/epoch - 710ms/step
# Epoch 35/100
# 22/22 - 16s - loss: 1.3192 - accuracy: 0.4711 - val_loss: 0.9691 - val_accuracy: 0.8082 - 16s/epoch - 730ms/step
# Epoch 36/100
# 22/22 - 16s - loss: 1.3785 - accuracy: 0.4292 - val_loss: 0.9696 - val_accuracy: 0.8082 - 16s/epoch - 724ms/step
# Epoch 37/100
# 22/22 - 16s - loss: 1.3269 - accuracy: 0.4769 - val_loss: 0.9704 - val_accuracy: 0.8082 - 16s/epoch - 719ms/step
# Epoch 38/100
# 22/22 - 16s - loss: 1.3263 - accuracy: 0.4639 - val_loss: 0.9705 - val_accuracy: 0.8082 - 16s/epoch - 714ms/step
# Epoch 39/100
# 22/22 - 16s - loss: 1.3385 - accuracy: 0.4610 - val_loss: 0.9705 - val_accuracy: 0.8082 - 16s/epoch - 721ms/step
# Epoch 40/100
# 22/22 - 16s - loss: 1.3418 - accuracy: 0.4465 - val_loss: 0.9699 - val_accuracy: 0.8082 - 16s/epoch - 713ms/step
# Epoch 41/100
# 22/22 - 16s - loss: 1.3028 - accuracy: 0.4783 - val_loss: 0.9691 - val_accuracy: 0.7945 - 16s/epoch - 709ms/step
# Epoch 42/100
# 22/22 - 16s - loss: 1.2958 - accuracy: 0.4754 - val_loss: 0.9680 - val_accuracy: 0.8082 - 16s/epoch - 743ms/step
# Epoch 43/100
# 22/22 - 16s - loss: 1.3381 - accuracy: 0.4754 - val_loss: 0.9686 - val_accuracy: 0.8082 - 16s/epoch - 708ms/step
# Epoch 44/100
# 22/22 - 16s - loss: 1.4127 - accuracy: 0.4335 - val_loss: 0.9687 - val_accuracy: 0.8082 - 16s/epoch - 711ms/step
# Epoch 45/100
# 22/22 - 16s - loss: 1.3494 - accuracy: 0.4465 - val_loss: 0.9684 - val_accuracy: 0.8082 - 16s/epoch - 720ms/step
# Epoch 46/100
# 22/22 - 16s - loss: 1.3645 - accuracy: 0.4697 - val_loss: 0.9681 - val_accuracy: 0.8082 - 16s/epoch - 720ms/step
# Epoch 47/100
# 22/22 - 16s - loss: 1.3840 - accuracy: 0.4480 - val_loss: 0.9683 - val_accuracy: 0.8082 - 16s/epoch - 731ms/step
# Epoch 48/100
# 22/22 - 16s - loss: 1.3577 - accuracy: 0.4523 - val_loss: 0.9671 - val_accuracy: 0.8082 - 16s/epoch - 733ms/step
# Epoch 49/100
# 22/22 - 16s - loss: 1.3295 - accuracy: 0.4697 - val_loss: 0.9676 - val_accuracy: 0.8082 - 16s/epoch - 732ms/step
# Epoch 50/100
# 22/22 - 16s - loss: 1.3340 - accuracy: 0.4740 - val_loss: 0.9679 - val_accuracy: 0.8082 - 16s/epoch - 730ms/step
# Epoch 51/100
# 22/22 - 16s - loss: 1.3169 - accuracy: 0.4783 - val_loss: 0.9670 - val_accuracy: 0.8082 - 16s/epoch - 734ms/step
# Epoch 52/100
# 22/22 - 16s - loss: 1.3545 - accuracy: 0.4523 - val_loss: 0.9686 - val_accuracy: 0.8082 - 16s/epoch - 730ms/step
# Epoch 53/100
# 22/22 - 16s - loss: 1.2965 - accuracy: 0.4957 - val_loss: 0.9697 - val_accuracy: 0.8082 - 16s/epoch - 732ms/step
# Epoch 54/100
# 22/22 - 16s - loss: 1.3344 - accuracy: 0.4451 - val_loss: 0.9705 - val_accuracy: 0.8082 - 16s/epoch - 712ms/step
# Epoch 55/100
# 22/22 - 16s - loss: 1.3736 - accuracy: 0.4595 - val_loss: 0.9709 - val_accuracy: 0.8082 - 16s/epoch - 709ms/step
# Epoch 56/100
# 22/22 - 16s - loss: 1.3119 - accuracy: 0.4841 - val_loss: 0.9715 - val_accuracy: 0.7945 - 16s/epoch - 712ms/step
# Epoch 57/100
# 22/22 - 16s - loss: 1.3062 - accuracy: 0.4769 - val_loss: 0.9714 - val_accuracy: 0.7945 - 16s/epoch - 728ms/step
# Epoch 58/100
# 22/22 - 16s - loss: 1.3630 - accuracy: 0.4581 - val_loss: 0.9710 - val_accuracy: 0.7945 - 16s/epoch - 715ms/step
# Epoch 59/100
# 22/22 - 16s - loss: 1.3181 - accuracy: 0.4725 - val_loss: 0.9714 - val_accuracy: 0.7945 - 16s/epoch - 712ms/step
# Epoch 60/100
# 22/22 - 16s - loss: 1.3550 - accuracy: 0.4509 - val_loss: 0.9720 - val_accuracy: 0.7945 - 16s/epoch - 718ms/step
# Epoch 61/100
# 22/22 - 16s - loss: 1.3507 - accuracy: 0.4465 - val_loss: 0.9720 - val_accuracy: 0.7945 - 16s/epoch - 730ms/step
# Epoch 61: early stopping

# %% [markdown]
# <h3>Accuracy and Loss graph</h3>

# %%
#accuracy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

#loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# <h3>Classification report</h3>

# %%
predictions = model.predict(test, verbose=0)
# predictions = predictions.reshape(1,-1)[0]
lst = np.argmax(predictions, axis= 1)

print(classification_report(test.classes, lst, target_names = test.class_indices))
# Out:
#               precision    recall  f1-score   support
#
#     Duracell       0.55      0.79      0.65        14
#    Energizer       0.92      0.86      0.89        14
#     Eveready       0.62      0.80      0.70        10
#        Exell       0.80      0.89      0.84         9
#           GP       0.90      0.75      0.82        12
#         Ikea       0.75      0.33      0.46         9
#       Klarus       0.89      0.73      0.80        11
#    Panasonic       0.50      0.50      0.50        10
#
#     accuracy                           0.72        89
#    macro avg       0.74      0.71      0.71        89
# weighted avg       0.74      0.72      0.72        89

# %% [markdown]
# <h3>Confusion matrix</h3>

# %%
result = confusion_matrix(test.classes, lst)
print(result)

def plot_confusion_matrix(result, classes, cmap=plt.cm.Blues):
    plt.subplots(figsize=(7, 7))
    plt.imshow(result, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

    thresh = result.max() / 2.
    for i, j in itertools.product(range(result.shape[0]), range(result.shape[1])):
        plt.text(j, i, result[i, j],
            horizontalalignment="center",
            color = "white" if result[i, j] > thresh else "black")
        
    #current matplotlib version will cut off top and bottom of the matrix, 
    #hence the manual workaround - remove if matplotlib version does not cut off
    b, t = plt.ylim() # discover bottom and top values
    b += 0.5 # Add 0.5 to bottom
    t -= 0.5 # Subtract 0.5 from top
    plt.ylim(b, t) # update ylim(bottom, top) values
    plt.show()
    
plot_confusion_matrix(result, list(test.class_indices.keys()))
# Out:
# [[11  0  0  0  0  0  1  2]
#  [ 2 12  0  0  0  0  0  0]
#  [ 1  0  8  0  0  0  0  1]
#  [ 1  0  0  8  0  0  0  0]
#  [ 0  1  0  0  9  1  0  1]
#  [ 1  0  1  2  1  3  0  1]
#  [ 3  0  0  0  0  0  8  0]
#  [ 1  0  4  0  0  0  0  5]]

# %% [markdown]
# <h3>Labels of wrong predictions</h3>

# %%
def getErrors(test, predictions):
    #get file names of all images in test data
    names = test.filenames

    #get IDs of all classes
    allClassesID = test.classes

    #get dictionary of classes and respective ID
    classLabelDict = test.class_indices
    
    #list of the names of all classes
    classLabels = list(classLabelDict.keys())

    print("The list of classes: ", classLabels)

    #get the most predicted class
    predictedClasses = np.argmax(predictions, axis=1)

    predictedErrors = np.where(predictedClasses != allClassesID)[0]

    print("Number of errors = {}/{}".format(len(predictedErrors),test.samples))

    return classLabels, predictedErrors, names

def showErrors(classLabels, predictedErrors, predictions, names):
    # Show the errors
    for i in range(len(errors)):
        predictedClass = np.argmax(predictions[predictedErrors[i]])

        predictedLabel = classLabels[predictedClass]

        title = 'Original Picture : {}, Prediction : {}, Confidence/Percentage : {:.3f}'.format\
                (names[predictedErrors[i]].split('/')[0],predictedLabel, predictions[errors[i]][predictedClass])
        print(title)

# %%
#get the list of class labels, prediction errors and file names
labels, errors, names = getErrors(test, predictions)

#show wrongly predicted images, prediction and and the percentage (confidence)
showErrors(labels, errors, predictions, names)
# Out:
# The list of classes:  ['Duracell', 'Energizer', 'Eveready', 'Exell', 'GP', 'Ikea', 'Klarus', 'Panasonic']
# Number of errors = 25/89
# Original Picture : Duracell\5.jpg, Prediction : Panasonic, Confidence/Percentage : 0.526
# Original Picture : Duracell\Image_51.jpg, Prediction : Panasonic, Confidence/Percentage : 0.376
# Original Picture : Duracell\a592dc4c-819d-4e50-8a17-9945092c6822.2e7043c49756d37f9a4544a67b78ad15.jpg, Prediction : Klarus, Confidence/Percentage : 0.503
# Original Picture : Energizer\3.jpg, Prediction : Duracell, Confidence/Percentage : 0.408
# Original Picture : Energizer\6174074009.jpeg, Prediction : Duracell, Confidence/Percentage : 0.543
# Original Picture : Eveready\4 (2).jpeg, Prediction : Panasonic, Confidence/Percentage : 0.301
# Original Picture : Eveready\eveready_c_sizeformat_battery_1679558982_1a2418a8_progressive.jpg, Prediction : Duracell, Confidence/Percentage : 0.358
# Original Picture : Exell\8.jpeg, Prediction : Duracell, Confidence/Percentage : 0.220
# Original Picture : GP\1-2v-aa-2500-mah-gp-rechargeable-nimh-battery.jpg, Prediction : Ikea, Confidence/Percentage : 0.254
# Original Picture : GP\e20dd0f6262f7130a366687da995e21b.jpg, Prediction : Panasonic, Confidence/Percentage : 0.340
# Original Picture : GP\tester1.jpg, Prediction : Energizer, Confidence/Percentage : 0.944
# Original Picture : Ikea\12 (2).jpeg, Prediction : Eveready, Confidence/Percentage : 0.492
# Original Picture : Ikea\2 (2).jpeg, Prediction : Exell, Confidence/Percentage : 0.229
# Original Picture : Ikea\Image_48.jpg, Prediction : Exell, Confidence/Percentage : 0.229
# Original Picture : Ikea\d6b6996cac3eed0460baec2c026d7169.jpg, Prediction : GP, Confidence/Percentage : 0.483
# Original Picture : Ikea\feel_power_with_ikea_batteries_by_buaha_dq4ax8-fullview.jpg, Prediction : Panasonic, Confidence/Percentage : 0.186
# Original Picture : Ikea\ikea_vinninge_with_2pcs_aa_bat_1652682852_034378e6_progressive.jpg, Prediction : Duracell, Confidence/Percentage : 0.188
# Original Picture : Klarus\Image_19.jpeg, Prediction : Duracell, Confidence/Percentage : 0.586
# Original Picture : Klarus\Image_34.jpg, Prediction : Duracell, Confidence/Percentage : 0.422
# Original Picture : Klarus\images.jpg, Prediction : Duracell, Confidence/Percentage : 0.450
# Original Picture : Panasonic\18.jpg, Prediction : Duracell, Confidence/Percentage : 0.310
# Original Picture : Panasonic\9 (3).jpeg, Prediction : Eveready, Confidence/Percentage : 0.429
# Original Picture : Panasonic\Image_15.jpg, Prediction : Eveready, Confidence/Percentage : 0.544
# Original Picture : Panasonic\Image_4.jpg, Prediction : Eveready, Confidence/Percentage : 0.497
# Original Picture : Panasonic\Image_5.jpg, Prediction : Eveready, Confidence/Percentage : 0.943

# %% [markdown]
# <h3>Save the model</h3>

# %%
#change the directory back to initial path (Image Classification folder)
os.chdir("../..")
# os.listdir()

#save the model so that it can be passed to edge device
model.save("image_classification.h5")
